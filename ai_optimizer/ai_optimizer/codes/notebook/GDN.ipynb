# %%
import uuid
from googleads import adwords
import sys

# %%
from csv import reader
import csv
import pandas as pd
import numpy as np
import copy

# %%
AUTH_FILE_PATH = '/home/tim_su/ai_optimizer/opt/ai_optimizer/googleads.yaml'
client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#client_2 = ad_manager.AdManagerClient.LoadFromStorage('/home/tim_su/ai_optimizer/opt/ai_optimizer/googleads.yaml')

# %%
CUSTOMER_SERVICE_ID = '3637290511'
CUSTOMER_SERVICE_ID = '5066360290'
client.SetClientCustomerId(CUSTOMER_SERVICE_ID)

# %% [markdown]
# ## Get Available Fields of Report Type

# %%
# Display which field is able to query for certain report type
REPORT_TYPE = 'CAMPAIGN_PERFORMANCE_REPORT'

def get_report_fields(client, report_type):
    # Initialize appropriate service.
    report_definition_service = client.GetService(
        'ReportDefinitionService', version='v201809')

    # Get report fields.
    fields = report_definition_service.getReportFields(report_type)

    # Display results.
    print('Report type "%s" contains the following fields:' % report_type)
    for field in fields:
        print(' - %s(%s)' % (field['fieldName'], field['fieldType']))
        if 'enumValues' in field:
            print('  := [%s]' % ', '.join(field['enumValues']))

if __name__ == '__main__':
    # Initialize client object.
    adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    get_report_fields(adwords_client, REPORT_TYPE)

# %% [markdown]
# ## Campaign Insights & AdGroup Insights

# %%
CAMPAIGN_FIELDS = ['ExternalCustomerId','CampaignId','AdvertisingChannelType', 'CampaignStatus',
                   'BiddingStrategyType','Amount','StartDate','EndDate','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion', 'Ctr']
class DatePreset:
    today = 'TODAY'
    yesterday = 'YESTERDAY'
    lifetime = 'ALL_TIME'

def get_campaign_insights(client, campaign_id=None, date_preset=None):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    report = {
        'reportName': 'CAMPAIGN_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
        'dateRangeType': date_preset,
        'reportType': 'CAMPAIGN_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': CAMPAIGN_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
            'predicates': [
                {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
                }
            ]
        }
    }
    # Print out the report as a string
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(CAMPAIGN_FIELDS)),
            columns=CAMPAIGN_FIELDS
        )
        df = df.append(df_temp)
        df['Ctr'] = df.Ctr.str.split('%', expand = True)[0]
    df[df.columns.difference(['CampaignStatus', 'AdvertisingChannelType', 'BiddingStrategyType', 'StartDate', 'EndDate'])] = df[df.columns.difference(
        ['CampaignStatus', 'AdvertisingChannelType', 'BiddingStrategyType', 'StartDate', 'EndDate'])].apply(pd.to_numeric, errors='coerce')
    df[df.columns.difference(['ExternalCustomerId', 'CampaignId', 'AdvertisingChannelType', 'CampaignStatus', 'BiddingStrategyType', 'StartDate', 'EndDate', 'Impressions', 'Clicks', 'Conversions', 'Ctr'])] = df[df.columns.difference(
        ['ExternalCustomerId', 'CampaignId', 'CampaignStatus', 'AdvertisingChannelType', 'BiddingStrategyType', 'StartDate', 'EndDate', 'Impressions', 'Clicks', 'Conversions', 'Ctr'])].div(1000000)
    df[['StartDate','EndDate']] = df[['StartDate','EndDate']].apply( pd.to_datetime, errors='coerce' )
    return df

# %%
if __name__ == '__main__':
    # Initialize client object.
    campaign_id = 1809236789
    client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    campaign_insights = get_campaign_insights(client, campaign_id=campaign_id)

# %%
campaign_insights

# %%
ADGROUP_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus',
                  'CpmBid','CpvBid', 'CpcBid', 'TargetCpa', 'BiddingStrategyType','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion']
# ADGROUP_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId','ConversionCategoryName']
def get_adgroup_insights(client, campaign_id=None, adgroup_id=None, date_preset=None):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    if campaign_id is not None and adgroup_id is None:
        operand = {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
        }
    elif adgroup_id is not None:
        operand = {
                    'field': 'AdGroupId',
                    'operator': 'EQUALS',
                    'values':[adgroup_id]
        }
    else:
        print('get_adgroup_insights: Missing arguments campaign_id or adgroup_id.' )
        operand = None
        return
    report = {
        'reportName': 'ADGROUP_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
        'dateRangeType': date_preset,
        'reportType': 'ADGROUP_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': ADGROUP_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
            'predicates': [
                operand
            ]
        }
    }
    # Print out the report as a string
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(ADGROUP_FIELDS)),
            columns=ADGROUP_FIELDS
        )
        df = df.append(df_temp)
    df[df.columns.difference(['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType'])] = df[df.columns.difference(
        ['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType'])].apply(pd.to_numeric, errors='coerce')
    df[df.columns.difference( ['ExternalCustomerId', 'CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType', 'Conversions'] )] = df[df.columns.difference(
        ['ExternalCustomerId', 'CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType', 'Conversions'])].div(1000000)

    return df.reset_index(drop=True)

if __name__ == '__main__':
    # Initialize client object.
    client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#     adgroup_insights = get_adgroup_insights(client)
    adgroup_insights = get_adgroup_insights(client, campaign_id=campaign_id)

# %% [markdown]
# ## Retrieve Age Range Performance Report

# %%
AGE_RANGE_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupId','Criteria', 'Id', 'AdGroupStatus',
                  'CpmBid', 'CpcBid', 'BiddingStrategyType','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion']
# AGE_RANGE_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId','ConversionCategoryName']
def get_age_range_insights(client, campaign_id=None, adgroup_id=None, date_preset=None):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    if campaign_id is not None and adgroup_id is None:
        operand = {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
        }
    elif adgroup_id is not None:
        operand = {
                    'field': 'AdGroupId',
                    'operator': 'EQUALS',
                    'values':[adgroup_id]
        }
    else:
        print('get_age_range_insights: Missing arguments campaign_id or adgroup_id.' )
        operand = None
        return
    report = {
        'reportName': 'AGE_RANGE_PERFORMANCE_REPORT',
        'dateRangeType': date_preset,
        'reportType': 'AGE_RANGE_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': AGE_RANGE_FIELDS,
            'predicates': [
                operand
            ]
        }
    }
    # Print out the report as a string
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(AGE_RANGE_FIELDS)),
            columns=AGE_RANGE_FIELDS
        )
        df = df.append(df_temp)
    df[df.columns.difference(['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType', 'Criteria'])] = df[df.columns.difference(
        ['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType', 'Criteria'])].apply(pd.to_numeric, errors='coerce')
    df[df.columns.difference( ['ExternalCustomerId', 'CampaignId','Criteria', 'Id', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType','Impressions', 'Clicks', 'Conversions'] )] = df[df.columns.difference(
        ['ExternalCustomerId', 'CampaignId', 'Criteria', 'Id', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType','Impressions', 'Clicks', 'Conversions'])].div(1000000)

    return df.reset_index(drop=True)

# if __name__ == '__main__':
# Initialize client object.
client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#     adgroup_insights = get_age_range_insights(client)
adgroup_insights = get_age_range_insights(client, campaign_id=1747836670, adgroup_id=68524904775)

# %% [markdown]
# ## Retrieve Performance Report from Different Criterions

# %%
import ai_optimizer.codes.gdn_db as gdn_db

# %%
# URL
URL_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'AdGroupStatus', 'Cost', 'AverageCost',
    'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion', 'DisplayName', ]

# CRITERIA,
CRITERIA_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'Criteria', 'Id', 'AdGroupStatus', 'CpmBid', 'CpcBid',
    'Cost', 'AverageCost', 'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion']

# AUDIENCE, AGE_RANGE, DISPLAY_KEYWORD
BIDDABLE_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'Criteria', 'Id', 'AdGroupStatus', 'CpmBid', 'CpcBid',
    'BiddingStrategyType', 'Cost', 'AverageCost', 'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion']

# ADGROUP
ADGROUP_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'CpmBid', 'CpvBid', 'CpcBid', 'TargetCpa',
    'BiddingStrategyType', 'Cost', 'AverageCost', 'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion']

NON_NUMERIC_FIELDS_LIST = [
    'Ad group type', 'Ad group state', 'Bid Strategy Type', 'Keyword', 'Age Range', 'Audience', 'Keyword / Placement', 'Criteria Display Name']

NUMERIC_FIELDS_LIST = [
    'Max. CPM', 'Max. CPV', 'Max. CPC', 'Default max. CPC', 'Target CPA', 'Cost', 'Avg. Cost', 'Avg. CPC', 'Cost / conv.']

FIELD_INDEX = {
    'ADGROUP': ADGROUP_FIELDS_LIST,
    'URL': URL_FIELDS_LIST,
    'CRITERIA': CRITERIA_FIELDS_LIST,
    'AUDIENCE': BIDDABLE_FIELDS_LIST,
    'AGE_RANGE': BIDDABLE_FIELDS_LIST,
    'DISPLAY_KEYWORD': BIDDABLE_FIELDS_LIST,
}

ADGROUP_FIELDS_LIST  = [
    'customer_id', 'campaign_id', 'channel_type', 'adgroup_id', 'status', 'cpm_bid', 'cpv_bid', 'cpc_bid', 'cpa_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
URL_FIELDS_LIST      = [
    'customer_id', 'campaign_id', 'adgroup_id', 'status', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion', 'url_display_name']
CRITERIA_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'keyword_placement', 'keyword_id', 'status', 'cpm_bid', 'cpc_bid', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
AUDIENCE_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'audience', 'criterion_id', 'status', 'cpm_bid', 'cpc_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
AGE_RANGE_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'age_range', 'criterion_id', 'status', 'cpm_bid', 'cpc_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
BIDDABLE_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'keyword', 'keyword_id', 'status', 'cpm_bid', 'cpc_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']

COLUMN_INDEX = {
    'ADGROUP': ADGROUP_FIELDS_LIST,
    'URL': URL_FIELDS_LIST,
    'CRITERIA': CRITERIA_FIELDS_LIST,
    'AUDIENCE': AUDIENCE_FIELDS_LIST,
    'AGE_RANGE': AGE_RANGE_FIELDS_LIST,
    'DISPLAY_KEYWORD': BIDDABLE_FIELDS_LIST,
}
DATABASE_INDEX = {
    'ADGROUP': 'adgroup_insights',
    'URL': 'url_insights',
    'CRITERIA': 'criteria_insights',
    'AUDIENCE': 'audience_insights',
    'AGE_RANGE': 'age_range_insights',
    'DISPLAY_KEYWORD': 'display_keyword_insights',
}

# %%
def get_performance_insights(client, campaign_id=None, adgroup_id=None, date_preset=None, performance_type='ADGROUP'):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if not date_preset:
        date_preset = 'ALL_TIME'
    # Create report definition.
    if campaign_id is not None and adgroup_id is None:
        operand = {
            'field': 'CampaignId',
            'operator': 'EQUALS',
            'values': [campaign_id]
        }
    elif adgroup_id is not None:
        operand = {
            'field': 'AdGroupId',
            'operator': 'EQUALS',
            'values': [adgroup_id]
        }
    else:
        print('get_audience_insights: Missing arguments campaign_id or adgroup_id.')
        operand = None
        return
    report = {
        'downloadFormat': 'CSV',
        'reportName': performance_type+'_PERFORMANCE_REPORT',
        'reportType': performance_type+'_PERFORMANCE_REPORT',
        'dateRangeType': date_preset,
        'selector': {
            'fields': FIELD_INDEX[performance_type],
            'predicates': [operand]
        }
    }
    # Print out the report as a string
    with open(performance_type+'.csv', 'wb') as output_file:
        report_downloader.DownloadReport(
            report, output=output_file, skip_report_header=True, skip_column_header=False,
            skip_report_summary=True, include_zero_impressions=False, client_customer_id=CUSTOMER_ID)
    with open(performance_type+'.csv')as csv_file:
        df = pd.read_csv(csv_file, sep=",", quotechar='"')
        df[df.columns.difference( NON_NUMERIC_FIELDS_LIST )] = df[
            df.columns.difference( NON_NUMERIC_FIELDS_LIST )].apply(pd.to_numeric, errors='coerce')
        
        df[df.columns.intersection( NUMERIC_FIELDS_LIST )] = df[
            df.columns.intersection( NUMERIC_FIELDS_LIST )].div(1000000)
        
        df.columns = COLUMN_INDEX[performance_type]
        gdn_db.into_table( df, DATABASE_INDEX[performance_type] )
        return df.sort_values(by=['impressions'], ascending=False).reset_index(drop=True)


# if __name__ == '__main__':
#     # Initialize client object.
#     # URL
#     # CRITERIA
#     # AUDIENCE, AGE_RANGE, DISPLAY_KEYWORD
#     from ai_optimizer.codes import gdn_db
#     client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#     display_keyword_insights = get_performance_insights(
#         client, campaign_id=1747836664, adgroup_id=68524904535, performance_type='DISPLAY_KEYWORD')

# %%
CUSTOMER_ID = 5922380045
CAMPAIGN_ID = 1896291336
ADGROUP_ID = 70071948917
AUTH_FILE_PATH = '/home/tim_su/ai_optimizer/opt/ai_optimizer/googleads.yaml'
adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
adwords_client.SetClientCustomerId(CUSTOMER_ID)
get_performance_insights(
    adwords_client,
    campaign_id=CAMPAIGN_ID,
    performance_type='AGE_RANGE')
# Out:
#    customer_id  campaign_id   adgroup_id     age_range  criterion_id   status  \
# 0   5922380045   1896291336  69785365626  Undetermined        503999  enabled
# 1   5922380045   1896291336  69785365626         25-34        503002  enabled
# 2   5922380045   1896291336  69785365626         35-44        503003  enabled
# 3   5922380045   1896291336  69785365626         45-54        503004  enabled
# 4   5922380045   1896291336  69785365626         18-24        503001  enabled
# 5   5922380045   1896291336  69785365626         55-64        503005  enabled
# 6   5922380045   1896291336  69785365626    65 or more        503006  enabled
#
#    cpm_bid  cpc_bid bidding_type        spend  cost_per_target  impressions  \
# 0      NaN      8.0          cpc  2411.121649         6.214231       355772
# 1      NaN      8.0          cpc  1132.496868         7.034142       118570
# 2      NaN      8.0          cpc  1121.448896         8.560679        97450
# 3      NaN      8.0          cpc   742.332172         7.897151        52456
# 4      NaN      8.0          cpc   351.940255         5.865671        45323
# 5      NaN      8.0          cpc   614.494418         7.229346        32382
# 6      NaN      8.0          cpc   641.917443         6.617706        27831
#
#    clicks  conversions  cost_per_click  cost_per_conversion
# 0     388          0.0        6.214231                  0.0
# 1     161          0.0        7.034142                  0.0
# 2     131          0.0        8.560679                  0.0
# 3      94          0.0        7.897151                  0.0
# 4      60          0.0        5.865671                  0.0
# 5      85          0.0        7.229346                  0.0
# 6      97          0.0        6.617706                  0.0

# %% [markdown]
# ## Make AdGroup

# %%
from googleads import adwords
CUSTOMER_SERVICE_ID = '3637290511'
client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
AD_GROUP_ID = 68524904055
CPC_BID_MICRO_AMOUNT = '4000000'


def update_adgroup_bid(client, ad_group_id, bid_micro_amount=None):
    # Initialize appropriate service.
    ad_group_service = client.GetService('AdGroupService', version='v201809')
    
    # Construct operations and update an ad group.
    operations = [{
        'operator': 'SET',
        'operand': {
            'id': ad_group_id,
            'status': 'ENABLED'
        }
    }]
  
    if bid_micro_amount:
        operations[0]['operand']['biddingStrategyConfiguration'] = {
            'bids': [{
                'xsi_type': 'CpcBid',
                'bid': {
                    'microAmount': bid_micro_amount,
                }
            }]
        }
  
    ad_groups = ad_group_service.mutate(operations)
    return ad_groups

if __name__ == '__main__':
    # Initialize client object.
    adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    adwords_client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    update_adgroup_bid(adwords_client, AD_GROUP_ID, CPC_BID_MICRO_AMOUNT)

# %%
adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
adwords_client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
update_adgroup_bid(adwords_client, AD_GROUP_ID, CPC_BID_MICRO_AMOUNT)

# %%
def retrieve_campaign_params(client, campaign_id):
    _FIELDS = ['CampaignId', 'Name']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'CampaignId',
                'operator': 'EQUALS',
                'values':[campaign_id]
            }
        ]
    }]
    campaign_service = client.GetService('CampaignService', version='v201809')
    campaign_params = campaign_service.get(selector)
    return campaign_params

# %% [markdown]
# ## Retrive AdGroup Params

# %% [markdown]
# ### Params

# %% [markdown]
# #### AdGroup

# %%
def retrieve_ad_group_params(client, ad_group_id):
    _FIELDS = ['CampaignId', 'AdGroupId', 'Name', 'CpcBid', 'BiddingStrategyId','BiddingStrategyName','BiddingStrategySource', 'BiddingStrategyType']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_group_service = client.GetService('AdGroupService', version='v201809')
    ad_group_params = ad_group_service.get(selector)
    return ad_group_params

def make_ad_group(ad_group_id):
    ad_group_params = retrieve_ad_group_params(client, ad_group_id)
    campaign_id = ad_group_params['entries'][0]['campaignId']
    name = ad_group_params['entries'][0]['name']
    xsi_type = ad_group_params['entries'][0]['biddingStrategyConfiguration']['bids'][0]['Bids.Type']
    micro_amount = ad_group_params['entries'][0]['biddingStrategyConfiguration']['bids'][0]['bid']['microAmount']
    operations = [{
        'operator': 'ADD',
        'operand': {
            'campaignId': campaign_id,
            'name':  'Mutant {}'.format(name),
            'status': 'ENABLED',
            'biddingStrategyConfiguration': {
                'bids': [
                    {
                        'xsi_type': xsi_type,
                        'bid': {
                            'microAmount': micro_amount
                        }
                    }
                ]
            }
        }
    }]
    ad_group_service = client.GetService('AdGroupService', version='v201809')
    ad_groups = ad_group_service.mutate(operations)
    return ad_groups

# %% [markdown]
# #### Ad

# %%
def retrive_ad_params(ad_group_id):
    ad_params_list = []
    ad_criteria = dict()
    _FIELDS = ['AdGroupId', 'HeadlinePart1', 'HeadlinePart2', 'DisplayUrl', 'CreativeFinalUrls', 'Description', 'Url']
    selector= [{
        'fields': _FIELDS,
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_service = client.GetService('AdGroupAdService', version='v201809')
    ad_params = ad_service.get(selector)
    for entry in ad_params['entries']:
        ad_criteria['id'] = entry['ad']['id']
        ad_params_list.append(copy.deepcopy(ad_criteria))
    return ad_params_list

def assign_ad_to_ad_group(ad_group_id, ad_params_list):
    operations = []
    for ad_params in ad_params_list:
        operations.append({
            'operator': 'ADD',
            'operand': {
                'adGroupId': ad_group_id,
                'status': 'ENABLED',
                'ad': ad_params
            }
        })
    ad_group_service = client.GetService('AdGroupAdService', version='v201809')
    ad_groups = ad_group_service.mutate(operations)
    return ad_groups

# %% [markdown]
# ### Criterion

# %%
def retrieve_ad_group_criterion(client, ad_group_id):
    _FIELDS = ['AdGroupId', 'CriteriaType', 'UserInterestId', 'UserInterestName', 'UserListId', 'LabelIds']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_group_service = client.GetService('AdGroupCriterionService', version='v201809')
    ad_group_criterion = ad_group_service.get(selector)
    return ad_group_criterion

def make_adgroup_criterion(new_adgroup_id = None, old_ad_group_criterion=None):
    if new_adgroup_id is None and old_ad_group_criterion is None:
        raise ValueError('new_adgroup_id and old_ad_group_criterion is Required.')
    biddable_criterion = dict()
    negative_criterion = dict()
    biddable_criterion['adGroupId'] = new_adgroup_id
    negative_criterion['adGroupId'] = new_adgroup_id

    biddable_ad_group_criteria_list = list()
    negative_ad_group_criteria_list = list()
    for entry in old_ad_group_criterion['entries']:
        criterion = dict()
        
        if 'AgeRange' in entry['criterion']['Criterion.Type']:
            criterion['id'] = entry['criterion']['id']
            criterion['xsi_type'] = entry['criterion']['Criterion.Type']
            
        elif 'Placement'  in entry['criterion']['Criterion.Type']:
            criterion['id'] = entry['criterion']['id']
            criterion['url'] = entry['criterion']['url']
            criterion['xsi_type'] = entry['criterion']['Criterion.Type']

        elif 'Keyword'  in entry['criterion']['Criterion.Type']:
            criterion['id'] = entry['criterion']['id']
            criterion['matchType'] = entry['criterion']['matchType']
            criterion['text'] = entry['criterion']['text']
            criterion['xsi_type'] = entry['criterion']['Criterion.Type']

        elif 'CriterionUserInterest'  in entry['criterion']['Criterion.Type']:
            criterion['id'] = entry['criterion']['id']
            criterion['userInterestId'] = entry['criterion']['userInterestId']
            criterion['xsi_type'] = entry['criterion']['Criterion.Type']
        else:
            pass
        if criterion:
            if 'BiddableAdGroupCriterion' in entry['AdGroupCriterion.Type']:
                biddable_criterion['xsi_type'] = entry['AdGroupCriterion.Type']
                biddable_criterion['criterion'] = criterion
                biddable_ad_group_criteria_list.append(copy.deepcopy(biddable_criterion))

            elif 'NegativeAdGroupCriterion' in entry['AdGroupCriterion.Type']:
                negative_criterion['xsi_type'] = entry['AdGroupCriterion.Type']
                negative_criterion['criterion'] = criterion
                negative_ad_group_criteria_list.append(copy.deepcopy(negative_criterion))
    return biddable_ad_group_criteria_list, negative_ad_group_criteria_list
 

def assign_criterion_to_ad_group(client, ad_group_id, ad_group_criterion):
    '''
    an example of addong 4 type of criterion to new adgroup,
    if trying to exclude certain criterions, 
    change 'xsi_type' from 'BiddableAdGroupCriterion' to 'NegativeAdGroupCriterion' in ad_group_criteria object
    '''
    # Initialize appropriate service.
    ad_group_criterion_service = client.GetService(
        'AdGroupCriterionService', version='v201809')
    # Create the ad group criteria.  
    # Create operations.
    operations = []
    for criterion in ad_group_criterion:
        operations.append({
            'operator': 'ADD',
            'operand': criterion
        })
    response = ad_group_criterion_service.mutate(operations)
    return response

def make_adgroup_criterion_by_score(campaign_id, new_ad_group_id):
    criterions=[]
    for criteria in SCORE_INDEX.keys():
        df = gdn_db.get_table(campaign_id=campaign_id, table=SCORE_INDEX[criteria]+"_score").head()
        if not df.empty:
#             print(criteria)
            sub_criterions = []
            df = df.sort_values(by=['score'], ascending=False).reset_index(drop=True).drop_duplicates([CRITERIA_COLUMN_INDEX[criteria]])
            criterion = {
                'adGroupId': new_ad_group_id,
                'xsi_type': 'BiddableAdGroupCriterion',
                'criterion': {
                    'xsi_type': None,
                    'id': None
                }
            }
            if criteria == 'AGE_RANGE':
                criterion['criterion']['xsi_type'] = CRITERIA_TYPE_INDEX[criteria]
                for i, criterion_id in enumerate( df[CRITERIA_COLUMN_INDEX[criteria]] ):
                    if CRITERIA_TYPE_INDEX[criteria] == 'AgeRange':
                        criterion['criterion']['id'] = criterion_id
                        sub_criterions.append(copy.deepcopy(criterion))
            else:
                criterion['criterion']['xsi_type'] = CRITERIA_TYPE_INDEX[criteria]
                for i, criterion_id in enumerate( df[CRITERIA_COLUMN_INDEX[criteria]] ):
                    if CRITERIA_TYPE_INDEX[criteria] == 'Placement':
                        criterion['criterion']['id'] = criterion_id
                        criterion['criterion']['url'] = df['url_display_name'].iloc[0]

                    elif CRITERIA_TYPE_INDEX[criteria] == 'Keyword':
#                         criterion['criterion']['id'] = criterion_id
                        criterion['criterion']['matchType'] = 'BROAD'
                        criterion['criterion']['text'] = df['keyword'].iloc[i]

                    elif CRITERIA_TYPE_INDEX[criteria] == 'CriterionUserInterest':
                        criterion['criterion']['id'] = criterion_id
                        criterion['criterion']['userInterestId'] = criterion_id
                    sub_criterions.append(copy.deepcopy(criterion))
            criterions = criterions+sub_criterions
    return criterions

# %% [markdown]
# ## Make New AdGroup With Criterion From Old AdGroup

# %%
def make_adgroup_with_criterion(old_ad_group_id):
    # Params
    ad_group_params = make_ad_group(old_ad_group_id)
    new_ad_group_id = ad_group_params['value'][0]['id']
    # Criterion
#     old_ad_group_criterion = retrieve_ad_group_criterion(client, old_ad_group_id)
#     biddable_criterion, negative_criterion = make_adgroup_criterion(new_ad_group_id, old_ad_group_criterion)
#     print(biddable_criterion)
#     new_ad_group_criterion = biddable_criterion + negative_criterion
    new_ad_group_criterion = make_adgroup_criterion_by_score(campaign_id, new_ad_group_id)
    result = assign_criterion_to_ad_group(client, new_ad_group_id, new_ad_group_criterion)
    # Assign Ad Params
    ad_params_list = retrive_ad_params(old_ad_group_id)
    assign_ad_to_ad_group(new_ad_group_id, ad_params_list)
    return result

# %% [markdown]
# ## Test Custom Affinity

# %%
custom_affinity_ad_group_id = 68524903895
similar_audience_ad_group_id = 68524904615
ad_group_id = 70749935918

# %% [markdown]
# ### Criterion

# %%
_FIELDS = ['AdGroupId', 'CriteriaType', 'UserInterestId', 'UserInterestName', 'UserListId', 'LabelIds','CustomAffinityId',
           'FinalUrls', 'UrlCustomParameters', 'CriteriaSamples','UserListMembershipStatus']
selector= [{
    'fields': _FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
    'predicates': [
        {
            'field': 'AdGroupId',
            'operator': 'EQUALS',
            'values':[ad_group_id]
        }
    ]
}]
ad_group_service = client.GetService('AdGroupCriterionService', version='v201809')
ad_group_criterion = ad_group_service.get(selector)

# %%
ad_group_criterion

# %%
for criterion in ad_group_criterion['entries']:
    if criterion['criterion']['type']=='CUSTOM_AFFINITY':
        print(criterion)

# %%
custom_affinity_id = 2511435
id = 456069648865

# %% [markdown]
# ### Params

# %%
_FIELDS = ['CampaignId', 'AdGroupId', 'Name', 'CpcBid', 'BiddingStrategyId','BiddingStrategyName','BiddingStrategySource',
           'BiddingStrategyType', 'FinalUrlSuffix', 'Settings', 'UrlCustomParameters', 'TrackingUrlTemplate']
selector= [{
    'fields': _FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
    'predicates': [
        {
            'field': 'AdGroupId',
            'operator': 'EQUALS',
            'values':[ad_group_id]
        }
    ]
}]
ad_group_service = client.GetService('AdGroupService', version='v201809')
ad_group_params = ad_group_service.get(selector)

# %%
ad_group_params

# %% [markdown]
# ### Custom Affinity Service(get url by CustomAffinityId)

# %%
_FIELDS = ['CustomAffinityId', 'Name', 'Status', 'Type']
selector= [{
    'fields': _FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
    'predicates': [
        {
            'field': 'CustomAffinityId',
            'operator': 'EQUALS',
            'values':[custom_affinity_id]
        }
    ]
}]
ad_group_service = client.GetService('CustomAffinityService', version='v201809')
ad_group_params = ad_group_service.get(selector)

# %%
ad_group_params

# %%
URL_FIELDS_LIST = [
#     'Criteria','CriteriaDestinationUrl','CriterionAttachmentLevel', 'CustomerDescriptiveName', 'ExternalCustomerId',
#     'FinalAppUrls','FinalMobileUrls', 'FinalUrls','Id','IsRestrict','Status','TrackingUrlTemplate','UrlCustomParameters',
#     'UserListName'
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'AdGroupStatus', 'Cost', 'AverageCost',
    'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion',
    'VerticalId', 'CustomerDescriptiveName', 'Criteria'
    
]
# client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
report_downloader = client.GetReportDownloader(version='v201809')

operand = {
    'field': 'AdGroupId',
    'operator': 'EQUALS',
    'values': [ad_group_id]
}

report = {
    'downloadFormat': 'CSV',
    'reportName': 'DISPLAY_TOPICS_PERFORMANCE_REPORT',
    'reportType': 'DISPLAY_TOPICS_PERFORMANCE_REPORT',
    'dateRangeType': 'ALL_TIME',
    'selector': {
        'fields': URL_FIELDS_LIST,
        'predicates': [operand]
    }
}
# Print out the report as a string
with open('url_test.csv', 'wb') as output_file:
    report_downloader.DownloadReport(
        report, output=output_file, skip_report_header=True, skip_column_header=False,
        skip_report_summary=True, include_zero_impressions=False, client_customer_id=CUSTOMER_SERVICE_ID)
with open('url_test.csv')as csv_file:
    df = pd.read_csv(csv_file, sep=",", quotechar='"')

# %%
df.head()
# Out:
#    Customer ID  Campaign ID  Ad group ID Ad group state       Cost  Avg. Cost  \
# 0   5066360290   1837064053  70749935918        enabled  378621243    3129101
#
#    Impressions  Clicks  Conversions  Avg. CPC  Cost / conv.  Vertical ID  \
# 0        48595     121          0.0   3129101             0           78
#
#   Client name                 Topic
# 0        三菱電機  Consumer Electronics

# %% [markdown]
# ## Google Search Ads Testing

# %%
CUSTOMER_SERVICE_ID = '2719877792'
client.SetClientCustomerId(CUSTOMER_SERVICE_ID)

# %%
campaign_id = 1843251822

# %%
def retrieve_campaign_params(client, campaign_id):
    _FIELDS = ['CampaignId', 'Name']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'CampaignId',
                'operator': 'EQUALS',
                'values':[campaign_id]
            }
        ]
    }]
    campaign_service = client.GetService('CampaignService', version='v201809')
    campaign_params = campaign_service.get(selector)
    return campaign_params

# %%
retrieve_campaign_params(client, campaign_id)
# Out:
# {
#     'totalNumEntries': 1,
#     'Page.Type': 'CampaignPage',
#     'entries': [
#         {
#             'id': 1843251822,
#             'campaignGroupId': None,
#             'name': 'Search_台北_双湖滙_類型字_錯誤字',
#             'status': None,
#             'servingStatus': None,
#             'startDate': None,
#             'endDate': None,
#             'budget': None,
#             'conversionOptimizerEligibility': None,
#             'adServingOptimizationStatus': None,
#             'frequencyCap': None,
#             'settings': [],
#             'advertisingChannelType': None,
#             'advertisingChannelSubType': None,
#             'networkSetting': None,
#             'labels': [],
#             'biddingStrategyConfiguration': None,
#             'campaignTrialType': None,
#             'baseCampaignId': None,
#             'forwardCompatibilityMap': [],
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None,
#             'vanityPharma': None,
#             'universalAppCampaignInfo': None,
#             'selectiveOptimization': None
#         }
#     ]
# }

# %%
def retrieve_ad_group_criterion(client, ad_group_id):
    _FIELDS = ['AdGroupId', 'CriteriaType', 'BiddingStrategyType', 'BiddingStrategySource',
               'CpcBidSource', 'CpcBid', 'CriteriaSamples',
               'UserInterestId', 'UserInterestName', 'UserListId', 'LabelIds']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_group_service = client.GetService('AdGroupCriterionService', version='v201809')
    ad_group_criterion = ad_group_service.get(selector)
    return ad_group_criterion

# %%
ad_group_id = 73670130390

# %%
retrieve_ad_group_criterion(client, ad_group_id)
# Out:
# {
#     'totalNumEntries': 22,
#     'Page.Type': 'AdGroupCriterionPage',
#     'entries': [
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 100967303067,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '双湖滙',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 340269811572,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙 湖 匯',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 554408203817,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '双湖會',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 554408203857,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '双湖滙',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 554408205817,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙湖會',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 554408205977,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙湖滙',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 554408206457,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙胡會',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 554408206497,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙胡滙',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829548522,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '双湖會',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829549082,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙 湖 匯',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829549322,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙湖會',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829549482,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙湖滙',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829549522,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙胡會',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829549562,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙胡滙',
#                 'matchType': 'PHRASE'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829553122,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '双湖會',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829553162,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '双湖滙',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829554082,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙 湖 匯',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829554322,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙湖會',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829554362,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙湖滙',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829554522,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙胡會',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 560829554562,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙胡滙',
#                 'matchType': 'EXACT'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 73670130390,
#             'criterionUse': 'BIDDABLE',
#             'criterion': {
#                 'id': 694889876313,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '雙 湖 匯 公設',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': None,
#             'systemServingStatus': None,
#             'approvalStatus': None,
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 18000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         }
#     ]
# }

# %%
CAMPAIGN_FIELDS = ['ExternalCustomerId','CampaignId','AdvertisingChannelType', 'CampaignStatus',
                   'BiddingStrategyType','Amount','StartDate','EndDate','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion', 'Ctr']
ADGROUP_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus',
                  'CpmBid','CpvBid', 'CpcBid', 'TargetCpa', 'BiddingStrategyType','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion', 'Ctr']

# %%
def get_campaign_insights( client, date_preset='TODAY'):
    if not date_preset:
        date_preset = 'ALL_TIME'
    # Create report definition.
    report = {
        'reportName': 'CAMPAIGN_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
        'dateRangeType': date_preset,
        'reportType': 'CAMPAIGN_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': CAMPAIGN_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
            'predicates': [{
                'field': 'CampaignId',
                'operator': 'EQUALS',
                'values':[campaign_id]
            }]
        }
    }
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(CAMPAIGN_FIELDS)),
            columns=CAMPAIGN_FIELDS
        )
        df = df.append(df_temp)
    return df

# %%
get_campaign_insights( client, date_preset='TODAY')
# Out:
#   ExternalCustomerId  CampaignId AdvertisingChannelType CampaignStatus  \
# 0         2719877792  1843251822                 Search        enabled
#
#   BiddingStrategyType     Amount   StartDate EndDate      Cost AverageCost  \
# 0                 cpc  400000000  2019-04-30      --  63280000     7910000
#
#   Impressions Clicks Conversions AverageCpc CostPerConversion     Ctr
# 0          35      8        0.00    7910000                 0  22.86%

# %%
def get_adgroup_insights( client, date_preset=None):
    if not date_preset:
        date_preset = 'ALL_TIME'
    # Create report definition.
    if campaign_id is not None and ad_group_id is None:
        operand = {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
        }
    elif ad_group_id is not None:
        operand = {
                    'field': 'AdGroupId',
                    'operator': 'EQUALS',
                    'values':[ad_group_id]
        }
    else:
        print('get_adgroup_insights: Missing arguments campaign_id or ad_group_id.' )
        operand = None
        return
    report = {
        'reportName': 'ADGROUP_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
        'dateRangeType': date_preset,
        'reportType': 'ADGROUP_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': ADGROUP_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
            'predicates': [
                operand
            ]
        }
    }
    # Print out the report as a string
    csv =report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(ADGROUP_FIELDS)),
            columns=ADGROUP_FIELDS
        )
        df = df.append(df_temp)
    return df

# %%
get_adgroup_insights( client, date_preset='TODAY')
# Out:
#   ExternalCustomerId  CampaignId AdGroupType    AdGroupId AdGroupStatus  \
# 0         2719877792  1843251822    Standard  73670130390       enabled
#
#   CpmBid CpvBid    CpcBid TargetCpa BiddingStrategyType      Cost AverageCost  \
# 0     --     --  18000000        --                 cpc  63280000     7910000
#
#   Impressions Clicks Conversions AverageCpc CostPerConversion     Ctr
# 0          36      8        0.00    7910000                 0  22.22%

# %% [markdown]
# ## ConstantDataService Testing

# %%
CUSTOMER_SERVICE_ID = '2719877792'
client.SetClientCustomerId(CUSTOMER_SERVICE_ID)

# %%
ad_constant_data_service = client.GetService('ConstantDataService', version='v201809')

# %%
ad_constant_data = ad_constant_data_service.getMobileDeviceCriterion()

# %%
ad_constant_data
# Out:
# [{
#      'id': 600329,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Hero',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 600334,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Magic',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 600346,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P4350',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 600354,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'S620',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 601673,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '5130',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 601690,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '5800 XpressMusic',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 601879,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E72',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 601885,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'N70',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 603626,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'K700c',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 603915,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'myTouch',
#      'manufacturerName': 'T-Mobile',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 604043,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iPad',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 604044,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iPhone',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 604045,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iPod',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 604504,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P780',
#      'manufacturerName': 'Lenovo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 604652,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Droid',
#      'manufacturerName': 'Verizon',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605230,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Spark',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605231,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'T8788',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605234,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GW910',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605241,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E10i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605242,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'U20i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605258,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9800',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605267,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Xoom',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605283,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iphone1,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605284,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iphone1,2',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605285,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iphone2,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605286,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iphone3,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605288,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipod1,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605289,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipod2,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605290,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipod3,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605291,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipod4,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605292,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipad1,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605293,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipad1,2',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605294,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ipad2,1',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Apple iOS'
#  }, {
#      'id': 605299,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9900',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605300,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9930',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605302,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Blade',
#      'manufacturerName': 'ZTE',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605303,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Droid2',
#      'manufacturerName': 'Verizon',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605306,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IS04',
#      'manufacturerName': 'Toshiba',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605309,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'myTouch 3G Slide',
#      'manufacturerName': 'T-Mobile',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605310,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'X10i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605311,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'X10a',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605312,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SO-01C',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605313,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SO-01B',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605314,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MT15i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605315,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IS11S',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605316,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SH-13C',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605317,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SH-12C',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605318,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SH-03C',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605319,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IS12SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605320,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IS11SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605321,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IS05',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605322,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IS03',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605323,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '003SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605324,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'YP-GB70',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605326,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SPH-M910',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605331,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-T959V',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605332,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-T959',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605333,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-I997',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605334,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-I897',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605336,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SCH-I500',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605337,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SCH-I400',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605338,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SC-02B',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605339,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SC-01C',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605340,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-i5500',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605341,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5830L',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605342,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5830',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605343,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5670',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605344,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5660',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605345,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5570',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605346,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-P1000',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605347,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I9100',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605348,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I9003',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605349,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I9001',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605350,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I9000',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605351,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I5800',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605352,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I5510',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605353,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I5500L',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605354,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-B7510',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605355,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT i5700',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605359,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'AKY IM-A730S',
#      'manufacturerName': 'Pantech',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605362,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'N-06C',
#      'manufacturerName': 'NEC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605363,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'N-04C',
#      'manufacturerName': 'NEC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605364,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'i1',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605366,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'XT316',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605367,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Milestone',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605369,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MB860',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605370,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MB855',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605372,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MB525',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605376,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'DroidX',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605377,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Droid 2',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605378,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'DROID PRO',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605379,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'VS660',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605380,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'VM670',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605381,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'US855',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605383,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P990',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605384,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P925',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605385,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P509',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605386,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P500h',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605387,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MS910',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605388,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MS690',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605389,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LU6800',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605393,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LS670',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605395,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Ally',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605396,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'M6000',
#      'manufacturerName': 'Kyocera',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605399,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'M860',
#      'manufacturerName': 'HUAWEI',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605401,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Wildfire S',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605402,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Wildfire',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605403,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Sensation',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605404,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'PG06100',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605405,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'PC36100',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605409,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ISW11HT',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605410,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Hero 200',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605411,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Glacier',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605412,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'G2',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605414,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Desire HD',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605415,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Desire',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605417,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ADR6400L',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605418,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ADR6350',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605419,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ADR6300',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605420,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9292',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605421,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Nexus S',
#      'manufacturerName': 'Google',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605427,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A500',
#      'manufacturerName': 'Acer',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605429,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A501',
#      'manufacturerName': 'Acer',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605558,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Galaxy6',
#      'manufacturerName': 'Asus',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605628,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A6380',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605651,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Desire S',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605659,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'EVO 3D',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605661,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Fiesta',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605664,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'HD2',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605678,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Legend',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605712,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'PB99400',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605723,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'S510e',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605727,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'S710e',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605744,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'T9292',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 605757,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Vision',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 605865,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Vodafone 858',
#      'manufacturerName': 'HUAWEI',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606235,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT540',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606361,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LG220C',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606397,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LU3700',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606399,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LW690',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606441,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P350',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606442,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P500',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606443,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P920',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606444,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P970',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606445,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'P999',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606448,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SU660',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606522,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A953',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606602,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MB526',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606607,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ME525',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606632,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MZ601',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606658,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Sholes',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606734,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'WX445',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606736,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'XT300',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 606780,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '2605',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606808,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '5233',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606840,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '6303i Classic',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606866,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C1-01',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606868,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C2-01',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606869,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C3-00',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606871,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C5-03',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606875,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E5-00',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606879,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E63',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606913,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'X2-00',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606914,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'X2-01',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 606961,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Opera Mini for S60',
#      'manufacturerName': 'Opera',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607013,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IM-A690S',
#      'manufacturerName': 'Pantech',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607014,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IM-A710K',
#      'manufacturerName': 'Pantech',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607015,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IM-A720L',
#      'manufacturerName': 'Pantech',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607138,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT I9000T',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607171,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-B7610',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607209,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I5801',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607212,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-i8700',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607214,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I9000B',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607221,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-P7100',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607222,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-P7500',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607225,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S3350',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607237,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S3850',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607253,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5570B',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607254,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5570L',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607335,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SCH-I100',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607347,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SCH-R910',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607503,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-i917',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607548,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-T839',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607564,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SHW-M130L',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607565,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SHW-M190S',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607581,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SPH-D700',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607587,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SPH-M920',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607625,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '006SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607684,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E10a',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607685,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E15a',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607686,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E15i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607705,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LT15i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607716,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'R800i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607719,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SO-03C',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607741,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'U20a',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607781,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'G2 Touch',
#      'manufacturerName': 'T-Mobile',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 607815,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'TG01',
#      'manufacturerName': 'Toshiba',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607928,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'iPod Touch',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607930,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'TV',
#      'manufacturerName': 'Apple',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607970,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '8520',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607975,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9300',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607980,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9650',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607981,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9700',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607982,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9780',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607983,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9860',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 607999,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'PlayBook',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 608807,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Kindle 3',
#      'manufacturerName': 'Amazon',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 608928,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E390',
#      'manufacturerName': 'Micromax',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 609007,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'CTS reformatting proxy',
#      'manufacturerName': 'Novarra',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 609122,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9360',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 609123,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '9810',
#      'manufacturerName': 'BlackBerry',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 609130,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '200',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 609131,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '2700 classic',
#      'manufacturerName': 'Nokia',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': None
#  }, {
#      'id': 609133,
#      'type': None,
# ...
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C1505',
#      'manufacturerName': 'Sony',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609950,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'One SV',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609951,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'N-03E',
#      'manufacturerName': 'DoCoMo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609952,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E400g',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609953,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C6502',
#      'manufacturerName': 'Sony',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609954,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'M1',
#      'manufacturerName': 'PiPO',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609955,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Cink Slim',
#      'manufacturerName': 'Wiko',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609956,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'U795',
#      'manufacturerName': 'ZTE',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609957,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Vivo Y3t',
#      'manufacturerName': 'BBK',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609958,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'R813T',
#      'manufacturerName': 'OPPO',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609959,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SH-06E',
#      'manufacturerName': 'DoCoMo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609960,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Vivo S7',
#      'manufacturerName': 'BBK',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609961,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A6',
#      'manufacturerName': 'Karbonn',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609962,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'F160S',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609963,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'T40',
#      'manufacturerName': 'Turkcell',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609964,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Lenovo A516',
#      'manufacturerName': 'Lenovo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609965,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '200SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609966,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'YP-GP1',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609967,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '302SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609968,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ST26a',
#      'manufacturerName': 'Sony',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609969,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LT22i',
#      'manufacturerName': 'SonyEricsson',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609970,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-T999V',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609971,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A21',
#      'manufacturerName': 'Karbonn',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609972,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E410g',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609973,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I9100T',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609974,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MS695',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609975,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '8720',
#      'manufacturerName': 'Coolpad',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609976,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'R809T',
#      'manufacturerName': 'OPPO',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609977,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'OT-4030D',
#      'manufacturerName': 'Alcatel',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609978,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'S9t',
#      'manufacturerName': 'Vivo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609979,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'F-04E',
#      'manufacturerName': 'DoCoMo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609980,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Iris 356',
#      'manufacturerName': 'Lava',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609981,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E615',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609982,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SCH-R530X',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609983,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-S730M',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609984,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-I8550L',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609985,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ONE TOUCH 6012X',
#      'manufacturerName': 'Alcatel',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609986,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5369',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609987,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A25',
#      'manufacturerName': 'Micromax',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609988,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SGH-I467',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609989,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '206SH',
#      'manufacturerName': 'Sharp',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609990,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-B5330L',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609991,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Desire 500',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609992,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SCH-I619',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609993,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'SHL21',
#      'manufacturerName': 'KDDI',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609994,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'KYY04',
#      'manufacturerName': 'Kyocera',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609995,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Iris 402',
#      'manufacturerName': 'Lava',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609996,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'LS860',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609997,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A8',
#      'manufacturerName': 'QMobile',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609998,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'OT-5035A',
#      'manufacturerName': 'Alcatel',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 609999,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A88',
#      'manufacturerName': 'Micromax',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610000,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'C6802',
#      'manufacturerName': 'Sony',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610001,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'GT-S5303',
#      'manufacturerName': 'Samsung',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610002,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Xplay',
#      'manufacturerName': 'Vivo',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610003,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'F160LV',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610004,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'L-05D',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610005,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'T619',
#      'manufacturerName': 'K-Touch',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610006,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'MZ617',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610007,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'F-01F',
#      'manufacturerName': 'Fujitsu',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610008,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'Fonepad 7',
#      'manufacturerName': 'Asus',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610009,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'IM-A870K',
#      'manufacturerName': 'Pantech',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610010,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'XT1053',
#      'manufacturerName': 'Motorola',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610011,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E410',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610012,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'ST21i',
#      'manufacturerName': 'Sony',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610013,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'U8651T',
#      'manufacturerName': 'T-Mobile',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610014,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'One VX',
#      'manufacturerName': 'HTC',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610015,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'OT-4007D',
#      'manufacturerName': 'Alcatel',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610016,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': '5890',
#      'manufacturerName': 'Coolpad',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610017,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'A1-811',
#      'manufacturerName': 'Acer',
#      'deviceType': 'DEVICE_TYPE_TABLET',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610018,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'E988',
#      'manufacturerName': 'LG',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, {
#      'id': 610019,
#      'type': None,
#      'Criterion.Type': 'MobileDevice',
#      'deviceName': 'One Touch 6033A',
#      'manufacturerName': 'Alcatel',
#      'deviceType': 'DEVICE_TYPE_MOBILE',
#      'operatingSystemName': 'Android'
#  }, ...]

# %%
adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
report_downloader = adwords_client.GetReportDownloader(version='v201809')

# %%
CUSTOMER_ID = 5922380045
adwords_client.SetClientCustomerId(CUSTOMER_ID)
CAMPAIGN_ID = 1896291336
CAMPAIGN_FIELDS = ['Device', 'ExternalCustomerId','CampaignId','AdvertisingChannelType', 'CampaignStatus',
                   'BiddingStrategyType','Amount','StartDate','EndDate','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion', 'Ctr']
# Create report definition.
report = {
    'reportName': 'CAMPAIGN_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
    'dateRangeType': 'ALL_TIME',
    'reportType': 'CAMPAIGN_PERFORMANCE_REPORT',
    'downloadFormat': 'CSV',
    'selector': {
        'fields': CAMPAIGN_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [{
            'field': 'CampaignId',
            'operator': 'EQUALS',
            'values':[CAMPAIGN_ID]
        }]
    }
}
csv = report_downloader.DownloadReportAsString(  
    report, skip_report_header=True, skip_column_header=True,   
    skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_ID)
csv_list = csv.split('\n')[:-1]
df = pd.DataFrame()
for lil_csv in csv_list:
    df_temp = pd.DataFrame(
        data=np.array(lil_csv.split(',')).reshape(1,len(CAMPAIGN_FIELDS)),
        columns=CAMPAIGN_FIELDS
    )
    df = df.append(df_temp)

# %%
df
# Out:
#                                           Device ExternalCustomerId  \
# 0                     Tablets with full browsers         5922380045
# 0                                      Computers         5922380045
# 0  Devices streaming video content to TV screens         5922380045
# 0              Mobile devices with full browsers         5922380045
#
#    CampaignId AdvertisingChannelType CampaignStatus BiddingStrategyType  \
# 0  1896291336                Display        enabled                 cpc
# 0  1896291336                Display        enabled                 cpc
# 0  1896291336                Display        enabled                 cpc
# 0  1896291336                Display        enabled                 cpc
#
#        Amount   StartDate     EndDate        Cost AverageCost Impressions  \
# 0  1000000000  2019-05-14  2019-05-28    38454525     6409088        6858
# 0  1000000000  2019-05-14  2019-05-28    39288999     5612714       10474
# 0  1000000000  2019-05-14  2019-05-28           0           0         212
# 0  1000000000  2019-05-14  2019-05-28  7998793592     6801695      844623
#
#   Clicks Conversions AverageCpc CostPerConversion    Ctr
# 0      6        0.00    6409088                 0  0.09%
# 0      7        0.00    5612714                 0  0.07%
# 0      0        0.00          0                 0  0.00%
# 0   1176        0.00    6801695                 0  0.14%
