# %%
import json
import requests
import time
import pytz
import datetime
import math
import random
import pandas as pd
from copy import deepcopy
from facebook_business.adobjects.adset import AdSet
from facebook_business.adobjects.targeting import Targeting
from facebook_business.adobjects.ad import Ad
from facebook_business.api import FacebookAdsApi

from bid_operator import revert_bid_amount
import mysql_adactivity_save
from facebook_datacollector import Campaigns
from facebook_datacollector import DatePreset
from facebook_adapter import FacebookCampaignAdapter
IS_DEBUG = False #debug mode will not modify anything


my_app_id = '958842090856883'
my_app_secret = 'a952f55afca38572cea2994d440d674b'
my_access_token = 'EAANoD9I4obMBALrHTgMWgRujnWcZA3ZB823phs6ynDDtQxnzIZASyRQZCHfr5soXBZA7NM9Dc4j9O8FtnlIzxiPCsYt4tmPQ6ZAT3yJLPuYQqjnWZBWX5dsOVzNhEqsHYj1jVJ3RAVVueW7RSxRDbNXKvK3W23dcAjNMjxIjQGIOgZDZD'
tim_access_token = 'EAANoD9I4obMBAPcoZA5V7OZBQaPa3Tk7NMAT0ZBZCepdD8zZBcwMZBMHAM1zPeQiRY4Yw07rscee4LMRn9lMsJGuNZAYBA4nCYdZA6tsyL0KGTfQKIAFls3T5jul9Am6t95nbvcGXFmcFDYEyZAX2FpAuVesVGyiHuLFRKxlXfh5t6AZDZD'
# 'EAANoD9I4obMBAHukuWuiyeNxAPGEojU982JmGHJP1MsdM03H3gY3EVQj5G3gzZCq7KECX0lOi87ZCGKZA5hy1INxZBhD6azH8oYHICQ1BhZAojC50zjgUa54f9R2VInhLGpHGXl6F1VWltmRK6LeF5kRkDvZC4lkZCzSU4II1gJ1NoC0SaiS6D6piSp2rUTqPXTtASZBRfy5tbscOhfXDSxyai7IAaeCFb5xRBH4QsRm8wZDZD'

FacebookAdsApi.init(my_app_id, my_app_secret, my_access_token)

DATABASE = 'dev_facebook_test'
DATE = datetime.datetime.now().date()
ACTION_BOUNDARY = 0.8
ACTION_DICT = {'bid': AdSet.Field.bid_amount,
               'age': AdSet.Field.targeting, 'interest': AdSet.Field.targeting}

BRANDING_CAMPAIGN_LIST = ['LINK_CLICKS', 'ALL_CLICKS','VIDEO_VIEWS', 'REACH', 'POST_ENGAGEMENT', 'PAGE_LIKES', 'LANDING_PAGE_VIEW']
PERFORMANCE_CAMPAIGN_LIST = ['CONVERSIONS', 'LEAD_GENERATION', 'ADD_TO_CART']

ADSET_COPY_COUNT = 3
ADSET_MIN_COUNT = 3

FIELDS = [
    AdSet.Field.id,
    AdSet.Field.account_id,
    AdSet.Field.adlabels,
    AdSet.Field.adset_schedule,
    AdSet.Field.attribution_spec,
    AdSet.Field.bid_amount,
    AdSet.Field.bid_info,
    AdSet.Field.bid_strategy,
    AdSet.Field.billing_event,
    AdSet.Field.budget_remaining,
    AdSet.Field.campaign_id,
    AdSet.Field.configured_status,
    AdSet.Field.created_time,
    AdSet.Field.creative_sequence,
    AdSet.Field.daily_budget,
    AdSet.Field.daily_min_spend_target,
    AdSet.Field.daily_spend_cap,
    AdSet.Field.destination_type,
    AdSet.Field.effective_status,
    AdSet.Field.end_time,
    AdSet.Field.frequency_control_specs,
    AdSet.Field.instagram_actor_id,
    AdSet.Field.is_dynamic_creative,
    AdSet.Field.issues_info,
    AdSet.Field.lifetime_budget,
    AdSet.Field.lifetime_imps,
    AdSet.Field.lifetime_min_spend_target,
    AdSet.Field.lifetime_spend_cap,
    AdSet.Field.name,
    AdSet.Field.optimization_goal,
    AdSet.Field.pacing_type,
    AdSet.Field.promoted_object,
    AdSet.Field.recommendations,
    AdSet.Field.recurring_budget_semantics,
    AdSet.Field.rf_prediction_id,
    AdSet.Field.start_time,
    AdSet.Field.status,
    AdSet.Field.targeting,
    AdSet.Field.time_based_ad_rotation_id_blocks,
    AdSet.Field.time_based_ad_rotation_intervals,
    AdSet.Field.updated_time,
    AdSet.Field.daily_min_spend_target,
    #     AdSet.Field.use_new_app_click
]




def copy_asset_new_target(new_adset_params, original_adset_id):
    new_adset_id = -1
    try:
        new_adset_id = make_adset(new_adset_params)
        print('[copy_adset] make_adset success, original_adset_id', original_adset_id, ' new_adset_id', new_adset_id)
        time.sleep(10)
        ad_id_list = get_ad_id_list(original_adset_id)
        for ad_id in ad_id_list:
            result_message = assign_copied_ad_to_new_adset(new_adset_id=new_adset_id, ad_id=ad_id)
            print('[copy_adset] result_message', result_message)
            
    except Exception as error:
        print('[copy_adset] this adset is not existed anymore, error:', error)

def make_suggest_adset(original_adset_id): 
    suggestion_id, suggestion_name = get_suggestion_target_by_asset(original_adset_id)
    if suggestion_id is None:
        print('[make_suggest_adset] error')
        return 
    
    print('[make_suggest_adset] pick this suggestion:',suggestion_id, suggestion_name)
    
    new_adset_params = retrieve_origin_adset_params(original_adset_id)
    print(new_adset_params)
    new_adset_params[AdSet.Field.name] = suggestion_name + "_Target_AI"

    interest_pair = {
            "interests":[{
                "id": suggestion_id,
                "name": suggestion_name,
            }]
        }
    new_adset_params[AdSet.Field.targeting]["flexible_spec"] = interest_pair

    print('[make_suggest_adset] new_adset_params',new_adset_params)
    original_adset_id = new_adset_params[AdSet.Field.id]
    new_adset_params[AdSet.Field.id] = None
    copy_asset_new_target(new_adset_params, original_adset_id)



def get_account_id_by_adset(adset_id):
    this_adsets = AdSet( adset_id ).remote_read(fields=["account_id"])
    account_id = this_adsets.get('account_id')
    return account_id

def get_suggestion_target_by_asset(adset_id):
    account_id = get_account_id_by_adset(adset_id)
    
    mydb = mysql_adactivity_save.connectDB(DATABASE)
    mycursor = mydb.cursor()
    ### select
    sql = "SELECT suggestion_id, suggestion_name   FROM account_target_suggestion WHERE account_id={}".format(account_id)
    mycursor.execute(sql)
    target_suggestions = mycursor.fetchall()
#     for suggestions in target_suggestions:
#         print(suggestions)

    mydb.commit()
    mydb.close()
    print('')
    if len(target_suggestions) > 0:
        pick_index = random.randint(0, len(target_suggestions)-1)
        print('[get_suggestion_target_by_asset] pick:',target_suggestions[pick_index])
        return target_suggestions[pick_index]
    else:
        return None,None
    

def get_ad_id_list(adset_id):
    ad_id_list = list()
    adset = AdSet(adset_id)
    ads = adset.get_ads(fields=[AdSet.Field.id])
    for ad in ads:
        ad_id_list.append(ad[Ad.Field.id])
    return ad_id_list


def retrieve_origin_adset_params(origin_adset_id):
    origin_adset = AdSet(fbid=origin_adset_id)
    origin_adset_params = origin_adset.remote_read(fields=FIELDS)
    return origin_adset_params


def assign_copied_ad_to_new_adset(new_adset_id=None, ad_id=None):
    url = "https://graph.facebook.com/v3.2/{}/copies".format(ad_id)
    querystring = {
        "adset_id": "{}".format(new_adset_id),
        "status_option": "INHERITED_FROM_SOURCE"}
    headers = {
        'Authorization': "Bearer {}".format(my_access_token), }
    response = requests.request(
        "POST", url, headers=headers, params=querystring)
    return response.text


def update_interest(adset_id=None, adset_params=None):
    adset = AdSet(adset_id)
    update_response = adset.update(adset_params)
    remote_update_response = adset.remote_update(
        params={'status': 'PAUSED', }
    )
    return


def update_status(adset_id, status=AdSet.Status.active):
    if IS_DEBUG:
        return 
    adset = AdSet(adset_id)
    adset[AdSet.Field.status] = status
    adset.remote_update()

def update_daily_min_spend_target(adset_id):
    if IS_DEBUG:
        return 
    adset = AdSet(adset_id)
    adset[AdSet.Field.status] = status
    adset.remote_update()

    
def get_sorted_adset(campaign):
    mydb = mysql_adactivity_save.connectDB(DATABASE)

    df = pd.read_sql( "select * from adset_score where campaign_id=%s" % (campaign), con=mydb)
    adset_list = []

    if len(df) > 0:
        df_today = df[df.request_time.dt.date == DATE].sort_values( by=['score'], ascending=False)
        print('[get_sorted_adset] df_today' , df_today )
        
        if len(df_today) > 0:
            adset_list = df_today['adset_id'].unique().tolist()
        else:
            print('[get_sorted_adset] Error, no adset score today')    
    else:  
        print('[get_sorted_adset] Error, no adset score')

    print('[get_sorted_adset]  adset_list:', adset_list)
    mydb.close()
    return adset_list


def split_adset_list(adset_list):
    import math
    adset_list.sort(reverse=True)
    half = math.ceil(len(adset_list) / 2)
    return adset_list[:ADSET_COPY_COUNT], adset_list[half:]


def is_contain_copy_string(adset_name):
    return ('Copy' in adset_name)

def is_contain_rt_string(adset_name):
    return ('RT_' in adset_name)

def check_init_bid(init_bid):
    if init_bid > 100:
        bid = math.ceil(init_bid*1.1)
        return bid
    else:
        bid = init_bid + 1
        return bid


def copy_adset(adset_id, actions, adset_params=None):
    
    new_adset_params = adset_params
    origin_adset_name = adset_params[AdSet.Field.name]
    new_adset_params[AdSet.Field.id] = None
    
    # Generate new adset name
    new_adset_name = ''
    index = origin_adset_name.find("Copy")
    if index > 0:
        new_adset_name = origin_adset_name[:index]  + '_' + str(datetime.datetime.now().date()) 
    else:
        new_adset_name = origin_adset_name + '_' + str(datetime.datetime.now().date())
    
    for i, action in enumerate(actions.keys()):
        if action == 'bid':
            new_adset_params[ACTION_DICT[action]] = math.ceil( revert_bid_amount(actions[action]) )  # for bid

        elif action == 'age':
            age_list = actions[action][0].split('-')
            new_adset_params[AdSet.Field.targeting]["age_min"] = int(
                age_list[:1][0])
            new_adset_params[AdSet.Field.targeting]["age_max"] = int(
                age_list[1:][0])
            new_adset_params[AdSet.Field.name] = new_adset_name

#         elif action == 'interest':
# #             if actions[action] is None:
# #                 new_adset_params[AdSet.Field.targeting]["flexible_spec"] = None
# #             else:
#             new_adset_params[AdSet.Field.targeting]["flexible_spec"] = {
#                     "interests": [actions[action]]}

    new_adset_id = -1
    try:
        new_adset_id = make_adset(new_adset_params)
        print('[copy_adset] make_adset success, adset_id', adset_id, ' new_adset_id', new_adset_id)
        time.sleep(10)
        ad_id_list = get_ad_id_list(adset_id)
        for ad_id in ad_id_list:
            result_message = assign_copied_ad_to_new_adset(new_adset_id=new_adset_id, ad_id=ad_id)
            print('[copy_adset] result_message', result_message)
            
    except Exception as error:
        print('[copy_adset] this adset is not existed anymore, error:', error)


def make_adset(adset_params):
    account_id = adset_params[AdSet.Field.account_id]
    new_adset = AdSet(parent_id='act_{}'.format(account_id))
    new_adset.update(adset_params)
    new_adset.remote_create(params={'status': 'ACTIVE', })
    return new_adset[AdSet.Field.id]

def modify_opt_result_db(campaign_id, is_optimized):
    #get date
    opt_date = datetime.datetime.now()
    #insert to table date and Ture for is_opt
    sql = "update campaign_target set is_optimized = '{}', optimized_date = '{}' where campaign_id = {}".format(is_optimized, opt_date, campaign_id)
    mydb = mysql_adactivity_save.connectDB(DATABASE)
    mycursor = mydb.cursor()
    mycursor.execute(sql)
    mydb.commit()
    mydb.close()

def handle_campaign_copy(campaign_id):
    
    print('[handle_campaign_copy] campaign ',campaign_id)
    df = mysql_adactivity_save.get_campaign_target(campaign_id)

    # charge_type attribute of first row
    charge_type = df['charge_type'].iloc[0]
    daily_charge = df['daily_charge'].iloc[0]
    campaign_daily_budget = df['daily_budget'].iloc[0]
    campaign_instance = Campaigns(campaign_id, charge_type)
    
    day_dict = campaign_instance.generate_campaign_info(date_preset=DatePreset.yesterday)
    lifetime_dict = campaign_instance.generate_campaign_info(date_preset=DatePreset.lifetime)
#     print('[handle_campaign_copy] day_dict ',day_dict)
#     print('[handle_campaign_copy] lifetime_dict ',lifetime_dict)
    lifetime_target = int( lifetime_dict['target'] )
    if lifetime_target > df['destination'].iloc[0]:
        modify_opt_result_db(campaign_id, False)
        return    
    
    is_performance_campaign = False
    is_split_age = False
    if charge_type in PERFORMANCE_CAMPAIGN_LIST:
        is_performance_campaign = True
        is_split_age = False
    elif charge_type in BRANDING_CAMPAIGN_LIST:
        is_performance_campaign = False
        is_split_age = True
    print('is_performance_campaign', is_performance_campaign)
    
    #compute achieving_rate
    target = 0 # get by insight
    if 'target' in day_dict:
        target = int(day_dict['target'])
    
    fb_adapter = FacebookCampaignAdapter(campaign_id)
    campaign_days_left = fb_adapter.campaign_days_left
    achieving_rate = target / daily_charge
    print('[achieving rate]', achieving_rate, ' target', target, ' daily_charge', daily_charge)
    
    is_adjust_bid = False
    if achieving_rate > ACTION_BOUNDARY and achieving_rate < 1:
        is_adjust_bid = False
    elif achieving_rate < ACTION_BOUNDARY:
        is_adjust_bid = True        
    else: # good enough, not to do anything
        print('[handle_campaign_copy] good enough, not to do anything')
        modify_opt_result_db(campaign_id , False)
        return
    print('[handle_campaign_copy] is_adjust_bid',is_adjust_bid)
    print('[handle_campaign_copy] is_performance_campaign',is_performance_campaign)

    # current going adset is less than ADSET_MIN_COUNT, not to close any adset
    adsets_active_list = campaign_instance.get_adsets_active()
    print('[handle_campaign_copy] adsets_active_list:', adsets_active_list)
    if len(adsets_active_list) <= ADSET_MIN_COUNT:
        if is_performance_campaign:
            print('[handle_campaign_copy] is_performance_campaign',is_performance_campaign)
            if len(adsets_active_list) > 0:
                #create one suggestion asset for CPA campaigin
                print('create one suggestion asset for CPA campaigin')        
                adset_id = adsets_active_list[0]
                make_suggest_adset(adset_id)
                return
        
    adset_list = get_sorted_adset(campaign_id)
    adset_action_list = []
    for adset in adset_list:
        if str(adset) in adsets_active_list:
            adset_action_list.append(adset)
    adset_for_copy_list, adset_for_off_list = split_adset_list(adset_action_list)
    # current going adset is less than ADSET_MIN_COUNT, not to close any adset
    if len(adsets_active_list) <= ADSET_MIN_COUNT:
        adset_for_off_list = []
    
    print('[handle_campaign_copy] adset_list',len(adset_list))
    print('[handle_campaign_copy] adset_action_list',len(adset_action_list))
    print('[handle_campaign_copy] adset_for_copy_list',len(adset_for_copy_list))
    print('[handle_campaign_copy] adset_for_off_list',len(adset_for_off_list))

    for adset_id in adset_for_off_list:
        origin_adset_params = retrieve_origin_adset_params(adset_id)
        origin_name = origin_adset_params[AdSet.Field.name]
        if not is_contain_rt_string(origin_name):
            update_status(adset_id, status=AdSet.Status.paused)
    
    # get ready to duplicate
    actions = {'bid': None, 'age': list(), 'interest': None}
    actions_list = list()
    
    # update bid for original existed adset
    if is_adjust_bid and not IS_DEBUG:
        mysql_adactivity_save.adjust_init_bid(campaign_id)
    
    #get adset bid for this campaign
    fb_adapter.retrieve_campaign_attribute()
    
    for adset_id in adset_for_copy_list:
        # bid adjust

        bid = fb_adapter.init_bid_dict.get(int(adset_id))
        #error handle: the adset did not have score
        if bid is None:
            print('[handle_campaign_copy] adset bid is None')
            break

        if is_adjust_bid:
            bid = check_init_bid(bid)

        actions.update({'bid': bid})
        origin_adset_params = retrieve_origin_adset_params(adset_id)
#         print('adset_id,  [origin_adset_params]',adset_id, origin_adset_params)
        origin_adset_params[AdSet.Field.id] = None
        origin_name = origin_adset_params[AdSet.Field.name]
        
        # optimize by daily_min_spend_target
        if 'daily_min_spend_target' in origin_adset_params:
            new_daily_min_spend_target = int( int(origin_adset_params[AdSet.Field.daily_min_spend_target]) * 1.1)
            actions.update({'daily_min_spend_target':  new_daily_min_spend_target })
        else:
            new_daily_min_spend_target = int(  campaign_daily_budget / len(adset_for_copy_list))
            actions.update({'daily_min_spend_target':  new_daily_min_spend_target })
        
        # interest decision
#         try:
#             origin_interest = origin_adset_params[AdSet.Field.targeting]["flexible_spec"][0]
#         except:
#             origin_interest = None
        # min max age
        adset_max = origin_adset_params[AdSet.Field.targeting]["age_max"]
        adset_min = origin_adset_params[AdSet.Field.targeting]["age_min"]

        try:
            actions['age'][0] = str(adset_min) + '-' + str(adset_max)
            actions.update({'interest': origin_interest['interests'][0]})
            
        except:
            actions['age'].append(str(adset_min) + '-' + str(adset_max))
            actions.update({'interest': None})
            
        # whether to split age or copy adset names with 'copy'
        if is_contain_copy_string(origin_name):
            # for CPA case or CPC with COPY string
            actions['age'] = list()
            actions['age'].append(str(adset_min) + '-' + str(adset_max))
            actions_copy = deepcopy(actions)
#             copy_adset(adset_id, actions_copy, origin_adset_params)
        else:
            # for CPC case without COPY string
            if is_split_age:
                interval = 2
                age_interval = math.ceil((adset_max-adset_min) / interval)
                for i in range(interval):
                    current_adset_min = adset_min
                    current_adset_max = current_adset_min + age_interval
                    actions['age'][0] = str(current_adset_min) + '-' + str(current_adset_max)
                    adset_min = current_adset_max
                    actions_copy = deepcopy(actions)
                    copy_adset(adset_id, actions_copy, origin_adset_params)
            else:
                actions_copy = deepcopy(actions)
                actions_list.append(actions_copy)
                copy_adset(adset_id, actions_copy, origin_adset_params)
                
    modify_opt_result_db(campaign_id, True)

# %%
if __name__ == '__main__':
    import index_collector_conversion_facebook
    current_time = datetime.datetime.now()
    print('[facebook_externals] current_time:', current_time)
    FacebookAdsApi.init(my_app_id, my_app_secret, my_access_token)
    df_not_opted = mysql_adactivity_save.get_campaigns_not_optimized()
    print('df_not_opted len:', len(df_not_opted))
    
    for campaign_id in df_not_opted.campaign_id.unique():
        handle_campaign_copy(campaign_id)
#     handle_campaign_copy(23843467729120098)
# Out:
# [facebook_externals] current_time: 2019-05-29 10:20:08.431027
# df_not_opted len: 21
# [handle_campaign_copy] campaign  23843319164090240
# is_performance_campaign True
# [achieving rate] 0.0  target 0  daily_charge 1.9697
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign True
# [get_adsets_active] adset_active_list: ['23843337793720240', '23843351208440240', '23843351208450240']
# [handle_campaign_copy] adsets_active_list: ['23843337793720240', '23843351208440240', '23843351208450240']
# [handle_campaign_copy] is_performance_campaign True
# create one suggestion asset for CPA campaigin
#
# [get_suggestion_target_by_asset] pick: (6002714895372, 'Frequent Travelers')
# [make_suggest_adset] pick this suggestion: 6002714895372 Frequent Travelers
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# <AdSet> {
#     "account_id": "388689501726787",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 6,
#     "bid_info": {
#         "ACTIONS": 6
#     },
#     "billing_event": "LINK_CLICKS",
#     "budget_remaining": "0",
#     "campaign_id": "23843319164090240",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-19T00:48:35+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-06-30T23:59:00+0800",
#     "id": "23843337793720240",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "BT_\u8cfc\u7269 Copy - ['26-39', '13-39', '13-39'] Copy - ['26-39'] Copy - ['13-65'] Copy - ['13-65']",
#     "optimization_goal": "LINK_CLICKS",
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-19T00:48:35+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 13,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003167425934",
#                         "name": "Shopping and fashion"
#                     },
#                     {
#                         "id": "6003346592981",
#                         "name": "Online shopping"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     },
#     "updated_time": "2019-05-24T03:36:27+0800"
# }
# [make_suggest_adset] new_adset_params <AdSet> {
#     "account_id": "388689501726787",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 6,
#     "bid_info": {
#         "ACTIONS": 6
#     },
#     "billing_event": "LINK_CLICKS",
#     "budget_remaining": "0",
#     "campaign_id": "23843319164090240",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-19T00:48:35+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-06-30T23:59:00+0800",
#     "id": "23843337793720240",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "Frequent Travelers_Target_AI",
#     "optimization_goal": "LINK_CLICKS",
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-19T00:48:35+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 65,
#         "age_min": 13,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": 6002714895372,
#                         "name": "Frequent Travelers"
#                     }
#                 ]
#             }
#         ],
#         "genders": [
#             2
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "instagram_positions": [
#             "stream",
#             "story"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ]
#     },
#     "updated_time": "2019-05-24T03:36:27+0800"
# }
# [copy_adset] this adset is not existed anymore, error:
#
#   Message: Call was not successful
#   Method:  POST
#   Path:    https://graph.facebook.com/v3.2/act_388689501726787/adsets
#   Params:  {'status': 'ACTIVE', 'account_id': '388689501726787', 'attribution_spec': '[{"event_type":"CLICK_THROUGH","window_days":1}]', 'bid_amount': 6, 'bid_info': '{"ACTIONS":6}', 'billing_event': 'LINK_CLICKS', 'budget_remaining': '0', 'campaign_id': '23843319164090240', 'configured_status': 'ACTIVE', 'created_time': '2019-05-19T00:48:35+0800', 'destination_type': 'UNDEFINED', 'effective_status': 'ACTIVE', 'end_time': '2019-06-30T23:59:00+0800', 'is_dynamic_creative': 'false', 'lifetime_imps': 0, 'name': 'Frequent Travelers_Target_AI', 'optimization_goal': 'LINK_CLICKS', 'recurring_budget_semantics': 'false', 'start_time': '2019-05-19T00:48:35+0800', 'targeting': '{"age_max":65,"age_min":13,"device_platforms":["mobile","desktop"],"facebook_positions":["feed"],"flexible_spec":[{"interests":[{"id":6002714895372,"name":"Frequent Travelers"}]}],"genders":[2],"geo_locations":{"countries":["TW"],"location_types":["home","recent"]},"instagram_positions":["stream","story"],"publisher_platforms":["facebook","instagram"]}', 'updated_time': '2019-05-24T03:36:27+0800'}
#
#   Status:  400
#   Response:
#     {
#       "error": {
#         "message": "Invalid parameter",
#         "type": "OAuthException",
#         "code": 100,
#         "error_subcode": 1487079,
#         "is_transient": false,
#         "error_user_title": "Invalid Targeting Spec",
#         "error_user_msg": "The specified targeting spec is not valid because: Invalid data for field flexible_spec. Invalid Targeting Spec: The specified targeting spec is not valid because: Invalid data for field interests. Invalid Targeting Spec: The specified targeting spec is not valid because: Interests with id 6002714895372 is invalid.",
#         "fbtrace_id": "EeBDMkMpO43"
#       }
#     }
#
# [handle_campaign_copy] campaign  23843358370700576
# [facebook_datacollector.Campaigns.get_campaign_insights] 'VIDEO_VIEW'
# [facebook_datacollector.Campaigns.get_campaign_insights] 'VIDEO_VIEW'
# is_performance_campaign False
# [achieving rate] 0.0  target 0  daily_charge 12784.1
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign False
# [get_adsets_active] adset_active_list: ['23843387830450576', '23843387831250576', '23843387831960576']
# [handle_campaign_copy] adsets_active_list: ['23843387830450576', '23843387831250576', '23843387831960576']
# [get_sorted_adset] df_today            campaign_id           adset_id     score request_time
# 284  23843358370700576  23843387830450576 -0.892715   2019-05-29
# 285  23843358370700576  23843387831250576 -0.892715   2019-05-29
# 286  23843358370700576  23843387831960576 -0.892715   2019-05-29
# [get_sorted_adset]  adset_list: [23843387830450576, 23843387831250576, 23843387831960576]
# [handle_campaign_copy] adset_list 3
# [handle_campaign_copy] adset_action_list 3
# [handle_campaign_copy] adset_for_copy_list 3
# [handle_campaign_copy] adset_for_off_list 0
# [handle_campaign_copy] campaign  23843546765400616
# is_performance_campaign False
# [achieving rate] 2.9444690626676304  target 101  daily_charge 34.3016
# [handle_campaign_copy] good enough, not to do anything
# [handle_campaign_copy] campaign  23843419701490612
# is_performance_campaign False
# [achieving rate] 0.3929273084479371  target 200  daily_charge 509.0
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign False
# [get_adsets_active] adset_active_list: ['23843437765540612', '23843441734200612', '23843452684940612']
# [handle_campaign_copy] adsets_active_list: ['23843437765540612', '23843441734200612', '23843452684940612']
# [get_sorted_adset] df_today            campaign_id           adset_id    score request_time
# 341  23843419701490612  23843437765540612 -9.55758   2019-05-29
# 342  23843419701490612  23843441734200612 -9.55758   2019-05-29
# 343  23843419701490612  23843452684940612 -9.55758   2019-05-29
# [get_sorted_adset]  adset_list: [23843437765540612, 23843441734200612, 23843452684940612]
# [handle_campaign_copy] adset_list 3
# [handle_campaign_copy] adset_action_list 3
# [handle_campaign_copy] adset_for_copy_list 3
# [handle_campaign_copy] adset_for_off_list 0
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843452684940612  new_adset_id 23843455523520612
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] result_message {"copied_ad_id":"23843455523710612"}
# [copy_adset] make_adset success, adset_id 23843452684940612  new_adset_id 23843455523810612
# [copy_adset] result_message {"copied_ad_id":"23843455524120612"}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843441734200612  new_adset_id 23843455524240612
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] result_message {"copied_ad_id":"23843455524520612"}
# [copy_adset] make_adset success, adset_id 23843441734200612  new_adset_id 23843455524620612
# [copy_adset] result_message {"copied_ad_id":"23843455525070612"}
# [handle_campaign_copy] campaign  23843318864630344
# is_performance_campaign True
# [achieving rate] 0.0  target 0  daily_charge 6.66667
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign True
# [get_adsets_active] adset_active_list: ['23843327978730344', '23843328005390344', '23843328017360344']
# [handle_campaign_copy] adsets_active_list: ['23843327978730344', '23843328005390344', '23843328017360344']
# [handle_campaign_copy] is_performance_campaign True
# create one suggestion asset for CPA campaigin
#
# [get_suggestion_target_by_asset] pick: (6002991736368, 'Reading')
# [make_suggest_adset] pick this suggestion: 6002991736368 Reading
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# <AdSet> {
#     "account_id": "1591607854267453",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 7
#         },
#         {
#             "event_type": "VIEW_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 349,
#     "bid_info": {
#         "ACTIONS": 349
#     },
#     "billing_event": "IMPRESSIONS",
#     "budget_remaining": "0",
#     "campaign_id": "23843318864630344",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-22T01:36:39+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-06-30T23:59:00+0800",
#     "id": "23843327978730344",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "BT_25-50_\u96fb\u5f71\u76f8\u95dc - \u8907\u672c Copy - ['18-54'] Copy - ['18-54']",
#     "optimization_goal": "OFFSITE_CONVERSIONS",
#     "promoted_object": {
#         "custom_event_type": "LEAD",
#         "pixel_id": "2034997316734801"
#     },
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-22T01:36:39+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 54,
#         "age_min": 18,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003139266461",
#                         "name": "Movies"
#                     },
#                     {
#                         "id": "6003287318856",
#                         "name": "HBO"
#                     },
#                     {
#                         "id": "6003378723965",
#                         "name": "Netflix"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ]
#     },
#     "updated_time": "2019-05-29T10:16:59+0800"
# }
# [make_suggest_adset] new_adset_params <AdSet> {
#     "account_id": "1591607854267453",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 7
#         },
#         {
#             "event_type": "VIEW_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 349,
#     "bid_info": {
#         "ACTIONS": 349
#     },
#     "billing_event": "IMPRESSIONS",
#     "budget_remaining": "0",
#     "campaign_id": "23843318864630344",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-22T01:36:39+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-06-30T23:59:00+0800",
#     "id": "23843327978730344",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "Reading_Target_AI",
#     "optimization_goal": "OFFSITE_CONVERSIONS",
#     "promoted_object": {
#         "custom_event_type": "LEAD",
#         "pixel_id": "2034997316734801"
#     },
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-22T01:36:39+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 54,
#         "age_min": 18,
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": 6002991736368,
#                         "name": "Reading"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ]
#     },
#     "updated_time": "2019-05-29T10:16:59+0800"
# }
# [copy_adset] make_adset success, original_adset_id 23843327978730344  new_adset_id 23843344177410344
# [copy_adset] result_message {"copied_ad_id":"23843344177690344"}
# [copy_adset] result_message {"copied_ad_id":"23843344177900344"}
# [copy_adset] result_message {"copied_ad_id":"23843344178060344"}
# [copy_adset] result_message {"copied_ad_id":"23843344178260344"}
# [copy_adset] result_message {"copied_ad_id":"23843344178460344"}
# [copy_adset] result_message {"copied_ad_id":"23843344178690344"}
# [copy_adset] result_message {"copied_ad_id":"23843344178820344"}
# [copy_adset] result_message {"copied_ad_id":"23843344178950344"}
# [copy_adset] result_message {"copied_ad_id":"23843344179120344"}
# [copy_adset] result_message {"copied_ad_id":"23843344179260344"}
# [copy_adset] result_message {"copied_ad_id":"23843344179440344"}
# [copy_adset] result_message {"copied_ad_id":"23843344179600344"}
# [copy_adset] result_message {"copied_ad_id":"23843344179810344"}
# [copy_adset] result_message {"copied_ad_id":"23843344179970344"}
# [copy_adset] result_message {"copied_ad_id":"23843344180150344"}
# [copy_adset] result_message {"copied_ad_id":"23843344180540344"}
# [copy_adset] result_message {"copied_ad_id":"23843344180790344"}
# [copy_adset] result_message {"copied_ad_id":"23843344180970344"}
# [copy_adset] result_message {"copied_ad_id":"23843344181180344"}
# [copy_adset] result_message {"copied_ad_id":"23843344181340344"}
# [copy_adset] result_message {"copied_ad_id":"23843344181490344"}
# [copy_adset] result_message {"copied_ad_id":"23843344181700344"}
# [copy_adset] result_message {"copied_ad_id":"23843344182130344"}
# [copy_adset] result_message {"copied_ad_id":"23843344182420344"}
# [copy_adset] result_message {"copied_ad_id":"23843344183010344"}
# [copy_adset] result_message {"copied_ad_id":"23843344183620344"}
# [copy_adset] result_message {"copied_ad_id":"23843344183820344"}
# [copy_adset] result_message {"copied_ad_id":"23843344184010344"}
# [copy_adset] result_message {"copied_ad_id":"23843344184230344"}
# [copy_adset] result_message {"copied_ad_id":"23843344184650344"}
# [copy_adset] result_message {"copied_ad_id":"23843344184890344"}
# [copy_adset] result_message {"copied_ad_id":"23843344185610344"}
# [copy_adset] result_message {"copied_ad_id":"23843344185870344"}
# [copy_adset] result_message {"copied_ad_id":"23843344186090344"}
# [copy_adset] result_message {"copied_ad_id":"23843344186300344"}
# [copy_adset] result_message {"copied_ad_id":"23843344186520344"}
# [copy_adset] result_message {"copied_ad_id":"23843344186690344"}
# [copy_adset] result_message {"copied_ad_id":"23843344186870344"}
# [copy_adset] result_message {"copied_ad_id":"23843344187050344"}
# [copy_adset] result_message {"copied_ad_id":"23843344187240344"}
# [copy_adset] result_message {"copied_ad_id":"23843344187430344"}
# [copy_adset] result_message {"copied_ad_id":"23843344187570344"}
# [copy_adset] result_message {"copied_ad_id":"23843344187800344"}
# [copy_adset] result_message {"copied_ad_id":"23843344188070344"}
# [copy_adset] result_message {"copied_ad_id":"23843344188210344"}
# [copy_adset] result_message {"copied_ad_id":"23843344188620344"}
# [copy_adset] result_message {"copied_ad_id":"23843344188770344"}
# [copy_adset] result_message {"copied_ad_id":"23843344188930344"}
# [handle_campaign_copy] campaign  23843368265910246
# is_performance_campaign True
# [achieving rate] 3.0  target 3  daily_charge 1.0
# [handle_campaign_copy] good enough, not to do anything
# [handle_campaign_copy] campaign  23843384204790368
# is_performance_campaign True
# [achieving rate] 0.0  target 0  daily_charge 4.0
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign True
# [get_adsets_active] adset_active_list: ['23843496293800368', '23843496304340368', '23843499841140368', '23843501397270368']
# [handle_campaign_copy] adsets_active_list: ['23843496293800368', '23843496304340368', '23843499841140368', '23843501397270368']
# [get_sorted_adset] df_today           campaign_id           adset_id  score request_time
# 69  23843384204790368  23843496293800368  -10.0   2019-05-29
# 70  23843384204790368  23843496304340368  -10.0   2019-05-29
# 71  23843384204790368  23843499841140368  -10.0   2019-05-29
# 72  23843384204790368  23843501397270368  -10.0   2019-05-29
# [get_sorted_adset]  adset_list: [23843496293800368, 23843496304340368, 23843499841140368, 23843501397270368]
# [handle_campaign_copy] adset_list 4
# [handle_campaign_copy] adset_action_list 4
# [handle_campaign_copy] adset_for_copy_list 3
# [handle_campaign_copy] adset_for_off_list 2
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843501397270368  new_adset_id 23843510068560368
# [copy_adset] result_message {"copied_ad_id":"23843510068980368"}
# [copy_adset] result_message {"copied_ad_id":"23843510069200368"}
# [copy_adset] result_message {"copied_ad_id":"23843510069410368"}
# [copy_adset] result_message {"copied_ad_id":"23843510069700368"}
# [copy_adset] result_message {"copied_ad_id":"23843510069940368"}
# [copy_adset] result_message {"copied_ad_id":"23843510070170368"}
# [copy_adset] result_message {"copied_ad_id":"23843510070360368"}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843499841140368  new_adset_id 23843510070470368
# [copy_adset] result_message {"copied_ad_id":"23843510070730368"}
# [copy_adset] result_message {"copied_ad_id":"23843510070900368"}
# [copy_adset] result_message {"copied_ad_id":"23843510071080368"}
# [copy_adset] result_message {"copied_ad_id":"23843510071270368"}
# [copy_adset] result_message {"copied_ad_id":"23843510071500368"}
# [copy_adset] result_message {"copied_ad_id":"23843510071680368"}
# [copy_adset] result_message {"copied_ad_id":"23843510071850368"}
# [copy_adset] result_message {"copied_ad_id":"23843510072080368"}
# [copy_adset] result_message {"copied_ad_id":"23843510072260368"}
# [copy_adset] result_message {"copied_ad_id":"23843510072520368"}
# [handle_campaign_copy] campaign  23843421520340559
# is_performance_campaign False
# [achieving rate] 6.546656469825004  target 553  daily_charge 84.4706
# [handle_campaign_copy] good enough, not to do anything
# [handle_campaign_copy] campaign  23843421509230559
# is_performance_campaign False
# [achieving rate] 6.832663250939808  target 1883  daily_charge 275.588
# [handle_campaign_copy] good enough, not to do anything
# [handle_campaign_copy] campaign  23843421529610559
# is_performance_campaign False
# [achieving rate] 21.0000223404493  target 658  daily_charge 31.3333
# [handle_campaign_copy] good enough, not to do anything
# [handle_campaign_copy] campaign  23843443352120127
# is_performance_campaign False
# [achieving rate] 0.7625  target 61  daily_charge 80.0
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign False
# [get_adsets_active] adset_active_list: ['23843443352620127', '23843446538440127', '23843446539610127', '23843446542320127', '23843457614820127', '23843459443060127', '23843459443620127']
# [handle_campaign_copy] adsets_active_list: ['23843443352620127', '23843446538440127', '23843446539610127', '23843446542320127', '23843457614820127', '23843459443060127', '23843459443620127']
# [get_sorted_adset] df_today           campaign_id           adset_id    score request_time
# 20  23843443352120127  23843443352620127 -9.64917   2019-05-29
# 21  23843443352120127  23843446538440127 -9.64917   2019-05-29
# 22  23843443352120127  23843446539610127 -9.64917   2019-05-29
# 23  23843443352120127  23843446542320127 -9.64917   2019-05-29
# 24  23843443352120127  23843457614820127 -9.64917   2019-05-29
# 25  23843443352120127  23843459443060127 -9.64917   2019-05-29
# 26  23843443352120127  23843459443620127 -9.64917   2019-05-29
# [get_sorted_adset]  adset_list: [23843443352620127, 23843446538440127, 23843446539610127, 23843446542320127, 23843457614820127, 23843459443060127, 23843459443620127]
# [handle_campaign_copy] adset_list 7
# [handle_campaign_copy] adset_action_list 7
# [handle_campaign_copy] adset_for_copy_list 3
# [handle_campaign_copy] adset_for_off_list 3
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843459443620127  new_adset_id 23843461827240127
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"HvhkIn4oT5I"}}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] result_message {"copied_ad_id":"23843461827660127"}
# [copy_adset] make_adset success, adset_id 23843459443620127  new_adset_id 23843461827770127
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"BpOQTk6TyEf"}}
# [copy_adset] result_message {"copied_ad_id":"23843461828300127"}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843459443060127  new_adset_id 23843461828430127
# [copy_adset] result_message {"copied_ad_id":"23843461829100127"}
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"GZ4JE0gaLtg"}}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] result_message {"copied_ad_id":"23843461829340127"}
# [copy_adset] make_adset success, adset_id 23843459443060127  new_adset_id 23843461829490127
# [copy_adset] result_message {"copied_ad_id":"23843461830020127"}
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"DWa8gokwUe5"}}
# [copy_adset] result_message {"copied_ad_id":"23843461830170127"}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] make_adset success, adset_id 23843457614820127  new_adset_id 23843461830290127
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"CSF7NrGyn+6"}}
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"Fi\/9rmyn2S\/"}}
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# [copy_adset] result_message {"copied_ad_id":"23843461830790127"}
# [copy_adset] make_adset success, adset_id 23843457614820127  new_adset_id 23843461830900127
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"DcsvR\/6e6F2"}}
# [copy_adset] result_message {"error":{"message":"Invalid parameter","type":"OAuthException","code":100,"error_subcode":1885996,"is_transient":false,"error_user_title":"Page Like Creative Type Deprecated","error_user_msg":"This creative type has been deprecated. For Page Like Ads, please create creatives using object story spec and specify 'Like Page' Call to Action.","fbtrace_id":"GT4tzxoMF32"}}
# [copy_adset] result_message {"copied_ad_id":"23843461831530127"}
# [handle_campaign_copy] campaign  23843445760160232
# is_performance_campaign True
# [achieving rate] 0.620689441141572  target 6  daily_charge 9.66667
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign True
# [get_adsets_active] adset_active_list: ['23843445760310232', '23843445760340232', '23843445760350232']
# [handle_campaign_copy] adsets_active_list: ['23843445760310232', '23843445760340232', '23843445760350232']
# [handle_campaign_copy] is_performance_campaign True
# create one suggestion asset for CPA campaigin
#
# [get_suggestion_target_by_asset] pick: (6003162946655, 'Language')
# [make_suggest_adset] pick this suggestion: 6003162946655 Language
# WARNING:root:parent_id as a parameter of constructor is being deprecated.
# <AdSet> {
#     "account_id": "176147159719912",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 839,
#     "bid_info": {
#         "ACTIONS": 839
#     },
#     "billing_event": "IMPRESSIONS",
#     "budget_remaining": "0",
#     "campaign_id": "23843445760160232",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-20T17:56:18+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-05-31T23:59:00+0800",
#     "id": "23843445760310232",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "BT_22-40_\u8f49\u8077_FB",
#     "optimization_goal": "LEAD_GENERATION",
#     "promoted_object": {
#         "page_id": "152797601448925"
#     },
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-22T00:00:28+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 40,
#         "age_min": 22,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23843072923500232",
#                 "name": "xt_181203_\u83dc\u9ce5\u6551\u661f_\u7522\u5b78\u5408\u4f5c"
#             }
#         ],
#         "excluded_geo_locations": {
#             "cities": [
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "key": "2345308",
#                     "name": "Hualien City",
#                     "radius": 40,
#                     "region_id": "3752"
#                 },
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "key": "2347574",
#                     "name": "Miaoli",
#                     "radius": 40,
#                     "region": "Miaoli",
#                     "region_id": "4987"
#                 },
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "key": "2347871",
#                     "name": "Nantou",
#                     "radius": 17,
#                     "region": "Nantou",
#                     "region_id": "4988"
#                 }
#             ],
#             "custom_locations": [
#                 {
#                     "address_string": "\u53f0\u6771\u5927\u5824, \u81fa\u6771\u5e02, Kaohsiung, \u53f0\u7063",
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "latitude": 22.77179,
#                     "longitude": 121.15551,
#                     "name": "\u53f0\u6771\u5927\u5824, \u81fa\u6771\u5e02, Kaohsiung, \u53f0\u7063",
#                     "primary_city_id": 2350711,
#                     "radius": 16,
#                     "region_id": 3750
#                 },
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "latitude": 23.446869,
#                     "longitude": 119.619141,
#                     "primary_city_id": 2347360,
#                     "radius": 27,
#                     "region_id": 4118
#                 }
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "facebook_positions": [
#             "feed"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": "6003127217324",
#                         "name": "Job interview"
#                     },
#                     {
#                         "id": "6003204859412",
#                         "name": "1111\u4eba\u529b\u9280\u884c"
#                     },
#                     {
#                         "id": "6003293548979",
#                         "name": "Cover letter"
#                     },
#                     {
#                         "id": "6004037215009",
#                         "name": "Job hunting"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ]
#     },
#     "updated_time": "2019-05-29T10:30:10+0800"
# }
# [make_suggest_adset] new_adset_params <AdSet> {
#     "account_id": "176147159719912",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 839,
#     "bid_info": {
#         "ACTIONS": 839
#     },
#     "billing_event": "IMPRESSIONS",
#     "budget_remaining": "0",
#     "campaign_id": "23843445760160232",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-20T17:56:18+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-05-31T23:59:00+0800",
#     "id": "23843445760310232",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "Language_Target_AI",
#     "optimization_goal": "LEAD_GENERATION",
#     "promoted_object": {
#         "page_id": "152797601448925"
#     },
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-22T00:00:28+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 40,
#         "age_min": 22,
#         "device_platforms": [
#             "mobile"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23843072923500232",
#                 "name": "xt_181203_\u83dc\u9ce5\u6551\u661f_\u7522\u5b78\u5408\u4f5c"
#             }
#         ],
#         "excluded_geo_locations": {
#             "cities": [
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "key": "2345308",
#                     "name": "Hualien City",
#                     "radius": 40,
#                     "region_id": "3752"
#                 },
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "key": "2347574",
#                     "name": "Miaoli",
#                     "radius": 40,
#                     "region": "Miaoli",
#                     "region_id": "4987"
#                 },
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "key": "2347871",
#                     "name": "Nantou",
#                     "radius": 17,
#                     "region": "Nantou",
#                     "region_id": "4988"
#                 }
#             ],
#             "custom_locations": [
#                 {
#                     "address_string": "\u53f0\u6771\u5927\u5824, \u81fa\u6771\u5e02, Kaohsiung, \u53f0\u7063",
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "latitude": 22.77179,
#                     "longitude": 121.15551,
#                     "name": "\u53f0\u6771\u5927\u5824, \u81fa\u6771\u5e02, Kaohsiung, \u53f0\u7063",
#                     "primary_city_id": 2350711,
#                     "radius": 16,
#                     "region_id": 3750
#                 },
#                 {
#                     "country": "TW",
#                     "distance_unit": "kilometer",
#                     "latitude": 23.446869,
#                     "longitude": 119.619141,
#                     "primary_city_id": 2347360,
#                     "radius": 27,
#                     "region_id": 4118
#                 }
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "facebook_positions": [
#             "feed"
#         ],
#         "flexible_spec": [
#             {
#                 "interests": [
#                     {
#                         "id": 6003162946655,
#                         "name": "Language"
#                     }
#                 ]
#             }
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home",
#                 "recent"
#             ]
#         },
#         "publisher_platforms": [
#             "facebook"
#         ]
#     },
#     "updated_time": "2019-05-29T10:30:10+0800"
# }
# [copy_adset] make_adset success, original_adset_id 23843445760310232  new_adset_id 23843465116240232
# [copy_adset] result_message {"copied_ad_id":"23843465116770232"}
# [copy_adset] result_message {"copied_ad_id":"23843465116990232"}
# [copy_adset] result_message {"copied_ad_id":"23843465117220232"}
# [copy_adset] result_message {"copied_ad_id":"23843465117680232"}
# [handle_campaign_copy] campaign  23843346060540647
# is_performance_campaign True
# [achieving rate] 0.0  target 0  daily_charge 55.4286
# [handle_campaign_copy] is_adjust_bid True
# [handle_campaign_copy] is_performance_campaign True
# [get_adsets_active] adset_active_list: ['23843346099470647', '23843346104340647']
# [handle_campaign_copy] adsets_active_list: ['23843346099470647', '23843346104340647']
# [handle_campaign_copy] is_performance_campaign True
# create one suggestion asset for CPA campaigin
#
# [get_suggestion_target_by_asset] pick: (6003242966413, 'Fashion blog')
# [make_suggest_adset] pick this suggestion: 6003242966413 Fashion blog
# <AdSet> {
#     "account_id": "171560460354321",
#     "attribution_spec": [
#         {
#             "event_type": "CLICK_THROUGH",
#             "window_days": 1
#         }
#     ],
#     "bid_amount": 200,
#     "bid_info": {
#         "ACTIONS": 200
#     },
#     "billing_event": "IMPRESSIONS",
#     "budget_remaining": "0",
#     "campaign_id": "23843346060540647",
#     "configured_status": "ACTIVE",
#     "created_time": "2019-05-21T12:17:52+0800",
#     "destination_type": "UNDEFINED",
#     "effective_status": "ACTIVE",
#     "end_time": "2019-06-20T23:59:00+0800",
#     "id": "23843346099470647",
#     "is_dynamic_creative": false,
#     "lifetime_imps": 0,
#     "name": "BT_CONV_LL3%",
#     "optimization_goal": "OFFSITE_CONVERSIONS",
#     "promoted_object": {
#         "custom_event_type": "ADD_TO_CART",
#         "pixel_id": "2063636910516817"
#     },
#     "recurring_budget_semantics": false,
#     "start_time": "2019-05-22T09:00:22+0800",
#     "status": "ACTIVE",
#     "targeting": {
#         "age_max": 50,
#         "age_min": 25,
#         "custom_audiences": [
#             {
#                 "id": "23843007692850647",
#                 "name": "\u985e\u4f3c\u5ee3\u544a\u53d7\u773e (TW, 3%) - \u8cfc\u8cb7_90\u5929(CLAP\u7684\u50cf\u7d20)"
#             }
#         ],
#         "device_platforms": [
#             "mobile",
#             "desktop"
#         ],
#         "excluded_custom_audiences": [
#             {
#                 "id": "23842861514610647",
#                 "name": "XT - \u8cfc\u8cb7_7\u5929_\u820a\u50cf\u7d20"
#             }
#         ],
#         "facebook_positions": [
#             "feed"
#         ],
#         "geo_locations": {
#             "countries": [
#                 "TW"
#             ],
#             "location_types": [
#                 "home"
#             ]
#         },
#         "instagram_positions": [
#             "stream"
#         ],
#         "publisher_platforms": [
#             "facebook",
#             "instagram"
#         ],
#         "targeting_optimization": "none"
#     },
#     "updated_time": "2019-05-24T18:14:56+0800"
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-1e4f77b3edce> in <module>
#       8
#       9     for campaign_id in df_not_opted.campaign_id.unique():
# ---> 10         handle_campaign_copy(campaign_id)
#      11 #     handle_campaign_copy(23843467729120098)
#
# <ipython-input-1-e8008fd90019> in handle_campaign_copy(campaign_id)
#     382                 print('create one suggestion asset for CPA campaigin')
#     383                 adset_id = adsets_active_list[0]
# --> 384                 make_suggest_adset(adset_id)
#     385                 return
#     386
#
# <ipython-input-1-e8008fd90019> in make_suggest_adset(original_adset_id)
#     115     print(new_adset_params)
#     116     new_adset_params[AdSet.Field.name] = suggestion_name + "_Target_AI"
# --> 117     new_adset_params[AdSet.Field.targeting]["flexible_spec"]
#     118
#     119     interest_pair = {
#
# ~/.local/lib/python3.6/site-packages/facebook_business/adobjects/abstractobject.py in __getitem__(self, key)
#      46
#      47     def __getitem__(self, key):
# ---> 48         return self._data[str(key)]
#      49
#      50     def __setitem__(self, key, value):
#
# KeyError: 'flexible_spec'
