# %%
from pathlib import Path
import datetime
import time

from facebook_business.api import FacebookAdsApi
# from facebook_business.adobjects.adaccount import AdAccount
import facebook_business.adobjects.adset as facebook_business_adset
# from facebook_business.adobjects.ad import Ad
import facebook_business.adobjects.campaign as facebook_business_campaign
# from facebook_business.adobjects.adcreative import AdCreative
# from facebook_business.adobjects.adactivity import AdActivity
# from facebook_business.adobjects.insightsresult import InsightsResult
import facebook_business.adobjects.adsinsights as facebook_business_adsinsights

import facebook_datacollector as fb_collector
import mysql_adactivity_save as mysql_saver
import database_controller
import adgeek_permission as permission
# my_app_id = '958842090856883'
# my_app_secret = 'a952f55afca38572cea2994d440d674b'
# my_access_token = 'EAANoD9I4obMBACygIE9jqmlaWeOW6tBma0oS6JbRpLgAvOYXpVi2XcXuasuwbBgqmaZBj5cP8MHE5WY2l9tAoi549eGZCP61mKr9BA8rZA6kxEW4ovX3KlbbrRGgt4RZC8MAi1UG0l0ZBUd0UBAhIPhzkZBi46ncuyCwkYPB7a6voVBZBTbEZAwH3azZA3Ph6g7aCOfxZCdDOp4AZDZD'


class DatePreset:
    today = 'today'
    
ADSET_QUERY_FIELD = [  facebook_business_adset.AdSet.Field.id 
                     , facebook_business_adset.AdSet.Field.optimization_goal
                     , facebook_business_adset.AdSet.Field.bid_amount               
                     , facebook_business_adset.AdSet.Field.status ]


ADSET_INSIGHT_QUERY_FIELD = {
    'impressions': facebook_business_adsinsights.AdsInsights.Field.impressions,
    'spend': facebook_business_adsinsights.AdsInsights.Field.spend,
    'clicks': facebook_business_adsinsights.AdsInsights.Field.clicks,
}

class Adset_Log_Handler(object):
    database_connector = mysql_saver.connectDB(mysql_saver.DATABASE)
    table_name = 'adset_status_log'
    
    def __init__(self, campaign_id, adset_id, optimization_goal, bid_amount, status):
        self.campaign_id = campaign_id
        self.adset_id = adset_id
        self.optimization_goal = optimization_goal
        self.bid_amount = bid_amount
        self.status = status
        
        self.clicks = 0
        self.impressions = 0
        self.spend = 0
        
    def __str__(self):
        return str(self.__dict__)
    
    def set_insight(self):
        self.log_date = datetime.datetime.now().strftime("%Y-%m-%d")
        self.log_datetime = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        
        this_adsets = facebook_business_adset.AdSet( self.adset_id )
        insights = this_adsets.get_insights(
            params = {'date_preset': DatePreset.today },
            fields = ADSET_INSIGHT_QUERY_FIELD
        )

        if len(insights) == 1:
            this_adset_insight = insights[0]
#             print(this_adset_insight)
            self.clicks = this_adset_insight.get( facebook_business_adsinsights.AdsInsights.Field.clicks )
            self.impressions = this_adset_insight.get( facebook_business_adsinsights.AdsInsights.Field.impressions)
            self.spend = this_adset_insight.get( facebook_business_adsinsights.AdsInsights.Field.spend)
    
    def save_into_database(self):
        cols = ', '.join(self.__dict__.keys())
        vals = self.__dict__.values()
        placeholders = ', '.join(['%s'] * len(self.__dict__))
    
        stmt = "insert into `{table}` ({columns}) values ({values});".format(table = self.table_name, columns = cols , values = placeholders)
        
        mycursor = self.database_connector.cursor()
        mycursor.execute(stmt, list( vals) )
        self.database_connector.commit()
    
    def read_data(self):
        sql = "SELECT  HOUR(TIMEDIFF( max(log_datetime), min(log_datetime))) as hour_diff, (max(spend)-min(spend)) as spend_diff  FROM {} WHERE adset_id={} and log_date='{}' and status='ACTIVE' ".format(self.table_name, self.adset_id, self.log_date)
        
        print(sql)
        mycursor = self.database_connector.cursor()
        mycursor.execute(sql)
        hour_diff, spend_diff = mycursor.fetchone()
        print('result',hour_diff, spend_diff )
        
        
        
        
        
            
def get_adset_handler_by_campaign(campaign_id):
    camp = facebook_business_campaign.Campaign( campaign_id)
    adsets = camp.get_ad_sets(fields = ADSET_QUERY_FIELD)
    adset_handler_list = []
    
    for adset in adsets:
        adset_id = adset.get(facebook_business_adset.AdSet.Field.id)
        optimization_goal = adset.get(facebook_business_adset.AdSet.Field.optimization_goal)
        bid_amount = adset.get(facebook_business_adset.AdSet.Field.bid_amount)
        status = adset.get(facebook_business_adset.AdSet.Field.status)
        
        adset_handler = Adset_Log_Handler(campaign_id, adset_id, optimization_goal, bid_amount, status)
        adset_handler_list.append(adset_handler)
    return adset_handler_list
        

def process_campaign(campaign_id):
    adset_handler_list = get_adset_handler_by_campaign(campaign_id)
    print('campaign_id:', campaign_id, ' len(adset_handler_list):', len(adset_handler_list))
    
    for adset_handler in adset_handler_list:
        adset_handler.set_insight()
        adset_handler.save_into_database()
#         adset_handler.read_data()        

    
def main():
    campaign_list = database_fb.get_running_campaign().to_dict('records')

    for campaign in campaign_list:
        account_id = campaign.get("account_id")
        campaign_id = campaign.get("campaign_id")
        permission.init_facebook_api(account_id)
        
        start_time = time.time()
        process_campaign(campaign_id)
        print('campaign_id:', campaign_id, ' spend seconds:', time.time() - start_time)

    
if __name__ == "__main__":
    start_time = time.time()
    global database_fb
    db = database_controller.Database()
    database_fb = database_controller.FB(db)
    main()

#     process_campaign(23843368265910246)

    print('total campaign spend seconds:', time.time() - start_time)
    Adset_Log_Handler.database_connector.close()
# Out:
# [get_token_by_accountid] account_id: 350498128813378
# first_data {'id': 1261, 'media': 'facebook', 'account_id': '350498128813378', 'name': 'Acer', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# [get_token_by_accountid] account_id: 516689492098932
# first_data {'id': 1249, 'media': 'facebook', 'account_id': '516689492098932', 'name': '私藏生活', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843467729120098  len(adset_handler_list): 44
# campaign_id: 23843467729120098  spend seconds: 14.828712463378906
# [get_token_by_accountid] account_id: 357788201437629
# first_data {'id': 1191, 'media': 'facebook', 'account_id': '357788201437629', 'name': 'GoGym 高勁健身', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843384204790368  len(adset_handler_list): 42
# campaign_id: 23843384204790368  spend seconds: 15.093287944793701
# [get_token_by_accountid] account_id: 1637394533022118
# first_data {'id': 1330, 'media': 'facebook', 'account_id': '1637394533022118', 'name': '消費高手_v2', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843484377040702  len(adset_handler_list): 19
# campaign_id: 23843484377040702  spend seconds: 6.254844903945923
# [get_token_by_accountid] account_id: 236093456987127
# first_data {'id': 1269, 'media': 'facebook', 'account_id': '236093456987127', 'name': 'tutorJr_新付款_180620', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843240188270516  len(adset_handler_list): 39
# campaign_id: 23843240188270516  spend seconds: 13.588838815689087
# [get_token_by_accountid] account_id: 335445053816049
# first_data {'id': 1745, 'media': 'facebook', 'account_id': '335445053816049', 'name': '蜂主義_森美', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843584924490768  len(adset_handler_list): 7
# campaign_id: 23843584924490768  spend seconds: 2.506073236465454
# [get_token_by_accountid] account_id: 469186777161582
# first_data {'id': 1743, 'media': 'facebook', 'account_id': '469186777161582', 'name': '傅康貴牙醫師', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843568997400374  len(adset_handler_list): 13
# campaign_id: 23843568997400374  spend seconds: 4.963221549987793
# [get_token_by_accountid] account_id: 269384303655858
# first_data {'id': 1240, 'media': 'facebook', 'account_id': '269384303655858', 'name': 'Ipresenttime 選禮時刻', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843481678350339  len(adset_handler_list): 22
# campaign_id: 23843481678350339  spend seconds: 7.808881521224976
# [get_token_by_accountid] account_id: 267083990698486
# first_data {'id': 1275, 'media': 'facebook', 'account_id': '267083990698486', 'name': '渣打_新付款_180606', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843098840440451  len(adset_handler_list): 16
# campaign_id: 23843098840440451  spend seconds: 6.109848737716675
# [get_token_by_accountid] account_id: 1602483736513198
# first_data {'id': 1335, 'media': 'facebook', 'account_id': '1602483736513198', 'name': '全聯_傳藝中心', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843447337770036  len(adset_handler_list): 20
# campaign_id: 23843447337770036  spend seconds: 7.4775214195251465
# [get_token_by_accountid] account_id: 601240550286778
# first_data {'id': 1164, 'media': 'facebook', 'account_id': '601240550286778', 'name': '國研院', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843672578810681  len(adset_handler_list): 7
# campaign_id: 23843672578810681  spend seconds: 2.53941011428833
# [get_token_by_accountid] account_id: 350498128813378
# first_data {'id': 1261, 'media': 'facebook', 'account_id': '350498128813378', 'name': 'Acer', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843537403310559  len(adset_handler_list): 8
# campaign_id: 23843537403310559  spend seconds: 2.971914768218994
# [get_token_by_accountid] account_id: 1591607854267453
# first_data {'id': 1341, 'media': 'facebook', 'account_id': '1591607854267453', 'name': 'MyVideo', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843473390820344  len(adset_handler_list): 8
# campaign_id: 23843473390820344  spend seconds: 3.7828919887542725
# [get_token_by_accountid] account_id: 350498128813378
# first_data {'id': 1261, 'media': 'facebook', 'account_id': '350498128813378', 'name': 'Acer', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843569311660559  len(adset_handler_list): 13
# campaign_id: 23843569311660559  spend seconds: 4.943140506744385
# [get_token_by_accountid] account_id: 2413350875562221
# first_data {'id': 2112, 'media': 'facebook', 'account_id': '2413350875562221', 'name': 'PHANTACi潮牌服飾', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843623065480355  len(adset_handler_list): 6
# campaign_id: 23843623065480355  spend seconds: 2.6173813343048096
# [get_token_by_accountid] account_id: 1529888140439425
# first_data {'id': 1360, 'media': 'facebook', 'account_id': '1529888140439425', 'name': 'Footer', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843592731740022  len(adset_handler_list): 6
# campaign_id: 23843592731740022  spend seconds: 3.010077714920044
# [get_token_by_accountid] account_id: 1529888140439425
# first_data {'id': 1360, 'media': 'facebook', 'account_id': '1529888140439425', 'name': 'Footer', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843592741150022  len(adset_handler_list): 6
# campaign_id: 23843592741150022  spend seconds: 2.463242769241333
# [get_token_by_accountid] account_id: 1703359043092333
# first_data {'id': 1319, 'media': 'facebook', 'account_id': '1703359043092333', 'name': '葡萄王_新付款_180625', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843457813880014  len(adset_handler_list): 29
# campaign_id: 23843457813880014  spend seconds: 10.643023490905762
# [get_token_by_accountid] account_id: 176147159719912
# first_data {'id': 1268, 'media': 'facebook', 'account_id': '176147159719912', 'name': 'Lccnet_180620', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843636617110232  len(adset_handler_list): 9
# campaign_id: 23843636617110232  spend seconds: 3.0442256927490234
# [get_token_by_accountid] account_id: 248533002503165
# first_data {'id': 1216, 'media': 'facebook', 'account_id': '248533002503165', 'name': '克蘭詩', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843596602350235  len(adset_handler_list): 3
# campaign_id: 23843596602350235  spend seconds: 1.2656867504119873
# [get_token_by_accountid] account_id: 636530750058744
# first_data {'id': 1243, 'media': 'facebook', 'account_id': '636530750058744', 'name': 'Miss Fashion', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843468131980091  len(adset_handler_list): 9
# campaign_id: 23843468131980091  spend seconds: 3.7247555255889893
# [get_token_by_accountid] account_id: 344075086467387
# first_data {'id': 1671, 'media': 'facebook', 'account_id': '344075086467387', 'name': 'MamiBuy媽咪拜', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843503273320350  len(adset_handler_list): 4
# campaign_id: 23843503273320350  spend seconds: 1.9871351718902588
# [get_token_by_accountid] account_id: 149785629221845
# first_data {'id': 1267, 'media': 'facebook', 'account_id': '149785629221845', 'name': 'TutorABC_新付款_180620', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843350824920010  len(adset_handler_list): 25
# campaign_id: 23843350824920010  spend seconds: 9.258955955505371
# [get_token_by_accountid] account_id: 10155657593726278
# first_data {'id': 1775, 'media': 'facebook', 'account_id': '10155657593726278', 'name': 'Shutterstock - Image - Asia (no DCM)', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23842880697850266  len(adset_handler_list): 21
# campaign_id: 23842880697850266  spend seconds: 8.946461915969849
# [get_token_by_accountid] account_id: 341659359840575
# first_data {'id': 1790, 'media': 'facebook', 'account_id': '341659359840575', 'name': 'Quaplar葵柏兒', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843646477870386  len(adset_handler_list): 7
# campaign_id: 23843646477870386  spend seconds: 2.644178867340088
# [get_token_by_accountid] account_id: 619617821814575
# first_data {'id': 1173, 'media': 'facebook', 'account_id': '619617821814575', 'name': 'Befit', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843318062740647  len(adset_handler_list): 11
# campaign_id: 23843318062740647  spend seconds: 4.695544958114624
# [get_token_by_accountid] account_id: 1118613661658466
# first_data {'id': 1939, 'media': 'facebook', 'account_id': '1118613661658466', 'name': 'KYC織創', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843671808580702  len(adset_handler_list): 5
# campaign_id: 23843671808580702  spend seconds: 2.1098763942718506
# [get_token_by_accountid] account_id: 1118613661658466
# first_data {'id': 1939, 'media': 'facebook', 'account_id': '1118613661658466', 'name': 'KYC織創', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843668618370702  len(adset_handler_list): 5
# campaign_id: 23843668618370702  spend seconds: 2.2911882400512695
# [get_token_by_accountid] account_id: 1232446390249419
# first_data {'id': 1972, 'media': 'facebook', 'account_id': '1232446390249419', 'name': 'Sisley', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843664635530316  len(adset_handler_list): 8
# campaign_id: 23843664635530316  spend seconds: 2.792383909225464
# [get_token_by_accountid] account_id: 1232446390249419
# first_data {'id': 1972, 'media': 'facebook', 'account_id': '1232446390249419', 'name': 'Sisley', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843664506230316  len(adset_handler_list): 8
# campaign_id: 23843664506230316  spend seconds: 2.947582721710205
# [get_token_by_accountid] account_id: 2151296625115262
# first_data {'id': 1278, 'media': 'facebook', 'account_id': '2151296625115262', 'name': '[actived]-資生堂_新付款_180606', 'credential_id': 35, 'services': 'mpc,bb'}
# [get_token_by_accountid] query_id: 35
# [get_media_token_by_queryid] credential_id: 958842090856883  credential_secret a952f55afca38572cea2994d440d674b  credential_token EAANoD9I4obMBAI8tcZCcpYhKMXKMyijNvOgMZA4I2BDRoVZAxPVAcYZAZBrZBwZAnb0Y2xvgSEG4OqtxVuD9dwMP8b9xB75PQsUlzvTe7m8RSnZCxvDzQ4InV4wBk7d1zMTJ56uTPkF3kuPc6qi0jE5GlpUl6SUZBXXYO0uAGmzN3eQZDZD
# campaign_id: 23843508739720127  len(adset_handler_list): 31
# campaign_id: 23843508739720127  spend seconds: 14.418486595153809
# total campaign spend seconds: 173.05963516235352
