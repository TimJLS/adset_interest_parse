# %%
import adgeek_permission as permission
import facebook_business.adobjects.campaign as facebook_business_campaign
import facebook_business.adobjects.adaccount as facebook_business_adaccount
import facebook_business.adobjects.ad as facebook_business_ad
import facebook_business.adobjects.adcreative as facebook_business_adCreative
import facebook_business.adobjects.pagepost as facebook_business_pagepost

# %%
account_id = 413727509469044
campaign_id = 23843497693370005
permission.init_facebook_api(account_id)

def get_ads_by_campaign(campaign_id):
    this_campaign = facebook_business_campaign.Campaign(campaign_id)
    this_campaign_ads = this_campaign.get_ads()
    ad_id_list = []
    for this_ad in this_campaign_ads:
        ad_id = int(this_ad.get('id'))
        ad_id_list.append(ad_id)
    return ad_id_list
# Out:
# [get_media_token_by_queryid] token_dic {'credential_id': '958842090856883', 'credential_secret': 'a952f55afca38572cea2994d440d674b', 'credential_token': 'EAANoD9I4obMBAINquIFv6AFKwuBmZAv9SQCpE5NGjNR1dBoGTfu8FqfUIzcbAJneZCNE9thdjA8s8tZAe6G0f5axGTnCK4oKKgvK5b0z1uwE2Nk6kUiYBqiT9k55beC0lMZAZBPHnjUz7qtqyTSa4dHihy2wZCaiA1DQuaYeD20gZDZD', 'credential_developer_token': '', 'credential_refresh_token': '', 'name': 'Ant Man-facebook-168027233986113'}

# %%
ad_id_list = get_ads_by_campaign(campaign_id)
ad_id_list
# Out:
# [23843591305520005,
#  23843591305480005,
#  23843591305510005,
#  23843591305490005,
#  23843591305470005,
#  23843591305460005,
#  23843560733250005,
#  23843560733240005,
#  23843560733380005,
#  23843560733200005,
#  23843560733260005,
#  23843560733270005,
#  23843560733220005,
#  23843560733210005,
#  23843560733280005,
#  23843560709220005,
#  23843560709200005,
#  23843560709150005,
#  23843560709330005,
#  23843560709140005,
#  23843560709130005,
#  23843560709120005,
#  23843560709100005,
#  23843560709190005,
#  23843560709110005,
#  23843560733190005,
#  23843559788730005,
#  23843559788670005,
#  23843559788830005,
#  23843559788820005,
#  23843559788810005,
#  23843559788760005,
#  23843559788740005,
#  23843559788840005,
#  23843559788780005,
#  23843559788690005,
#  23843559788710005,
#  23843559788750005,
#  23843559788680005,
#  23843559788850005,
#  23843559788770005,
#  23843559788800005,
#  23843559788720005,
#  23843559788700005,
#  23843559788660005,
#  23843559788790005,
#  23843542311270005,
#  23843542311290005,
#  23843529616330005,
#  23843529616340005,
#  23843500954750005,
#  23843500955800005,
#  23843500956620005,
#  23843500956630005,
#  23843500955960005,
#  23843500955950005,
#  23843500956170005,
#  23843500952830005,
#  23843500956190005,
#  23843500952810005,
#  23843500954760005,
#  23843498558510005,
#  23843498549990005,
#  23843500955820005,
#  23843498538400005,
#  23843498524850005]

# %%
def get_creative_by_ad(ad_id):
    this_ad = facebook_business_ad.Ad(ad_id)
    this_creatives = this_ad.get_ad_creatives()
    creative_id_list = []
    for this_creative in this_creatives:
        creative_id = int(this_creative.get('id'))
        creative_id_list.append(creative_id)
    return creative_id_list

# %%
ad_id = 23843708427040451
creative_id_list = get_creative_by_ad(ad_id)
creative_id_list
# Out:
# [23843708446390451]

# %%
def get_post_by_creative(creative_id):
    this_creative = facebook_business_adCreative.AdCreative(creative_id)
    this_object_story_id = this_creative.api_get(fields=['object_story_id','call_to_action_type', 'body'])
    object_story_id = this_object_story_id.get('object_story_id')
    call_to_action_type = this_object_story_id.get('call_to_action_type')
    post_body = this_object_story_id.get('body')
    return object_story_id, call_to_action_type, post_body

# %%
creative_id = 23843708446390451
post_id = get_post_by_creative(creative_id)

# %%
def get_call_to_action_link_by_post(post_id):
    try:
        this_post = facebook_business_pagepost.PagePost(post_id)
        this_post_info = this_post.api_get(fields=['call_to_action'])
        call_to_action = this_post_info.get('call_to_action')
        if call_to_action:
            call_to_action_value = call_to_action.get('value')
            if call_to_action_value:
                call_to_action_link = call_to_action_value.get('link')
                if call_to_action_link:
                    return call_to_action_link
    except  Exception as e:
        print('[get_call_to_action_link_by_post] error', e)
        return None

# %%
post_id = '820612794778213_1252928054880016'
call_to_action_link = get_call_to_action_link_by_post(post_id)
call_to_action_link
# Out:
# 'https://ad.doubleclick.net/ddm/trackclk/N200801.3030407ADGEEKDBM/B11287272.255206388;dc_trk_aid=451118677;dc_trk_cid=121256134;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;tfua='

# %%
##test total campaign
import csv

account_id = 2404065389867866
permission.init_facebook_api(account_id)

#get account's all campaigns , campaign_id_list
this_account = facebook_business_adaccount.AdAccount('act_' + str(account_id))
this_campaigns = this_account.get_campaigns()
campaign_id_list = []
for this_campaign in this_campaigns:
    campaign_id_list.append(int(this_campaign.get('id')))
    


with open('account_creative_' + str(account_id) + '.csv', 'w', newline='\n') as csvfile:
    writer = csv.writer(csvfile, delimiter='|')

    for campaign_id in campaign_id_list:
        
        #process one campaign    
        call_to_action_link_set = set()
        post_id_set = set()

        ad_id_list = get_ads_by_campaign(campaign_id)
        for ad_id in ad_id_list:
            print('ad_id:',ad_id)
            creative_id_list = get_creative_by_ad(ad_id)
            for creative_id in creative_id_list:
                post_id, call_to_action_type, post_body = get_post_by_creative(creative_id)


                call_to_action_link = get_call_to_action_link_by_post(post_id)
                if call_to_action_link and len(call_to_action_link) > 0:
                    print('creative_id:',creative_id)
                    print('post_id:',post_id)
                    print('call_to_action_type:',call_to_action_type)
                    print('post_body:',post_body)
                    print('call_to_action_link:', call_to_action_link)
                    call_to_action_link_set.add(call_to_action_link)

                    if post_id not in post_id_set:
                        post_id_set.add(post_id)
                        post_body = post_body.replace('\n',' ')
                        writer.writerow([campaign_id, creative_id, post_id, call_to_action_type, call_to_action_link, post_body])

            print('--')
# Out:
# [get_media_token_by_queryid] token_dic {'credential_id': '958842090856883', 'credential_secret': 'a952f55afca38572cea2994d440d674b', 'credential_token': 'EAANoD9I4obMBAINquIFv6AFKwuBmZAv9SQCpE5NGjNR1dBoGTfu8FqfUIzcbAJneZCNE9thdjA8s8tZAe6G0f5axGTnCK4oKKgvK5b0z1uwE2Nk6kUiYBqiT9k55beC0lMZAZBPHnjUz7qtqyTSa4dHihy2wZCaiA1DQuaYeD20gZDZD', 'credential_developer_token': '', 'credential_refresh_token': '', 'name': 'Ant Man-facebook-168027233986113'}
# ad_id: 23843905397150439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AKQ303IWBj0D-cpDkBDVVsO"
#       }
#     }
#
# --
# ad_id: 23843906177580439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AwUXwjPvWLdldvtoIhyBIWx"
#       }
#     }
#
# --
# ad_id: 23843906177550439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AR3T1xFbYfXbBbnR3ibhjCE"
#       }
#     }
#
# --
# ad_id: 23843906177600439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AKCzlRe2O28oOKdiTFfbz9A"
#       }
#     }
#
# --
# ad_id: 23843906177590439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AtPOubTSiIn-7BTGSvj7O19"
#       }
#     }
#
# --
# ad_id: 23843906177560439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A-vkDuF6uCcTWuARHpbRVnZ"
#       }
#     }
#
# --
# ad_id: 23843905400740439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AcRIEFf2jv7qiAQNOo3fe11"
#       }
#     }
#
# --
# ad_id: 23843905400720439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A2MkX8mLHKVS7qry9rwh2Zp"
#       }
#     }
#
# --
# ad_id: 23843905400770439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AJRRuUY4lZfqHhKHqZGgf-G"
#       }
#     }
#
# --
# ad_id: 23843905400750439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A5k9DAdWoAnm_kkxTi2jO7Q"
#       }
#     }
#
# --
# ad_id: 23843905400730439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AJ5kL_-yntY1fzYcVPD4gTg"
#       }
#     }
#
# --
# ad_id: 23843905376410439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AQMRzyOayT7x8rQkHENzLBf"
#       }
#     }
#
# --
# ad_id: 23843905376390439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A_pjODCz_WsdOC2F9ib2MCu"
#       }
#     }
#
# --
# ad_id: 23843905397120439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ABAfrqY6uBdBnoCA7pKlHNn"
#       }
#     }
#
# --
# ad_id: 23843905397130439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARhzqmpCzmUEYQTYuTTqLUV"
#       }
#     }
#
# --
# ad_id: 23843905397140439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A0TCYLSN8gOGZYk3LPxrbL0"
#       }
#     }
#
# --
# ad_id: 23843905397160439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AKqTqYwZKuU8td2NZpdgAFs"
#       }
#     }
#
# --
# ad_id: 23843905343170439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Aksjo0lYXjFXK8OQYl9bEGp"
#       }
#     }
#
# --
# ad_id: 23843905376430439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AdM3J1XyTiIP4-UGIEWw0A_"
#       }
#     }
#
# --
# ad_id: 23843905376440439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AUCjkDq3cgB6sIxYJDd7Uew"
#       }
#     }
#
# --
# ad_id: 23843905376400439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A2bQ6lcdQbxk-gOgWmyCab9"
#       }
#     }
#
# --
# ad_id: 23843905343210439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AjhEN8Ck9LrAx-4172E1_d2"
#       }
#     }
#
# --
# ad_id: 23843905343190439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AQGb-fD8PfDSXKd9NK7FSkh"
#       }
#     }
#
# --
# ad_id: 23843905343200439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A7wtwrqvdoF4qNUn0eDHmNA"
#       }
#     }
#
# --
# ad_id: 23843905343180439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AOpRII0L3demD2cTSjXpWJs"
#       }
#     }
#
# --
# ad_id: 23844033748160439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AhNezvUBcx8pkIEg9efdOXF"
#       }
#     }
#
# --
# ad_id: 23844033748010439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Al6thAWh-Rs7fIxFJY6c9qi"
#       }
#     }
#
# --
# ad_id: 23844033747880439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A0WRChM-1Qcdt8X38exi6U_"
#       }
#     }
#
# --
# ad_id: 23844033747820439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AUlhGtYZoCu87YkCDtn_tYm"
#       }
#     }
#
# --
# ad_id: 23844033747830439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AbVm33WghbUrByHPtAiIm7c"
#       }
#     }
#
# --
# ad_id: 23844033747810439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A1WQfl9ZDttdODCimJQP89V"
#       }
#     }
#
# --
# ad_id: 23844033747980439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AHwmDWY6u28d3ja1k00l3YA"
#       }
#     }
#
# --
# ad_id: 23844033747780439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ArTWdKkH1ZtFRGR4c-7suLI"
#       }
#     }
#
# --
# ad_id: 23844033747960439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ArmVOnnR4F2O9EizK1GgPGh"
#       }
#     }
#
# --
# ad_id: 23844033747800439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AVwuXO0TMhpeLr2Ik2OiG4V"
#       }
#     }
#
# --
# ad_id: 23844033748070439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AlbHxetQU880vFBdRDMWQa4"
#       }
#     }
#
# --
# ad_id: 23844033747970439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AD80OHJOl2rpNonrb7Ax8pW"
#       }
#     }
#
# --
# ad_id: 23844033748030439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AohS8Xr8tn2wPGvgefKI21Q"
#       }
#     }
#
# --
# ad_id: 23844033748000439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AVP-DyfNISYpPAY9jpheChZ"
#       }
#     }
#
# --
# ad_id: 23844033747940439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ANYMwLkOEtbsAURqUFlkVTH"
#       }
#     }
#
# --
# ad_id: 23844033747840439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AUSh7WC7VKjjLzkmf-Ls-CH"
#       }
#     }
#
# --
# ad_id: 23844033748170439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AfXs4mIlqGuT6F6lo6cWseb"
#       }
#     }
#
# --
# ad_id: 23844033747790439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARKyEWyYb9Tqeg4_AVu8Ggn"
#       }
#     }
#
# --
# ad_id: 23844033748040439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Axvdja-oXLyC-Bvzfw2njEQ"
#       }
#     }
#
# --
# ad_id: 23844033747990439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ApdacTX2Q8v9MVoe605TJqF"
#       }
#     }
#
# --
# ad_id: 23843773529620439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Arb0pBgRbMos2KFXW0oLWZC"
#       }
#     }
#
# --
# ad_id: 23843977296940439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Ak6bftzYz_PEcSvpvlqmMb6"
#       }
#     }
#
# --
# ad_id: 23843777565810439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AuN0YCREKOdNDhQ3i3gbs5d"
#       }
#     }
#
# --
# ad_id: 23843808100100439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Ae1Wu_W4bG6CPuKdXhpWXPM"
#       }
#     }
#
# --
# ad_id: 23843808100070439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AWlBSbH_CKfUckLqigvip-j"
#       }
#     }
#
# --
# ad_id: 23843903267100439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Asgxvv7eb8WJMY8MhX5xZoR"
#       }
#     }
#
# --
# ad_id: 23843903267120439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A0HaBEKgsxfEVWW4vYuizEa"
#       }
#     }
#
# --
# ad_id: 23843977285410439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A4FhLois4-kEoJ37B5a5o_R"
#       }
#     }
#
# --
# ad_id: 23844026606580439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AtCZwtwvX1H46n1jtQGqxJS"
#       }
#     }
#
# --
# ad_id: 23844026606620439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AabqgGngHsJ6zuPLXxkDmWn"
#       }
#     }
#
# --
# ad_id: 23844026606610439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A_lhoQlQ2-YCpMXQMRVKZKh"
#       }
#     }
#
# --
# ad_id: 23844026606600439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A15KdVvye1MwRTt71FS9QPf"
#       }
#     }
#
# --
# ad_id: 23844026606640439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AE9YII7PYH4S8m54LSleV2a"
#       }
#     }
#
# --
# ad_id: 23844026606660439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Auh4qWfcI11It36ZZXPQMNJ"
#       }
#     }
#
# --
# ad_id: 23844026606590439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AwafwKUHKUbQtoj6Y5H-X6P"
#       }
#     }
#
# --
# ad_id: 23844026606650439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AMApTj1cPJEOqutoj1DChBh"
#       }
#     }
#
# --
# ad_id: 23843977296800439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ANpaQiDdKonL_gB0zcBWsCS"
#       }
#     }
#
# --
# ad_id: 23843977288750439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AmoBWB8SKdio4Pnp_3Txh_H"
#       }
#     }
#
# --
# ad_id: 23843773529610439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AombJcO5fQvlFeNMb-uHgJj"
#       }
#     }
#
# --
# ad_id: 23843977288840439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AkGT5T__OhfaH79Qr0AGNb1"
#       }
#     }
#
# --
# ad_id: 23843977288700439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AGVC4oYPb_SnRma88r0f09Q"
#       }
#     }
#
# --
# ad_id: 23843766429700439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AfXxlZePkUfM1AUvxGE5Wbw"
#       }
#     }
#
# --
# ad_id: 23843766429670439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ABjK94GmaoUQ_pIrSeC6q-d"
#       }
#     }
#
# --
# ad_id: 23843750000650439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ApkLie3xexyVZQ8f5VZnUUa"
#       }
#     }
#
# --
# ad_id: 23843745005940439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AgmXRFsWLDKoM5ZDC1z2tAj"
#       }
#     }
#
# --
# ad_id: 23843729433660439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Ag8QbuiKhJSBHbUIkzfm4yH"
#       }
#     }
#
# --
# ad_id: 23843977296780439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AUrRHmBRzX-Q58PC3vOwmx2"
#       }
#     }
#
# --
# ad_id: 23843713502670439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A9VnboBL8ayaUj9WKMMpmSi"
#       }
#     }
#
# --
# ad_id: 23843745005960439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AwVwt4vOnGYfYy5hQID5L85"
#       }
#     }
#
# --
# ad_id: 23843729377170439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Amq0d08MBfAPZNStNa9_-dC"
#       }
#     }
#
# --
# ad_id: 23843808096160439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AWVyKHZKmwJvoanCgTzu8iJ"
#       }
#     }
#
# --
# ad_id: 23843729377220439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AfDsgAmen2OKZnIG5urNj-E"
#       }
#     }
#
# --
# ad_id: 23843750000610439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Ax4CpX0bh1UHNll-VJOulhH"
#       }
#     }
#
# --
# ad_id: 23843931653570439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ASkOAx6rKFaIGJGrm2mRVIf"
#       }
#     }
#
# --
# ad_id: 23843808096180439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AITgmyPKxsqPd7eDuU3cVZl"
#       }
#     }
#
# --
# ad_id: 23843729433630439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARaGrKcgG3hGxW90kD8w9aY"
#       }
#     }
#
# --
# ad_id: 23843931653580439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AsJkGuWpdtzG5v4HNEBDWzt"
#       }
#     }
#
# --
# ad_id: 23843766429650439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AHKzY4CJ44XkirUl253x-TQ"
#       }
#     }
#
# --
# ad_id: 23843977288770439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Au9ugsJBwkVKkRZefzZDDTm"
#       }
#     }
#
# --
# ad_id: 23843933821730439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AYdNTMzZDQWqQVewrGiGAgE"
#       }
#     }
#
# --
# ad_id: 23843773529650439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AbtbHSc5toi11ybbhXFdSiY"
#       }
#     }
#
# --
# ad_id: 23843931653590439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AYzUtvqWG70HLj9doGmqR5W"
#       }
#     }
#
# --
# ad_id: 23843977296890439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A7XKDiGhSYofiGaLflbvLXj"
#       }
#     }
#
# --
# ad_id: 23843903267080439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Atvc2bO6n2SvNsOL97EiW1s"
#       }
#     }
#
# --
# ad_id: 23843773529640439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AuB-00pkEpj-SlM9r62k8Rf"
#       }
#     }
#
# --
# ad_id: 23843773529660439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AMlYmViG3xXyB8YeGTCSZ9o"
#       }
#     }
#
# --
# ad_id: 23843933821950439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ASYGNKkiV-2BooH_ujHIZbF"
#       }
#     }
#
# --
# ad_id: 23843903267130439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARr6qmcgEoeNEDbFc870KPW"
#       }
#     }
#
# --
# ad_id: 23843903267090439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AkLZ54iEi69THy7N-N4iujy"
#       }
#     }
#
# --
# ad_id: 23843933821670439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Acv_f2WcsBe076xIkkObgr9"
#       }
#     }
#
# --
# ad_id: 23843977296770439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A_53uX4STFJE3gov3fdfGoM"
#       }
#     }
#
# --
# ad_id: 23843977288800439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AeSD7zIbClPno_taVgTYsiu"
#       }
#     }
#
# --
# ad_id: 23843745005950439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A0GA_x9RtsZNEXUyVB9Z2oM"
#       }
#     }
#
# --
# ad_id: 23843745005930439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AyFbV2ZK-RvbNj8TNPsBiU_"
#       }
#     }
#
# --
# ad_id: 23843766429660439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARG8MLTA8eAEMkBealJVXXg"
#       }
#     }
#
# --
# ad_id: 23843745005920439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AoUDZVtlQLeyPbjJBXXZIVm"
#       }
#     }
#
# --
# ad_id: 23843777565860439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A4Yw6LO8vhSqXPH4QoILR5v"
#       }
#     }
#
# --
# ad_id: 23843933821870439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AOKJpyFo3m9vjuHg3OmqHR9"
#       }
#     }
#
# --
# ad_id: 23843777565840439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
# ...
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARXfCy8LuuUrsxhneNhXvMF"
#       }
#     }
#
# --
# ad_id: 23843933838820439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AzjQnqDSu4hOsZraeQ2NWaF"
#       }
#     }
#
# --
# ad_id: 23843789651490439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A--mTf6KFrDoN1_N1Ne_1UL"
#       }
#     }
#
# --
# ad_id: 23843789651470439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AZ9zjVB5laKlKsvks-tGHa6"
#       }
#     }
#
# --
# ad_id: 23843789651440439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARZB_hCFU0R7akqx9uh165q"
#       }
#     }
#
# --
# ad_id: 23843696391260439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARXBlWgqwFaObcXTEc3345L"
#       }
#     }
#
# --
# ad_id: 23843933838580439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AeZ6Vjsw4_2I9EHWN9aJysu"
#       }
#     }
#
# --
# ad_id: 23843791973110439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AQ_C57LMtJa1i_eidh31b5h"
#       }
#     }
#
# --
# ad_id: 23843791973080439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A6jrTtlQJ9_PDjA6oGWevOM"
#       }
#     }
#
# --
# ad_id: 23843933838550439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AphkZsR6p9IhNn3HcRlj_5y"
#       }
#     }
#
# --
# ad_id: 23843791973100439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AXdLRM7rB2-GKEtR56pFZSu"
#       }
#     }
#
# --
# ad_id: 23843903106100439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AbpNjTycGaZDLdOFqq3VMga"
#       }
#     }
#
# --
# ad_id: 23843729359100439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Am2wXoYN5bhqLUEp7rFmPjP"
#       }
#     }
#
# --
# ad_id: 23843977305590439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AqqeLb7XLuYK-diz_PxJEgf"
#       }
#     }
#
# --
# ad_id: 23843933838570439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ASr9dOIQQV0cuUNmBsbUN-Y"
#       }
#     }
#
# --
# ad_id: 23843786040320439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AePRINN5fPUnMpBvcIznNfm"
#       }
#     }
#
# --
# ad_id: 23843786040360439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AWCVy4v9qUp-bucavbbGhuy"
#       }
#     }
#
# --
# ad_id: 23843786040350439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ASh-xXTG-npY9zz7sIqdAdS"
#       }
#     }
#
# --
# ad_id: 23843933838630439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "A2vrTRBkdn9-y9KMA1hT0zK"
#       }
#     }
#
# --
# ad_id: 23843789654870439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Ain10t8lcWNH127eVNiTDso"
#       }
#     }
#
# --
# ad_id: 23843789654840439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ApC3tYILiEKZNmbeAxZq3eS"
#       }
#     }
#
# --
# ad_id: 23843789654820439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ARHJM0m-YZo6AOiK2hE1Q1L"
#       }
#     }
#
# --
# ad_id: 23843696391210439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AOhIGjJLt-18lE18pjAABAo"
#       }
#     }
#
# --
# ad_id: 23843933838770439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AL5nOD-6mwm3G9MF4SlJfMk"
#       }
#     }
#
# --
# ad_id: 23843696391200439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ABx6CUYVm0qob60R7gUllQX"
#       }
#     }
#
# --
# ad_id: 23843729358820439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "ADGuRPQgHemPedyCWPeuApx"
#       }
#     }
#
# --
# ad_id: 23843782267100439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AXlVrM_SmNLMGyA0aO-b-a-"
#       }
#     }
#
# --
# ad_id: 23843933838830439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AkGWRITh01e9pENVWLHREeR"
#       }
#     }
#
# --
# ad_id: 23843782267110439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AbwozgSmQDsi2mnul0hoC1H"
#       }
#     }
#
# --
# ad_id: 23843782267070439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "Af44dB7qOfGZY7NtaftTVBX"
#       }
#     }
#
# --
# ad_id: 23843782267090439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AwWEyp32W5UYOv9lFgg3W66"
#       }
#     }
#
# --
# ad_id: 23843933794050439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AFnI7iwlD5OTXh9A-PABhmG"
#       }
#     }
#
# --
# ad_id: 23843729433700439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AJZjfz23ZoksMHoGH-frykM"
#       }
#     }
#
# --
# ad_id: 23843729325480439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AtDDUsyJZ4y0iFfR5ijQkut"
#       }
#     }
#
# --
# ad_id: 23843729320560439
# [get_call_to_action_link_by_post] error
#
#   Message: Call was not successful
#   Method:  GET
#   Path:    https://graph.facebook.com/v4.0/None/
#   Params:  {'fields': 'call_to_action'}
#
#   Status:  404
#   Response:
#     {
#       "error": {
#         "message": "(#803) Some of the aliases you requested do not exist: None",
#         "type": "OAuthException",
#         "code": 803,
#         "fbtrace_id": "AE3yk6ybJ674OxghssTDpIo"
#       }
#     }
#
# --

# %%
# Out:
# True

# %%
# Out:
# [[100, 2, 3], [4, 5, 6], [100, 2, 3], [4, 5, 6]]
