# %%
import uuid
from googleads import adwords
import sys

# %%
from csv import reader
import csv
import pandas as pd
import numpy as np
import copy

# %%
AUTH_FILE_PATH = '/home/tim_su/ai_optimizer/opt/ai_optimizer/googleads.yaml'
client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#client_2 = ad_manager.AdManagerClient.LoadFromStorage('/home/tim_su/ai_optimizer/opt/ai_optimizer/googleads.yaml')

# %%
CUSTOMER_SERVICE_ID = '3637290511'
client.SetClientCustomerId(CUSTOMER_SERVICE_ID)

# %% [markdown]
# ## Get Available Fields of Report Type

# %%
# Display which field is able to query for certain report type
REPORT_TYPE = 'CAMPAIGN_PERFORMANCE_REPORT'

def get_report_fields(client, report_type):
    # Initialize appropriate service.
    report_definition_service = client.GetService(
        'ReportDefinitionService', version='v201809')

    # Get report fields.
    fields = report_definition_service.getReportFields(report_type)

    # Display results.
    print('Report type "%s" contains the following fields:' % report_type)
    for field in fields:
        print(' - %s(%s)' % (field['fieldName'], field['fieldType']))
        if 'enumValues' in field:
            print('  := [%s]' % ', '.join(field['enumValues']))

if __name__ == '__main__':
    # Initialize client object.
    adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    get_report_fields(adwords_client, REPORT_TYPE)
# Out:
# Report type "CAMPAIGN_PERFORMANCE_REPORT" contains the following fields:
#  - Period(BudgetPeriod)
#   := []
#  - UrlCustomParameters(CustomParameters)
#   := []
#  - AbsoluteTopImpressionPercentage(Double)
#   := []
#  - AccountCurrencyCode(String)
#   := []
#  - AccountDescriptiveName(String)
#   := []
#  - AccountTimeZone(String)
#   := []
#  - ActiveViewCpm(Money)
#   := []
#  - ActiveViewCtr(Double)
#   := []
#  - ActiveViewImpressions(Long)
#   := []
#  - ActiveViewMeasurability(Double)
#   := []
#  - ActiveViewMeasurableCost(Money)
#   := []
#  - ActiveViewMeasurableImpressions(Long)
#   := []
#  - ActiveViewViewability(Double)
#   := []
#  - AdNetworkType1(AdNetworkType1)
#   := [UNKNOWN, SEARCH, CONTENT, YOUTUBE_SEARCH, YOUTUBE_WATCH, MIXED]
#  - AdNetworkType2(AdNetworkType2)
#   := [UNKNOWN, SEARCH, SEARCH_PARTNERS, CONTENT, YOUTUBE_SEARCH, YOUTUBE_WATCH, MIXED]
#  - AdvertisingChannelSubType(AdvertisingChannelSubType)
#   := [UNKNOWN, SEARCH_MOBILE_APP, DISPLAY_MOBILE_APP, SEARCH_EXPRESS, DISPLAY_EXPRESS, UNIVERSAL_APP_CAMPAIGN, DISPLAY_SMART_CAMPAIGN, SHOPPING_GOAL_OPTIMIZED_ADS, DISPLAY_GMAIL_AD]
#  - AdvertisingChannelType(AdvertisingChannelType)
#   := [UNKNOWN, SEARCH, DISPLAY, SHOPPING, VIDEO, MULTI_CHANNEL, EXPRESS]
#  - AllConversionRate(Double)
#   := []
#  - AllConversions(Double)
#   := []
#  - AllConversionValue(Double)
#   := []
#  - Amount(Money)
#   := []
#  - AverageCost(Money)
#   := []
#  - AverageCpc(Money)
#   := []
#  - AverageCpe(Double)
#   := []
#  - AverageCpm(Money)
#   := []
#  - AverageCpv(Double)
#   := []
#  - AverageFrequency(Double)
#   := []
#  - AveragePageviews(Double)
#   := []
#  - AveragePosition(Double)
#   := []
#  - AverageTimeOnSite(Double)
#   := []
#  - BaseCampaignId(Long)
#   := []
#  - BiddingStrategyId(Long)
#   := []
#  - BiddingStrategyName(String)
#   := []
#  - BiddingStrategyType(BiddingStrategyType)
#   := [MANUAL_CPC, MANUAL_CPV, MANUAL_CPM, PAGE_ONE_PROMOTED, TARGET_SPEND, TARGET_CPA, TARGET_ROAS, MAXIMIZE_CONVERSIONS, MAXIMIZE_CONVERSION_VALUE, TARGET_OUTRANK_SHARE, NONE, UNKNOWN]
#  - BounceRate(Double)
#   := []
#  - BudgetId(Long)
#   := []
#  - CampaignDesktopBidModifier(Double)
#   := []
#  - CampaignGroupId(Long)
#   := []
#  - CampaignId(Long)
#   := []
#  - CampaignMobileBidModifier(Double)
#   := []
#  - CampaignName(String)
#   := []
#  - CampaignStatus(CampaignStatus)
#   := [UNKNOWN, ENABLED, PAUSED, REMOVED]
#  - CampaignTabletBidModifier(Double)
#   := []
#  - CampaignTrialType(CampaignTrialType)
#   := [UNKNOWN, BASE, DRAFT, TRIAL]
#  - ClickAssistedConversions(Long)
#   := []
#  - ClickAssistedConversionsOverLastClickConversions(Double)
#   := []
#  - ClickAssistedConversionValue(Double)
#   := []
#  - Clicks(Long)
#   := []
#  - ClickType(ClickType)
#   := [URL_CLICKS, CALLS, OTHER, PRODUCT_EXTENSION_CLICKS, SITELINKS, PRODUCT_LISTING_AD_CLICKS, GET_DIRECTIONS, OFFER_PRINTS, BREADCRUMBS, CALL_TRACKING, MOBILE_CALL_TRACKING, LOCATION_EXPANSION, STORE_LOCATOR, PRODUCT_LISTING_AD_LOCAL, APP_DEEPLINK, PRODUCT_LISTING_AD_MULTICHANNEL_LOCAL, PRODUCT_LISTING_AD_MULTICHANNEL_ONLINE, PRODUCT_LISTING_ADS_COUPON, PRODUCT_LISTING_AD_TRANSACTABLE, PRODUCT_AD_APP_DEEPLINK, SHOWCASE_AD_CATEGORY_LINK, SHOWCASE_AD_LOCAL_STOREFRONT_LINK, SHOWCASE_AD_ONLINE_PRODUCT_LINK, SHOWCASE_AD_LOCAL_PRODUCT_LINK, PRICE_EXTENSION, VIDEO_WEBSITE_CLICKS, VIDEO_CALL_TO_ACTION_CLICKS, VIDEO_APP_STORE_CLICKS, VIDEO_CARD_ACTION_HEADLINE_CLICKS, VIDEO_END_CAP_CLICKS, CLICK_ON_ENGAGEMENT_AD, LOCATION_FORMAT_MAP, LOCATION_FORMAT_LANDING_PAGE, LOCATION_FORMAT_STORE_INFO, LOCATION_FORMAT_DIRECTIONS, LOCATION_FORMAT_CALL, LOCATION_FORMAT_TEXT, LOCATION_FORMAT_IMAGE, BROADBAND_PLAN, WIRELESS_PLAN, VISUAL_SITELINKS, PROMOTION_EXTENSION, SWIPEABLE_GALLERY_AD_HEADLINE, SWIPEABLE_GALLERY_AD_SWIPES, SWIPEABLE_GALLERY_AD_SEE_MORE, SWIPEABLE_GALLERY_AD_SITELINK_ONE, SWIPEABLE_GALLERY_AD_SITELINK_TWO, SWIPEABLE_GALLERY_AD_SITELINK_THREE, SWIPEABLE_GALLERY_AD_SITELINK_FOUR, SWIPEABLE_GALLERY_AD_SITELINK_FIVE, HOTEL_PRICE, HOTEL_BOOK_ON_GOOGLE_ROOM_SELECTION, UNKNOWN]
#  - ContentBudgetLostImpressionShare(Double)
#   := []
#  - ContentImpressionShare(Double)
#   := []
#  - ContentRankLostImpressionShare(Double)
#   := []
#  - ConversionAdjustment(Enum)
#   := [TRUE, FALSE]
#  - ConversionAdjustmentLagBucket(ConversionAdjustmentLagBucket)
#   := [UNKNOWN, CONVERSION_0_TO_1_DAY, CONVERSION_1_TO_2_DAYS, CONVERSION_2_TO_3_DAYS, CONVERSION_3_TO_4_DAYS, CONVERSION_4_TO_5_DAYS, CONVERSION_5_TO_6_DAYS, CONVERSION_6_TO_7_DAYS, CONVERSION_7_TO_8_DAYS, CONVERSION_8_TO_9_DAYS, CONVERSION_9_TO_10_DAYS, CONVERSION_10_TO_11_DAYS, CONVERSION_11_TO_12_DAYS, CONVERSION_12_TO_13_DAYS, CONVERSION_13_TO_14_DAYS, CONVERSION_14_TO_21_DAYS, CONVERSION_21_TO_30_DAYS, CONVERSION_30_TO_45_DAYS, CONVERSION_45_TO_60_DAYS, CONVERSION_60_TO_90_DAYS, ADJUSTMENT_0_TO_1_DAY, ADJUSTMENT_1_TO_2_DAYS, ADJUSTMENT_2_TO_3_DAYS, ADJUSTMENT_3_TO_4_DAYS, ADJUSTMENT_4_TO_5_DAYS, ADJUSTMENT_5_TO_6_DAYS, ADJUSTMENT_6_TO_7_DAYS, ADJUSTMENT_7_TO_8_DAYS, ADJUSTMENT_8_TO_9_DAYS, ADJUSTMENT_9_TO_10_DAYS, ADJUSTMENT_10_TO_11_DAYS, ADJUSTMENT_11_TO_12_DAYS, ADJUSTMENT_12_TO_13_DAYS, ADJUSTMENT_13_TO_14_DAYS, ADJUSTMENT_14_TO_21_DAYS, ADJUSTMENT_21_TO_30_DAYS, ADJUSTMENT_30_TO_45_DAYS, ADJUSTMENT_45_TO_60_DAYS, ADJUSTMENT_60_TO_90_DAYS, ADJUSTMENT_90_TO_145_DAY, CONVERSION_UNKNOWN, ADJUSTMENT_UNKNOWN]
#  - ConversionAttributionEventType(ConversionAttributionEventType)
#   := [UNKNOWN, IMPRESSION, INTERACTION]
#  - ConversionCategoryName(String)
#   := []
#  - ConversionLagBucket(ConversionLagBucket)
#   := [UNKNOWN, CONVERSION_0_TO_1_DAY, CONVERSION_1_TO_2_DAYS, CONVERSION_2_TO_3_DAYS, CONVERSION_3_TO_4_DAYS, CONVERSION_4_TO_5_DAYS, CONVERSION_5_TO_6_DAYS, CONVERSION_6_TO_7_DAYS, CONVERSION_7_TO_8_DAYS, CONVERSION_8_TO_9_DAYS, CONVERSION_9_TO_10_DAYS, CONVERSION_10_TO_11_DAYS, CONVERSION_11_TO_12_DAYS, CONVERSION_12_TO_13_DAYS, CONVERSION_13_TO_14_DAYS, CONVERSION_14_TO_21_DAYS, CONVERSION_21_TO_30_DAYS, CONVERSION_30_TO_45_DAYS, CONVERSION_45_TO_60_DAYS, CONVERSION_60_TO_90_DAYS]
#  - ConversionRate(Double)
#   := []
#  - Conversions(Double)
#   := []
#  - ConversionTrackerId(Long)
#   := []
#  - ConversionTypeName(String)
#   := []
#  - ConversionValue(Double)
#   := []
#  - Cost(Money)
#   := []
#  - CostPerAllConversion(Money)
#   := []
#  - CostPerConversion(Money)
#   := []
#  - CostPerCurrentModelAttributedConversion(Double)
#   := []
#  - CrossDeviceConversions(Double)
#   := []
#  - Ctr(Double)
#   := []
#  - CurrentModelAttributedConversions(Double)
#   := []
#  - CurrentModelAttributedConversionValue(Double)
#   := []
#  - CustomerDescriptiveName(String)
#   := []
#  - Date(Date)
#   := []
#  - DayOfWeek(DayOfWeek)
#   := [MONDAY, TUESDAY, WEDNESDAY, THURSDAY, FRIDAY, SATURDAY, SUNDAY]
#  - Device(DeviceType)
#   := [UNKNOWN, DESKTOP, HIGH_END_MOBILE, TABLET, CONNECTED_TV]
#  - EndDate(Date)
#   := []
#  - EngagementRate(Double)
#   := []
#  - Engagements(Long)
#   := []
#  - EnhancedCpcEnabled(Enum)
#   := [TRUE, FALSE]
#  - ExternalConversionSource(ExternalConversionSource)
#   := [UNKNOWN, WEBPAGE, ANALYTICS, UPLOAD, AD_CALL_METRICS, OFFERS, ENGAGEMENT, WEBSITE_CALL_METRICS, STORE_VISITS, ANDROID_IN_APP, ANDROID_DOWNLOAD, IOS_IN_APP, IOS_FIRST_OPEN, APP_UNSPECIFIED, ANDROID_FIRST_OPEN, UPLOAD_CALLS, FIREBASE, CLICK_TO_CALL, SALESFORCE, STORE_SALES_CRM, STORE_SALES_PAYMENT_NETWORK, GOOGLE_PLAY, THIRD_PARTY_APP_ANALYTICS, GOOGLE_ATTRIBUTION, STORE_SALES_DIRECT]
#  - ExternalCustomerId(Long)
#   := []
#  - FinalUrlSuffix(String)
#   := []
#  - GmailForwards(Long)
#   := []
#  - GmailSaves(Long)
#   := []
#  - GmailSecondaryClicks(Long)
#   := []
#  - HasRecommendedBudget(Enum)
#   := [TRUE, FALSE]
#  - HourOfDay(Integer)
#   := []
#  - ImpressionAssistedConversions(Long)
#   := []
#  - ImpressionAssistedConversionsOverLastClickConversions(Double)
#   := []
#  - ImpressionAssistedConversionValue(Double)
#   := []
#  - ImpressionReach(Long)
#   := []
#  - Impressions(Long)
#   := []
#  - InteractionRate(Double)
#   := []
#  - Interactions(Long)
#   := []
#  - InteractionTypes(EnumSet)
#   := []
#  - InvalidClickRate(Double)
#   := []
#  - InvalidClicks(Long)
#   := []
#  - IsBudgetExplicitlyShared(Enum)
#   := [TRUE, FALSE]
#  - LabelIds(List)
#   := []
#  - Labels(List)
#   := []
#  - MaximizeConversionValueTargetRoas(Double)
#   := []
#  - Month(String)
#   := []
#  - MonthOfYear(MonthOfYear)
#   := [JANUARY, FEBRUARY, MARCH, APRIL, MAY, JUNE, JULY, AUGUST, SEPTEMBER, OCTOBER, NOVEMBER, DECEMBER]
#  - NumOfflineImpressions(Long)
#   := []
#  - NumOfflineInteractions(Long)
#   := []
#  - OfflineInteractionRate(Double)
#   := []
#  - PercentNewVisitors(Double)
#   := []
#  - Quarter(String)
#   := []
#  - RecommendedBudgetAmount(Money)
#   := []
#  - RelativeCtr(Double)
#   := []
#  - SearchAbsoluteTopImpressionShare(Double)
#   := []
#  - SearchBudgetLostAbsoluteTopImpressionShare(Double)
#   := []
#  - SearchBudgetLostImpressionShare(Double)
#   := []
#  - SearchBudgetLostTopImpressionShare(Double)
#   := []
#  - SearchClickShare(Double)
#   := []
#  - SearchExactMatchImpressionShare(Double)
#   := []
#  - SearchImpressionShare(Double)
#   := []
#  - SearchRankLostAbsoluteTopImpressionShare(Double)
#   := []
#  - SearchRankLostImpressionShare(Double)
#   := []
#  - SearchRankLostTopImpressionShare(Double)
#   := []
#  - SearchTopImpressionShare(Double)
#   := []
#  - ServingStatus(ServingStatus)
#   := [SERVING, NONE, ENDED, PENDING, SUSPENDED]
#  - Slot(Slot)
#   := [SearchRhs, SearchTop, SearchOther, Content, AfsTop, AfsOther, Mixed, Unknown]
#  - StartDate(Date)
#   := []
#  - TopImpressionPercentage(Double)
#   := []
#  - TotalAmount(Money)
#   := []
#  - TrackingUrlTemplate(String)
#   := []
#  - ValuePerAllConversion(Double)
#   := []
#  - ValuePerConversion(Double)
#   := []
#  - ValuePerCurrentModelAttributedConversion(Double)
#   := []
#  - VideoQuartile100Rate(Double)
#   := []
#  - VideoQuartile25Rate(Double)
#   := []
#  - VideoQuartile50Rate(Double)
#   := []
#  - VideoQuartile75Rate(Double)
#   := []
#  - VideoViewRate(Double)
#   := []
#  - VideoViews(Long)
#   := []
#  - ViewThroughConversions(Long)
#   := []
#  - Week(String)
#   := []
#  - Year(Integer)
#   := []

# %% [markdown]
# ## Campaign Insights & AdGroup Insights

# %%
CAMPAIGN_FIELDS = ['ExternalCustomerId','CampaignId','AdvertisingChannelType', 'CampaignStatus',
                   'BiddingStrategyType','Amount','StartDate','EndDate','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion']
class DatePreset:
    today = 'TODAY'
    yesterday = 'YESTERDAY'
    lifetime = 'ALL_TIME'

def get_campaign_insights(client, campaign_id=None, date_preset=None):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    report = {
        'reportName': 'CAMPAIGN_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
        'dateRangeType': date_preset,
        'reportType': 'CAMPAIGN_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': CAMPAIGN_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
            'predicates': [
                {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
                }
            ]
        }
    }
    # Print out the report as a string
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(CAMPAIGN_FIELDS)),
            columns=CAMPAIGN_FIELDS
        )
        df = df.append(df_temp)
    df[df.columns.difference(['CampaignStatus', 'AdvertisingChannelType', 'BiddingStrategyType', 'StartDate', 'EndDate'])] = df[df.columns.difference(
        ['CampaignStatus', 'AdvertisingChannelType', 'BiddingStrategyType', 'StartDate', 'EndDate'])].apply(pd.to_numeric, errors='coerce')
    df[df.columns.difference(['ExternalCustomerId', 'CampaignId', 'AdvertisingChannelType', 'CampaignStatus', 'BiddingStrategyType', 'StartDate', 'EndDate', 'Impressions', 'Clicks', 'Conversions'])] = df[df.columns.difference(
        ['ExternalCustomerId', 'CampaignId', 'CampaignStatus', 'AdvertisingChannelType', 'BiddingStrategyType', 'StartDate', 'EndDate', 'Impressions', 'Clicks', 'Conversions'])].div(1000000)
    df[['StartDate','EndDate']] = df[['StartDate','EndDate']].apply( pd.to_datetime, errors='coerce' )
    return df

if __name__ == '__main__':
    # Initialize client object.
    client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    campaign_insights = get_campaign_insights(client, campaign_id=campaign_id)

# %%
ADGROUP_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus',
                  'CpmBid','CpvBid', 'CpcBid', 'TargetCpa', 'BiddingStrategyType','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion']
# ADGROUP_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId','ConversionCategoryName']
def get_adgroup_insights(client, campaign_id=None, adgroup_id=None, date_preset=None):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    if campaign_id is not None and adgroup_id is None:
        operand = {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
        }
    elif adgroup_id is not None:
        operand = {
                    'field': 'AdGroupId',
                    'operator': 'EQUALS',
                    'values':[adgroup_id]
        }
    else:
        print('get_adgroup_insights: Missing arguments campaign_id or adgroup_id.' )
        operand = None
        return
    report = {
        'reportName': 'ADGROUP_PERFORMANCE_REPORT',
#         'dateRangeType': 'CUSTOM_DATE',
        'dateRangeType': date_preset,
        'reportType': 'ADGROUP_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': ADGROUP_FIELDS,
#             'dateRange': {'min': '20190301','max': '20190401'},
            'predicates': [
                operand
            ]
        }
    }
    # Print out the report as a string
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(ADGROUP_FIELDS)),
            columns=ADGROUP_FIELDS
        )
        df = df.append(df_temp)
    df[df.columns.difference(['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType'])] = df[df.columns.difference(
        ['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType'])].apply(pd.to_numeric, errors='coerce')
    df[df.columns.difference( ['ExternalCustomerId', 'CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType', 'Conversions'] )] = df[df.columns.difference(
        ['ExternalCustomerId', 'CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType', 'Conversions'])].div(1000000)

    return df.reset_index(drop=True)

if __name__ == '__main__':
    # Initialize client object.
    client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#     adgroup_insights = get_adgroup_insights(client)
    adgroup_insights = get_adgroup_insights(client, campaign_id=campaign_id)

# %% [markdown]
# ## Retrieve Age Range Performance Report

# %%
AGE_RANGE_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupId','Criteria', 'Id', 'AdGroupStatus',
                  'CpmBid', 'CpcBid', 'BiddingStrategyType','Cost',
                   'AverageCost','Impressions', 'Clicks','Conversions',
                   'AverageCpc','CostPerConversion']
# AGE_RANGE_FIELDS = ['ExternalCustomerId','CampaignId', 'AdGroupType', 'AdGroupId','ConversionCategoryName']
def get_age_range_insights(client, campaign_id=None, adgroup_id=None, date_preset=None):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    if campaign_id is not None and adgroup_id is None:
        operand = {
                    'field': 'CampaignId',
                    'operator': 'EQUALS',
                    'values':[campaign_id]
        }
    elif adgroup_id is not None:
        operand = {
                    'field': 'AdGroupId',
                    'operator': 'EQUALS',
                    'values':[adgroup_id]
        }
    else:
        print('get_age_range_insights: Missing arguments campaign_id or adgroup_id.' )
        operand = None
        return
    report = {
        'reportName': 'AGE_RANGE_PERFORMANCE_REPORT',
        'dateRangeType': date_preset,
        'reportType': 'AGE_RANGE_PERFORMANCE_REPORT',
        'downloadFormat': 'CSV',
        'selector': {
            'fields': AGE_RANGE_FIELDS,
            'predicates': [
                operand
            ]
        }
    }
    # Print out the report as a string
    csv = report_downloader.DownloadReportAsString(  
        report, skip_report_header=True, skip_column_header=True,   
        skip_report_summary=True, include_zero_impressions=True,client_customer_id=CUSTOMER_SERVICE_ID)
    csv_list = csv.split('\n')[:-1]
    df = pd.DataFrame()
    for lil_csv in csv_list:
        df_temp = pd.DataFrame(
            data=np.array(lil_csv.split(',')).reshape(1,len(AGE_RANGE_FIELDS)),
            columns=AGE_RANGE_FIELDS
        )
        df = df.append(df_temp)
    df[df.columns.difference(['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType', 'Criteria'])] = df[df.columns.difference(
        ['AdGroupType', 'AdGroupStatus', 'BiddingStrategyType', 'Criteria'])].apply(pd.to_numeric, errors='coerce')
    df[df.columns.difference( ['ExternalCustomerId', 'CampaignId','Criteria', 'Id', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType','Impressions', 'Clicks', 'Conversions'] )] = df[df.columns.difference(
        ['ExternalCustomerId', 'CampaignId', 'Criteria', 'Id', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'BiddingStrategyType','Impressions', 'Clicks', 'Conversions'])].div(1000000)

    return df.reset_index(drop=True)

# if __name__ == '__main__':
# Initialize client object.
client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
#     adgroup_insights = get_age_range_insights(client)
adgroup_insights = get_age_range_insights(client, campaign_id=1747836670, adgroup_id=68524904775)

# %% [markdown]
# ## Retrieve Performance Report from Different Criterions

# %%
# URL
URL_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'AdGroupStatus', 'Cost', 'AverageCost',
    'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion', 'DisplayName', ]

# CRITERIA,
CRITERIA_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'Criteria', 'Id', 'AdGroupStatus', 'CpmBid', 'CpcBid',
    'Cost', 'AverageCost', 'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion']

# AUDIENCE, AGE_RANGE, DISPLAY_KEYWORD
BIDDABLE_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupId', 'Criteria', 'Id', 'AdGroupStatus', 'CpmBid', 'CpcBid',
    'BiddingStrategyType', 'Cost', 'AverageCost', 'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion']

# ADGROUP
ADGROUP_FIELDS_LIST = [
    'ExternalCustomerId', 'CampaignId', 'AdGroupType', 'AdGroupId', 'AdGroupStatus', 'CpmBid', 'CpvBid', 'CpcBid', 'TargetCpa',
    'BiddingStrategyType', 'Cost', 'AverageCost', 'Impressions', 'Clicks', 'Conversions', 'AverageCpc', 'CostPerConversion']

NON_NUMERIC_FIELDS_LIST = [
    'Ad group type', 'Ad group state', 'Bid Strategy Type', 'Keyword', 'Age Range', 'Audience', 'Keyword / Placement', 'Criteria Display Name']

NUMERIC_FIELDS_LIST = [
    'Max. CPM', 'Max. CPV', 'Max. CPC', 'Default max. CPC', 'Target CPA', 'Cost', 'Avg. Cost', 'Avg. CPC', 'Cost / conv.']

FIELD_INDEX = {
    'ADGROUP': ADGROUP_FIELDS_LIST,
    'URL': URL_FIELDS_LIST,
    'CRITERIA': CRITERIA_FIELDS_LIST,
    'AUDIENCE': BIDDABLE_FIELDS_LIST,
    'AGE_RANGE': BIDDABLE_FIELDS_LIST,
    'DISPLAY_KEYWORD': BIDDABLE_FIELDS_LIST,
}

ADGROUP_FIELDS_LIST  = [
    'customer_id', 'campaign_id', 'channel_type', 'adgroup_id', 'status', 'cpm_bid', 'cpv_bid', 'cpc_bid', 'cpa_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
URL_FIELDS_LIST      = [
    'customer_id', 'campaign_id', 'adgroup_id', 'status', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion', 'url_display_name']
CRITERIA_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'keyword_placement', 'keyword_id', 'status', 'cpm_bid', 'cpc_bid', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
AUDIENCE_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'audience', 'criterion_id', 'status', 'cpm_bid', 'cpc_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
AGE_RANGE_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'age_range', 'criterion_id', 'status', 'cpm_bid', 'cpc_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']
BIDDABLE_FIELDS_LIST = [
    'customer_id', 'campaign_id', 'adgroup_id', 'keyword', 'keyword_id', 'status', 'cpm_bid', 'cpc_bid', 'bidding_type', 'spend', 'cost_per_target', 'impressions', 'clicks', 'conversions', 'cost_per_click', 'cost_per_conversion']

COLUMN_INDEX = {
    'ADGROUP': ADGROUP_FIELDS_LIST,
    'URL': URL_FIELDS_LIST,
    'CRITERIA': CRITERIA_FIELDS_LIST,
    'AUDIENCE': AUDIENCE_FIELDS_LIST,
    'AGE_RANGE': AGE_RANGE_FIELDS_LIST,
    'DISPLAY_KEYWORD': BIDDABLE_FIELDS_LIST,
}
DATABASE_INDEX = {
    'ADGROUP': 'adgroup_insights',
    'URL': 'url_insights',
    'CRITERIA': 'criteria_insights',
    'AUDIENCE': 'audience_insights',
    'AGE_RANGE': 'age_range_insights',
    'DISPLAY_KEYWORD': 'display_keyword_insights',
}

# %%
def get_performance_insights(client, campaign_id=None, adgroup_id=None, date_preset=None, performance_type='ADGROUP'):
    client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    report_downloader = client.GetReportDownloader(version='v201809')
    if date_preset is None:
        date_preset = 'ALL_TIME'
    else:
        date_preset = date_preset
    # Create report definition.
    if campaign_id is not None and adgroup_id is None:
        operand = {
            'field': 'CampaignId',
            'operator': 'EQUALS',
            'values': [campaign_id]
        }
    elif adgroup_id is not None:
        operand = {
            'field': 'AdGroupId',
            'operator': 'EQUALS',
            'values': [adgroup_id]
        }
    else:
        print('get_audience_insights: Missing arguments campaign_id or adgroup_id.')
        operand = None
        return
    report = {
        'downloadFormat': 'CSV',
        'reportName': performance_type+'_PERFORMANCE_REPORT',
        'reportType': performance_type+'_PERFORMANCE_REPORT',
        'dateRangeType': date_preset,
        'selector': {
            'fields': FIELD_INDEX[performance_type],
            'predicates': [operand]
        }
    }
    # Print out the report as a string
    with open(performance_type+'.csv', 'wb') as output_file:
        report_downloader.DownloadReport(
            report, output=output_file, skip_report_header=True, skip_column_header=False,
            skip_report_summary=True, include_zero_impressions=False, client_customer_id=CUSTOMER_SERVICE_ID)
    with open(performance_type+'.csv')as csv_file:
        df = pd.read_csv(csv_file, sep=",", quotechar='"')
        
        df[df.columns.difference( NON_NUMERIC_FIELDS_LIST )] = df[df.columns.difference( NON_NUMERIC_FIELDS_LIST )].apply(pd.to_numeric, errors='coerce')
        
        df[df.columns.intersection( NUMERIC_FIELDS_LIST )] = df[df.columns.intersection( NUMERIC_FIELDS_LIST )].div(1000000)
        
        df.columns = COLUMN_INDEX[performance_type]
        gdn_db.into_table( df, DATABASE_INDEX[performance_type] )
        return df.sort_values(by=['impressions'], ascending=False).reset_index(drop=True)


if __name__ == '__main__':
    # Initialize client object.
    # URL
    # CRITERIA
    # AUDIENCE, AGE_RANGE, DISPLAY_KEYWORD
    from ai_optimizer.codes import gdn_db
    client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    display_keyword_insights = get_performance_insights(
        client, campaign_id=1747836664, adgroup_id=68524904535, performance_type='DISPLAY_KEYWORD')

# %% [markdown]
# ## Make AdGroup

# %%
from googleads import adwords
CUSTOMER_SERVICE_ID = '3637290511'
client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
AD_GROUP_ID = 68524904055
CPC_BID_MICRO_AMOUNT = '4000000'


def update_adgroup_bid(client, ad_group_id, bid_micro_amount=None):
    # Initialize appropriate service.
    ad_group_service = client.GetService('AdGroupService', version='v201809')
    
    # Construct operations and update an ad group.
    operations = [{
        'operator': 'SET',
        'operand': {
            'id': ad_group_id,
            'status': 'ENABLED'
        }
    }]
  
    if bid_micro_amount:
        operations[0]['operand']['biddingStrategyConfiguration'] = {
            'bids': [{
                'xsi_type': 'CpcBid',
                'bid': {
                    'microAmount': bid_micro_amount,
                }
            }]
        }
  
    ad_groups = ad_group_service.mutate(operations)
    return ad_groups

if __name__ == '__main__':
    # Initialize client object.
    adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
    adwords_client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
    update_adgroup_bid(adwords_client, AD_GROUP_ID, CPC_BID_MICRO_AMOUNT)

# %%
adwords_client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
adwords_client.SetClientCustomerId(CUSTOMER_SERVICE_ID)
update_adgroup_bid(adwords_client, AD_GROUP_ID, CPC_BID_MICRO_AMOUNT)

# %%
def retrieve_campaign_params(client, campaign_id):
    _FIELDS = ['CampaignId', 'Name']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'CampaignId',
                'operator': 'EQUALS',
                'values':[campaign_id]
            }
        ]
    }]
    campaign_service = client.GetService('CampaignService', version='v201809')
    campaign_params = campaign_service.get(selector)
    return campaign_params

# %%
retrieve_ad_group_params(client, 66867879022)
# Out:
# {
#     'totalNumEntries': 1,
#     'Page.Type': 'AdGroupPage',
#     'entries': [
#         {
#             'id': 66867879022,
#             'campaignId': 1777436620,
#             'campaignName': None,
#             'name': 'Mutant feccdc4a-2d52-4d07-90f3-62220595497d',
#             'status': None,
#             'settings': [],
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': None,
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'contentBidCriterionTypeGroup': None,
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None,
#             'adGroupType': None,
#             'adGroupAdRotationMode': None
#         }
#     ]
# }

# %% [markdown]
# ## Retrive AdGroup Params

# %% [markdown]
# ### Params

# %% [markdown]
# #### AdGroup

# %%
def retrieve_ad_group_params(client, ad_group_id):
    _FIELDS = ['CampaignId', 'AdGroupId', 'Name', 'CpcBid', 'BiddingStrategyId','BiddingStrategyName','BiddingStrategySource', 'BiddingStrategyType']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_group_service = client.GetService('AdGroupService', version='v201809')
    ad_group_params = ad_group_service.get(selector)
    return ad_group_params

def make_ad_group(ad_group_id):
    ad_group_params = retrieve_ad_group_params(client, ad_group_id)
    campaign_id = ad_group_params['entries'][0]['campaignId']
    name = ad_group_params['entries'][0]['name']
    xsi_type = ad_group_params['entries'][0]['biddingStrategyConfiguration']['bids'][0]['Bids.Type']
    micro_amount = ad_group_params['entries'][0]['biddingStrategyConfiguration']['bids'][0]['bid']['microAmount']
    operations = [{
        'operator': 'ADD',
        'operand': {
            'campaignId': campaign_id,
            'name':  'Mutant {}'.format(name),
            'status': 'ENABLED',
            'biddingStrategyConfiguration': {
                'bids': [
                    {
                        'xsi_type': xsi_type,
                        'bid': {
                            'microAmount': micro_amount
                        }
                    }
                ]
            }
        }
    }]
    ad_group_service = client.GetService('AdGroupService', version='v201809')
    ad_groups = ad_group_service.mutate(operations)
    return ad_groups

# %% [markdown]
# #### Ad

# %%
def retrive_ad_params(ad_group_id):
    ad_params_list = []
    ad_criteria = dict()
    _FIELDS = ['AdGroupId', 'HeadlinePart1', 'HeadlinePart2', 'DisplayUrl', 'CreativeFinalUrls', 'Description', 'Url']
    selector= [{
        'fields': _FIELDS,
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_service = client.GetService('AdGroupAdService', version='v201809')
    ad_params = ad_service.get(selector)
    for entry in ad_params['entries']:
        ad_criteria['id'] = entry['ad']['id']
        ad_params_list.append(copy.deepcopy(ad_criteria))
    return ad_params_list

# %%
def assign_ad_to_ad_group(ad_group_id, ad_params_list):
    operations = []
    for ad_params in ad_params_list:
        operations.append({
            'operator': 'ADD',
            'operand': {
                'adGroupId': ad_group_id,
                'status': 'ENABLED',
                'ad': ad_params
            }
        })
    ad_group_service = client.GetService('AdGroupAdService', version='v201809')
    ad_groups = ad_group_service.mutate(operations)
    return ad_groups

# %% [markdown]
# ### Criterion

# %%
def retrieve_ad_group_criterion(client, ad_group_id):
    _FIELDS = ['AdGroupId', 'CriteriaType', 'UserInterestId', 'UserInterestName', 'UserListId', 'LabelIds']
    selector= [{
        'fields': _FIELDS,
    #             'dateRange': {'min': '20190301','max': '20190401'},
        'predicates': [
            {
                'field': 'AdGroupId',
                'operator': 'EQUALS',
                'values':[ad_group_id]
            }
        ]
    }]
    ad_group_service = client.GetService('AdGroupCriterionService', version='v201809')
    ad_group_criterion = ad_group_service.get(selector)
    return ad_group_criterion

def make_adgroup_criterion(new_adgroup_id = None, old_ad_group_criterion=None):
    if new_adgroup_id is None and old_ad_group_criterion is None:
        raise ValueError('new_adgroup_id and old_ad_group_criterion is Required.')
    biddable_criterion = dict()
    negative_criterion = dict()
    biddable_criterion['adGroupId'] = new_adgroup_id
    negative_criterion['adGroupId'] = new_adgroup_id

    biddable_ad_group_criteria_list = list()
    negative_ad_group_criteria_list = list()
    for entry in old_ad_group_criterion['entries']:
        criterion = dict()
        criterion['xsi_type'] = entry['criterion']['Criterion.Type']
        
        if 'AgeRange' in entry['criterion']['Criterion.Type']:
#             print(entry['criterion']['id'], entry['criterion']['Criterion.Type'])
            criterion['id'] = entry['criterion']['id']
            
        elif 'Placement'  in entry['criterion']['Criterion.Type']:
#             print(entry['criterion']['id'], entry['criterion']['url'])
            criterion['id'] = entry['criterion']['id']
            criterion['url'] = entry['criterion']['url']

        elif 'Keyword'  in entry['criterion']['Criterion.Type']:
#             print(entry['criterion']['id'], entry['criterion']['text'])
            criterion['id'] = entry['criterion']['id']
            criterion['matchType'] = entry['criterion']['matchType']
            criterion['text'] = entry['criterion']['text']

        elif 'CriterionUserInterest'  in entry['criterion']['Criterion.Type']:
#             print(entry['criterion']['id'], entry['criterion'])
            criterion['userInterestId'] = entry['criterion']['userInterestId']

        if criterion:
            if 'BiddableAdGroupCriterion' in entry['AdGroupCriterion.Type']:
                biddable_criterion['xsi_type'] = entry['AdGroupCriterion.Type']
                biddable_criterion['criterion'] = criterion
                biddable_ad_group_criteria_list.append(copy.deepcopy(biddable_criterion))

            elif 'NegativeAdGroupCriterion' in entry['AdGroupCriterion.Type']:
                negative_criterion['xsi_type'] = entry['AdGroupCriterion.Type']
                negative_criterion['criterion'] = criterion
                negative_ad_group_criteria_list.append(copy.deepcopy(negative_criterion))
    return biddable_ad_group_criteria_list, negative_ad_group_criteria_list

# %%
def assign_criterion_to_ad_group(client, ad_group_id, ad_group_criterion):
    '''
    an example of addong 4 type of criterion to new adgroup,
    if trying to exclude certain criterions, 
    change 'xsi_type' from 'BiddableAdGroupCriterion' to 'NegativeAdGroupCriterion' in ad_group_criteria object
    '''
    # Initialize appropriate service.
    ad_group_criterion_service = client.GetService(
        'AdGroupCriterionService', version='v201809')
    # Create the ad group criteria.  
    # Create operations.
    operations = []
    for criterion in ad_group_criterion:
        operations.append({
            'operator': 'ADD',
            'operand': criterion
        })
    response = ad_group_criterion_service.mutate(operations)
#     for criterion in ad_group_criterion:
#     print(ad_group_criterion[-1])
#     operation = {
#         'operator': 'ADD',
#         'operand': ad_group_criterion[-1]
#     }
#     response = ad_group_criterion_service.mutate(operation)
    return response

# %%
ad_group_criterion_service = client.GetService('AdGroupCriterionService', version='v201809')
keyword1 = {
    'xsi_type': 'BiddableAdGroupCriterion',
    'adGroupId': 66276904021,
    'criterion': {
        'xsi_type': 'Keyword',
        'matchType': 'BROAD',
        'text': '維也納'
    }
}
operation = {
    'operator': 'ADD',
    'operand': keyword1
}
response = ad_group_criterion_service.mutate(operation)
# Out:
# Error summary: {'faultMessage': "[OperationAccessDenied.OPERATION_NOT_PERMITTED_FOR_REMOVED_ENTITY @ operations[0]; trigger:'AdGroup']", 'requestId': '00058744bff8a4b90a62328205035c83', 'serviceName': 'AdGroupCriterionService', 'methodName': 'mutate', 'operations': '1', 'responseTime': '235'}
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/googleads/common.py in MakeSoapRequest(*args)
#    1381         return soap_service_method(
# -> 1382             *packed_args, _soapheaders=soap_headers)['body']['rval']
#    1383       except zeep.exceptions.Fault as e:
#
# ~/.local/lib/python3.6/site-packages/zeep/proxy.py in __call__(self, *args, **kwargs)
#      41             self._proxy._client, self._proxy._binding_options,
# ---> 42             self._op_name, args, kwargs)
#      43
#
# ~/.local/lib/python3.6/site-packages/zeep/wsdl/bindings/soap.py in send(self, client, options, operation, args, kwargs)
#     131
# --> 132         return self.process_reply(client, operation_obj, response)
#     133
#
# ~/.local/lib/python3.6/site-packages/zeep/wsdl/bindings/soap.py in process_reply(self, client, operation, response)
#     193         if response.status_code != 200 or fault_node is not None:
# --> 194             return self.process_error(doc, operation)
#     195
#
# ~/.local/lib/python3.6/site-packages/zeep/wsdl/bindings/soap.py in process_error(self, doc, operation)
#     298             actor=get_text('faultactor'),
# --> 299             detail=fault_node.find('detail'))
#     300
#
# Fault: [OperationAccessDenied.OPERATION_NOT_PERMITTED_FOR_REMOVED_ENTITY @ operations[0]; trigger:'AdGroup']
#
# During handling of the above exception, another exception occurred:
#
# GoogleAdsServerFault                      Traceback (most recent call last)
# <ipython-input-300-68604ea46e86> in <module>
#      13     'operand': keyword1
#      14 }
# ---> 15 response = ad_group_criterion_service.mutate(operation)
#
# ~/.local/lib/python3.6/site-packages/googleads/common.py in MakeSoapRequest(*args)
#    1392           error_list = fault.errors or error_list
#    1393         raise googleads.errors.GoogleAdsServerFault(
# -> 1394             e.detail, errors=error_list, message=e.message)
#    1395     return MakeSoapRequest
#    1396
#
# GoogleAdsServerFault: [OperationAccessDenied.OPERATION_NOT_PERMITTED_FOR_REMOVED_ENTITY @ operations[0]; trigger:'AdGroup']

# %%
new_ad_group_criterion[-1]
# Out:
# {'adGroupId': 66276904021,
#  'xsi_type': 'BiddableAdGroupCriterion',
#  'criterion': {'xsi_type': 'Keyword',
#   'id': 330657408684,
#   'matchType': 'BROAD',
#   'text': '維也納'}}

# %%
assign_criterion_to_ad_group(client, 64867100570, new_ad_group_criterion)
# Out:
# {'adGroupId': 66276904021, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': 330657408684, 'matchType': 'BROAD', 'text': '維也納'}}
# Error summary: {'faultMessage': "[OperationAccessDenied.OPERATION_NOT_PERMITTED_FOR_REMOVED_ENTITY @ operations[0]; trigger:'AdGroup']", 'requestId': '00058744b2641acd0aa791c84e06f4d2', 'serviceName': 'AdGroupCriterionService', 'methodName': 'mutate', 'operations': '1', 'responseTime': '247'}
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/googleads/common.py in MakeSoapRequest(*args)
#    1381         return soap_service_method(
# -> 1382             *packed_args, _soapheaders=soap_headers)['body']['rval']
#    1383       except zeep.exceptions.Fault as e:
#
# ~/.local/lib/python3.6/site-packages/zeep/proxy.py in __call__(self, *args, **kwargs)
#      41             self._proxy._client, self._proxy._binding_options,
# ---> 42             self._op_name, args, kwargs)
#      43
#
# ~/.local/lib/python3.6/site-packages/zeep/wsdl/bindings/soap.py in send(self, client, options, operation, args, kwargs)
#     131
# --> 132         return self.process_reply(client, operation_obj, response)
#     133
#
# ~/.local/lib/python3.6/site-packages/zeep/wsdl/bindings/soap.py in process_reply(self, client, operation, response)
#     193         if response.status_code != 200 or fault_node is not None:
# --> 194             return self.process_error(doc, operation)
#     195
#
# ~/.local/lib/python3.6/site-packages/zeep/wsdl/bindings/soap.py in process_error(self, doc, operation)
#     298             actor=get_text('faultactor'),
# --> 299             detail=fault_node.find('detail'))
#     300
#
# Fault: [OperationAccessDenied.OPERATION_NOT_PERMITTED_FOR_REMOVED_ENTITY @ operations[0]; trigger:'AdGroup']
#
# During handling of the above exception, another exception occurred:
#
# GoogleAdsServerFault                      Traceback (most recent call last)
# <ipython-input-298-dcb4093d5710> in <module>
# ----> 1 assign_criterion_to_ad_group(client, 64867100570, new_ad_group_criterion)
#
# <ipython-input-297-d46e99c0f421> in assign_criterion_to_ad_group(client, ad_group_id, ad_group_criterion)
#      23         'operand': ad_group_criterion[-1]
#      24     }
# ---> 25     response = ad_group_criterion_service.mutate(operation)
#      26     return response
#
# ~/.local/lib/python3.6/site-packages/googleads/common.py in MakeSoapRequest(*args)
#    1392           error_list = fault.errors or error_list
#    1393         raise googleads.errors.GoogleAdsServerFault(
# -> 1394             e.detail, errors=error_list, message=e.message)
#    1395     return MakeSoapRequest
#    1396
#
# GoogleAdsServerFault: [OperationAccessDenied.OPERATION_NOT_PERMITTED_FOR_REMOVED_ENTITY @ operations[0]; trigger:'AdGroup']

# %% [markdown]
# # Test

# %%
from ai_optimizer.codes import gdn_db
CRITERIA_LIST = ['ADGROUP', 'URL', 'CRITERIA', 'AGE_RANGE', 'DISPLAY_KEYWORD', 'AUDIENCE']
CRITERIA_LIST = ['URL', 'CRITERIA', 'AGE_RANGE', 'DISPLAY_KEYWORD', 'AUDIENCE']
SCORE_INDEX = {
#     'ADGROUP': 'adgroup',
    'URL': 'url',
    'CRITERIA': 'criteria',
    'AUDIENCE': 'audience',
    'AGE_RANGE': 'age_range',
    'DISPLAY_KEYWORD': 'display_keyword',
}
CRITERIA_COLUMN_INDEX = {
#     'ADGROUP': 'adgroup_id',
    'URL': 'url_display_name',
    'CRITERIA': 'keyword_id',
    'AUDIENCE': 'criterion_id',
    'AGE_RANGE': 'criterion_id',
    'DISPLAY_KEYWORD': 'keyword_id',
}
CRITERIA_TYPE_INDEX = {
    'URL': 'Placement',
    'CRITERIA': 'Criteria',
    'AUDIENCE': 'CriterionUserInterest',
    'AGE_RANGE': 'AgeRange',
    'DISPLAY_KEYWORD': 'Keyword',
}

# %%
make_adgroup_criterion_by_score(1777436620)
# Out:
# AGE_RANGE
# True
# DISPLAY_KEYWORD
# True
# [{'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503999}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503006}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503004}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503005}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503002}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 359766231285,
#    'matchType': 'BROAD',
#    'text': '真善美旅行社'}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 305601653452,
#    'matchType': 'BROAD',
#    'text': '策馬特'}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 295738708969,
#    'matchType': 'BROAD',
#    'text': '文藝復興'}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 2055642706,
#    'matchType': 'BROAD',
#    'text': '跨年'}},
#  {'adGroupId': 66276904021,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 330657408684,
#    'matchType': 'BROAD',
#    'text': '維也納'}}]

# %%
def make_adgroup_criterion_by_score(campaign_id, new_ad_group_id):
    criterions=[]
    for criteria in SCORE_INDEX.keys():
        df = gdn_db.get_table(campaign_id=campaign_id, table=SCORE_INDEX[criteria]+"_score").head()
        if not df.empty:
            print(criteria)
            sub_criterions = []
            df = df.sort_values(by=['score'], ascending=False).reset_index(drop=True).drop_duplicates([CRITERIA_COLUMN_INDEX[criteria]])
            criterion = {
                'adGroupId': new_ad_group_id,
                'xsi_type': 'BiddableAdGroupCriterion',
                'criterion': {
                    'xsi_type': None,
                    'id': None
                }
            }
            if criteria == 'AGE_RANGE':
                criterion['criterion']['xsi_type'] = CRITERIA_TYPE_INDEX[criteria]
                for i, criterion_id in enumerate( df[CRITERIA_COLUMN_INDEX[criteria]] ):
                    if CRITERIA_TYPE_INDEX[criteria] == 'AgeRange':
                        criterion['criterion']['id'] = criterion_id
                        sub_criterions.append(copy.deepcopy(criterion))
            else:
                criterion['criterion']['xsi_type'] = CRITERIA_TYPE_INDEX[criteria]
                for i, criterion_id in enumerate( df[CRITERIA_COLUMN_INDEX[criteria]] ):
                    if CRITERIA_TYPE_INDEX[criteria] == 'Placement':
                        criterion['criterion']['id'] = criterion_id
                        criterion['criterion']['url'] = df['url_display_name'].iloc[0]

                    elif CRITERIA_TYPE_INDEX[criteria] == 'Keyword':
#                         criterion['criterion']['id'] = criterion_id
                        criterion['criterion']['matchType'] = 'BROAD'
                        criterion['criterion']['text'] = df['keyword'].iloc[i]

                    elif CRITERIA_TYPE_INDEX[criteria] == 'CriterionUserInterest':
                        criterion['criterion']['userInterestId'] = criterion_id
                    sub_criterions.append(copy.deepcopy(criterion))
            if sub_criterions:
                print(True)
            criterions = criterions+sub_criterions
    return criterions
#     return criterions

# %%
df_score.sort_values(by=['score'], ascending=False).reset_index(drop=True).head().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
# campaign_id     5 non-null int64
# adgroup_id      5 non-null int64
# score           5 non-null float64
# request_time    5 non-null object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 240.0+ bytes

# %%
criterions=[]
criterion = {
    'adGroupId': new_ad_group_id,
    'xsi_type': 'BiddableAdGroupCriterion',
    'criterion': {
        'xsi_type': None,
        'id': None
    }
}
df = df_score.sort_values(by=['score'], ascending=False).reset_index(drop=True).head().drop_duplicates(['criterion_id'])
for criterion_id in df['criterion_id']:
    criterion['criterion']['id'] = criterion_id
    
    criterions.append(copy.deepcopy(criterion))

# %% [markdown]
# ## Make New AdGroup With Criterion From Old AdGroup

# %%
old_ad_group_id = 67966950646
def make_adgroup_with_criterion(old_ad_group_id):
    # Params
    ad_group_params = make_ad_group(old_ad_group_id)
    new_ad_group_id = ad_group_params['value'][0]['id']
    # Criterion
    old_ad_group_criterion = retrieve_ad_group_criterion(client, old_ad_group_id)
#     biddable_criterion, negative_criterion = make_adgroup_criterion(new_ad_group_id, old_ad_group_criterion)
#     new_ad_group_criterion = biddable_criterion + negative_criterion
    new_ad_group_criterion = make_adgroup_criterion_by_score(campaign_id, new_ad_group_id)
    result = assign_criterion_to_ad_group(client, new_ad_group_id, new_ad_group_criterion)
    # Assign Ad Params
    ad_params_list = retrive_ad_params(old_ad_group_id)
    assign_ad_to_ad_group(new_ad_group_id, ad_params_list)
    return result

# %%
new_ad_group_id = 69167404723
new_ad_group_criterion = [{'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503999}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503006}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503004}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503005}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503002}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {
    'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '真善美旅行社'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '策馬特'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '文藝復興'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '跨年'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '維也納'}}]

# %%
result = assign_criterion_to_ad_group(client, new_ad_group_id, new_ad_group_criterion)

# %%
ad_params_list = retrive_ad_params(old_ad_group_id)
assign_ad_to_ad_group(new_ad_group_id, ad_params_list)
# Out:
# {
#     'ListReturnValue.Type': 'AdGroupAdReturnValue',
#     'value': [
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882858,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=422'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 6514746134353674240,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 70,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/14673714865838352033'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/1319458119490947851'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x600.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882861,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=422'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 5120037624752373760,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 320,
#                                 'height': 50
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 96,
#                                 'height': 15
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/14551562636791700639'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/9954188705370015093'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '320x50.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882864,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=422'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -5211782870388965376,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 728,
#                                 'height': 90
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 180,
#                                 'height': 22
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/8955486865128252525'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/259329838164229438'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '728x90.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882867,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=422'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 7399421986155266048,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 160,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 36,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/3692387056790114380'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/7507378805434481608'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '160x600.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882870,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=422'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -6621409553755930624,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 250
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 120,
#                                 'height': 100
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/15693499327064682148'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/8603443706411405146'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x250_.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882873,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=271'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -5065415882499424256,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 320,
#                                 'height': 50
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 96,
#                                 'height': 15
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/15950999352914357809'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/18294762423440997978'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '320x50.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882876,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=271'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 139606192694493184,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 728,
#                                 'height': 90
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 180,
#                                 'height': 22
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/5836636047008830070'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/17679737960385334109'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '728x90.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427882879,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=271'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -5977957756995371008,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 160,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 36,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/10080061312232935663'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/12514007531394383324'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '160x600.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883002,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=271'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 8731361575950090240,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 250
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 120,
#                                 'height': 100
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/11785717876491390306'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/7842273460807713767'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x250.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883005,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=271'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 7874833221819564032,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 70,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/6705430164137558759'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/10773081936585421023'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x600.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883008,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=109'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 3122959470850736128,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 320,
#                                 'height': 50
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 96,
#                                 'height': 15
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/15967625983114895891'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/8893306093601515539'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '320-50-IST.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883011,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=109'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 4487844827060240384,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 728,
#                                 'height': 90
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 180,
#                                 'height': 22
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/2932695696139627730'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/3089167914741561345'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '728-90-IST.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883014,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=109'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -4962549972651212800,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 160,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 36,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/4804266651722890578'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/14440282147210970599'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '160-600-IST.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883017,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=109'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 3691833592922505216,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 250
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 120,
#                                 'height': 100
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/3155676085605628908'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/17559422721911506717'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300-250-IST.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883020,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=306'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 8036681333428191232,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 320,
#                                 'height': 50
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 96,
#                                 'height': 15
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/539206920169326101'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/12531123619705558041'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '320x50.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883023,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=306'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 1568386368617316352,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 728,
#                                 'height': 90
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 180,
#                                 'height': 22
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/11324384254798205144'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/16258322114947514578'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '728x90.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883026,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=306'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 8329402115067740160,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 160,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 36,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/1503184808263376421'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/7977658136581402677'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '160x600.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883029,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=306'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 4488126302036951040,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 250
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 120,
#                                 'height': 100
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/3995355020593164787'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/8133944959326262176'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x250.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883032,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=306'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 6090000394497294336,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 70,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/5781590790835647496'
#                         },
# ...
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x600.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883035,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=313'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -5731948627350257664,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 250
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 120,
#                                 'height': 100
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/15901899554302093571'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/14728667181443492066'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300X250-EFF.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883038,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=313'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -2458676123182039040,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 320,
#                                 'height': 50
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 96,
#                                 'height': 15
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/8262250824005717040'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/1332834112818972412'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '320x50-EFF.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883041,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=313'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 8921920135183204352,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 728,
#                                 'height': 90
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 180,
#                                 'height': 22
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/793171726848580071'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/3913389240606848793'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '728x90.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883044,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=313'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -7433746336542883840,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 160,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 36,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/3517063086555290033'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/273055427451988324'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '160X600-EFF.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883047,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=313'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': 3466848499990003712,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 70,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/11212736458412569694'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/9634154235967938616'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x600-EFF.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'ad': {
#                 'id': 343427883050,
#                 'url': None,
#                 'displayUrl': 'www.mitravel.com.tw',
#                 'finalUrls': [
#                     'http://www.mitravel.com.tw/tour_feature.php?id=109'
#                 ],
#                 'finalMobileUrls': [],
#                 'finalAppUrls': [],
#                 'trackingUrlTemplate': None,
#                 'finalUrlSuffix': None,
#                 'urlCustomParameters': None,
#                 'urlData': [],
#                 'automated': None,
#                 'type': 'IMAGE_AD',
#                 'devicePreference': None,
#                 'systemManagedEntitySource': None,
#                 'Ad.Type': 'ImageAd',
#                 'image': {
#                     'mediaId': None,
#                     'type': 'IMAGE',
#                     'referenceId': -8511002474583162880,
#                     'dimensions': [
#                         {
#                             'key': 'FULL',
#                             'value': {
#                                 'width': 300,
#                                 'height': 600
#                             }
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': {
#                                 'width': 70,
#                                 'height': 140
#                             }
#                         }
#                     ],
#                     'urls': [
#                         {
#                             'key': 'FULL',
#                             'value': 'https://tpc.googlesyndication.com/simgad/15523672007587627577'
#                         },
#                         {
#                             'key': 'PREVIEW',
#                             'value': 'https://tpc.googlesyndication.com/simgad/8947221364497628083'
#                         }
#                     ],
#                     'mimeType': 'IMAGE_JPEG',
#                     'sourceUrl': None,
#                     'name': None,
#                     'fileSize': 0,
#                     'creationTime': None,
#                     'Media.Type': 'Image',
#                     'data': None
#                 },
#                 'name': '300x600-IST.jpg',
#                 'adToCopyImageFrom': None
#             },
#             'status': 'ENABLED',
#             'policySummary': None,
#             'labels': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'forwardCompatibilityMap': [],
#             'adStrengthInfo': None
#         }
#     ],
#     'partialFailureErrors': []
# }

# %%
result
# Out:
# {
#     'ListReturnValue.Type': 'AdGroupCriterionReturnValue',
#     'value': [
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503999,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_UNDETERMINED'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503006,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_65_UP'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503004,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_45_54'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503005,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_55_64'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503002,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_25_34'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 359766231285,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '真善美旅行社',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'PENDING_REVIEW',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 305601653452,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '策馬特',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'PENDING_REVIEW',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 295738708969,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '文藝復興',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'PENDING_REVIEW',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 2055642706,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '跨年',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'PENDING_REVIEW',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 69167404723,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 330657408684,
#                 'type': 'KEYWORD',
#                 'Criterion.Type': 'Keyword',
#                 'text': '維也納',
#                 'matchType': 'BROAD'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'PENDING_REVIEW',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         }
#     ],
#     'partialFailureErrors': []
# }

# %%
make_adgroup_with_criterion(old_ad_group_id)
# Out:
# AGE_RANGE
# True
# DISPLAY_KEYWORD
# True
# [new_ad_group_id]:  69167404723
# [new_criterion]:  [{'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503999}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503006}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503004}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503005}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'AgeRange', 'id': 503002}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '真善美旅行社'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '策馬特'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '文藝復興'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '跨年'}}, {'adGroupId': 69167404723, 'xsi_type': 'BiddableAdGroupCriterion', 'criterion': {'xsi_type': 'Keyword', 'id': None, 'matchType': 'BROAD', 'text': '維也納'}}]
# (69167404723,
#  [{'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'AgeRange', 'id': 503999}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'AgeRange', 'id': 503006}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'AgeRange', 'id': 503004}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'AgeRange', 'id': 503005}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'AgeRange', 'id': 503002}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'Keyword',
#     'id': None,
#     'matchType': 'BROAD',
#     'text': '真善美旅行社'}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'Keyword',
#     'id': None,
#     'matchType': 'BROAD',
#     'text': '策馬特'}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'Keyword',
#     'id': None,
#     'matchType': 'BROAD',
#     'text': '文藝復興'}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'Keyword',
#     'id': None,
#     'matchType': 'BROAD',
#     'text': '跨年'}},
#   {'adGroupId': 69167404723,
#    'xsi_type': 'BiddableAdGroupCriterion',
#    'criterion': {'xsi_type': 'Keyword',
#     'id': None,
#     'matchType': 'BROAD',
#     'text': '維也納'}}])

# %%
ad_group_params = make_ad_group(old_ad_group_id)

# %%
new_ad_group_id = ad_group_params['value'][0]['id']

# %%
old_ad_group_criterion = retrieve_ad_group_criterion(client, old_ad_group_id)

# %%
new_ad_group_criterion = make_adgroup_criterion_by_score(campaign_id)
# Out:
# AGE_RANGE
# True
# DISPLAY_KEYWORD
# True

# %%
criterion
# Out:
# {'adGroupId': 66867879022,
#  'xsi_type': 'BiddableAdGroupCriterion',
#  'criterion': {'xsi_type': 'Keyword',
#   'id': 330657408684,
#   'matchType': 'BROAD',
#   'text': '維也納'}}

# %%
biddable_criterion
# Out:
# [{'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Gender'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Gender'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Gender'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Parent'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Parent'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Parent'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503002}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503003}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503004}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503005}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503006}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'AgeRange', 'id': 503999}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 301633843,
#    'matchType': 'BROAD',
#    'text': '瑞士'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 304679784,
#    'matchType': 'BROAD',
#    'text': '波西米亞'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 321256110,
#    'matchType': 'BROAD',
#    'text': '西班牙'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 345327055,
#    'matchType': 'BROAD',
#    'text': '德國'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 357693175,
#    'matchType': 'BROAD',
#    'text': '巴黎'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 370483024,
#    'matchType': 'BROAD',
#    'text': '法國'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 461144284,
#    'matchType': 'BROAD',
#    'text': '冰島'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 461151364,
#    'matchType': 'BROAD',
#    'text': '馬德里'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 706784884,
#    'matchType': 'BROAD',
#    'text': '捷克'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 1483017079,
#    'matchType': 'BROAD',
#    'text': '羅浮宮'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 5226886094,
#    'matchType': 'BROAD',
#    'text': '萊茵河'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 5226900554,
#    'matchType': 'BROAD',
#    'text': '馬特洪峰'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 5537877448,
#    'matchType': 'BROAD',
#    'text': '米其林'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 9682969820,
#    'matchType': 'BROAD',
#    'text': '巴洛克'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 295738708969,
#    'matchType': 'BROAD',
#    'text': '文藝復興'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 296185093360,
#    'matchType': 'BROAD',
#    'text': '聖保羅'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 296334766526,
#    'matchType': 'BROAD',
#    'text': '極光'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 297071252151,
#    'matchType': 'BROAD',
#    'text': '慕尼黑'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 297373137830,
#    'matchType': 'BROAD',
#    'text': '薰衣草季'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 297413409300,
#    'matchType': 'BROAD',
#    'text': '巴塞隆納'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 298542862720,
#    'matchType': 'BROAD',
#    'text': '瑞士火車'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 299526325873,
#    'matchType': 'BROAD',
#    'text': '奧地利'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 300074153175,
#    'matchType': 'BROAD',
#    'text': '少女峰'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 300074153935,
#    'matchType': 'BROAD',
#    'text': '布拉格'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 301763494688,
#    'matchType': 'BROAD',
#    'text': '凡爾賽宮'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 301763800448,
#    'matchType': 'BROAD',
#    'text': '蔚藍海岸'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 305601653452,
#    'matchType': 'BROAD',
#    'text': '策馬特'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 305939782781,
#    'matchType': 'BROAD',
#    'text': '克倫洛夫'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 307271012094,
#    'matchType': 'BROAD',
#    'text': '安達露西亞'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 308596898113,
#    'matchType': 'BROAD',
#    'text': '伯恩'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 308596948513,
#    'matchType': 'BROAD',
#    'text': '藍湖'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 316474204495,
#    'matchType': 'BROAD',
#    'text': '亞爾薩斯'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 323056253441,
#    'matchType': 'BROAD',
#    'text': '加泰隆尼亞'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 328102397204,
#    'matchType': 'BROAD',
#    'text': '普羅旺斯'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 330657408684,
#    'matchType': 'BROAD',
#    'text': '維也納'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 352947749007,
#    'matchType': 'BROAD',
#    'text': '德瑞'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 371581817463,
#    'matchType': 'BROAD',
#    'text': '藍冰洞'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 387155761625,
#    'matchType': 'BROAD',
#    'text': '冰川健行'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 390354391177,
#    'matchType': 'BROAD',
#    'text': '國王湖'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 394920119233,
#    'matchType': 'BROAD',
#    'text': '卡羅維瓦利'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 394920230633,
#    'matchType': 'BROAD',
#    'text': '瓦倫索勒'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 403496301737,
#    'matchType': 'BROAD',
#    'text': '琉森湖'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 412338129802,
#    'matchType': 'BROAD',
#    'text': '哈布斯堡王朝'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 468951123496,
#    'matchType': 'BROAD',
#    'text': '北極光遊船'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 468951123536,
#    'matchType': 'BROAD',
#    'text': '杜恩湖'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 468951123736,
#    'matchType': 'BROAD',
#    'text': '策馬特連'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 489312944108,
#    'matchType': 'BROAD',
#    'text': '艾菲爾鐵'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 561078738205,
#    'matchType': 'BROAD',
#    'text': '伏爾塔瓦河'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 561078738365,
#    'matchType': 'BROAD',
#    'text': '紅蔥頭教堂'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 561078738405,
#    'matchType': 'BROAD',
#    'text': '薩爾茲卡莫'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 561078738445,
#    'matchType': 'BROAD',
#    'text': '薩爾茲卡莫古特湖區'}},
#  {'adGroupId': 71763883120,
#   'xsi_type': 'BiddableAdGroupCriterion',
#   'criterion': {'xsi_type': 'Keyword',
#    'id': 561078738605,
#    'matchType': 'BROAD',
#    'text': '薩爾茲堡景觀餐廳'}}]

# %%
assign_criterion_to_ad_group(client, new_ad_group_id, criterions)
# Out:
# {
#     'ListReturnValue.Type': 'AdGroupCriterionReturnValue',
#     'value': [
#         {
#             'adGroupId': 66867879022,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503005,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_55_64'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 66867879022,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503005,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_55_64'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 66867879022,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503005,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_55_64'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         },
#         {
#             'adGroupId': 66867879022,
#             'criterionUse': None,
#             'criterion': {
#                 'id': 503005,
#                 'type': 'AGE_RANGE',
#                 'Criterion.Type': 'AgeRange',
#                 'ageRangeType': 'AGE_RANGE_55_64'
#             },
#             'labels': [],
#             'forwardCompatibilityMap': [],
#             'baseCampaignId': None,
#             'baseAdGroupId': None,
#             'AdGroupCriterion.Type': 'BiddableAdGroupCriterion',
#             'userStatus': 'ENABLED',
#             'systemServingStatus': 'ELIGIBLE',
#             'approvalStatus': 'APPROVED',
#             'disapprovalReasons': [],
#             'firstPageCpc': None,
#             'topOfPageCpc': None,
#             'firstPositionCpc': None,
#             'qualityInfo': None,
#             'biddingStrategyConfiguration': {
#                 'biddingStrategyId': None,
#                 'biddingStrategyName': None,
#                 'biddingStrategyType': 'MANUAL_CPC',
#                 'biddingStrategySource': 'CAMPAIGN',
#                 'biddingScheme': {
#                     'BiddingScheme.Type': 'ManualCpcBiddingScheme',
#                     'enhancedCpcEnabled': False
#                 },
#                 'bids': [
#                     {
#                         'Bids.Type': 'CpmBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 10000
#                         },
#                         'cpmBidSource': 'ADGROUP'
#                     },
#                     {
#                         'Bids.Type': 'CpcBid',
#                         'bid': {
#                             'ComparableValue.Type': 'Money',
#                             'microAmount': 3000000
#                         },
#                         'cpcBidSource': 'ADGROUP'
#                     }
#                 ],
#                 'targetRoasOverride': None
#             },
#             'bidModifier': None,
#             'finalUrls': None,
#             'finalMobileUrls': None,
#             'finalAppUrls': None,
#             'trackingUrlTemplate': None,
#             'finalUrlSuffix': None,
#             'urlCustomParameters': None
#         }
#     ],
#     'partialFailureErrors': []
# }

# %%
client = adwords.AdWordsClient.LoadFromStorage(AUTH_FILE_PATH)
ad_group_service = client.GetService('AdGroupService', version='v201809')

# Construct operations and update an ad group.
operations = [{
    'operator': 'SET',
    'operand': {
        'id': ad_group_id,
        'status': 'ACTIVE'
    }
}]

if bid_micro_amount:
    operations[0]['operand']['biddingStrategyConfiguration'] = {
      'bids': [{
          'xsi_type': 'CpcBid',
          'bid': {
              'microAmount': bid_micro_amount,
          }
      }]
    }

ad_groups = ad_group_service.mutate(operations)
