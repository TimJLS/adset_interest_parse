# %%
import mysql.connector
import pandas as pd
import datetime
from pandas.io import sql
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import MySQLdb as db

import numpy as np

# %%
CAMPAIGN_ID = 23843180432940316

# %%
date = datetime.date(2018,11,8)
minute = datetime.time(11,59,20).minute

# %%
def connectDB(db_name):
    mydb = mysql.connector.connect(
        host="localhost", 
        user="root",
        passwd="adgeek1234",
        database=db_name
    )
    return mydb
mydb = connectDB("ad_activity")
df_camp = pd.read_sql( "SELECT * FROM by_campaign where campaign_id = %s" %(CAMPAIGN_ID), con=mydb)

# %%
df_camp1108 = df_camp[ (df_camp.request_time.dt.date == date) & (df_camp.request_time.dt.minute == minute) ]
df_camp1108.head(3)
# Out:
#                    ad_id      cpc  clicks  impressions  reach  \
# 28973  23843180433050316  3.33333       6           64     64
# 28974  23843180432960316  0.00000       0            2      2
# 29118  23843180433050316  2.00000      14          181    181
#
#              campaign_id spend_cap    objective          start_time  \
# 28973  23843180432940316      None  LINK_CLICKS 2018-11-05 00:00:59
# 28974  23843180432940316      None  LINK_CLICKS 2018-11-05 00:00:59
# 29118  23843180432940316      None  LINK_CLICKS 2018-11-05 00:00:59
#
#                 stop_time                        ...                          \
# 28973 2018-11-12 23:59:00                        ...
# 28974 2018-11-12 23:59:00                        ...
# 29118 2018-11-12 23:59:00                        ...
#
#        bid_amount  daily_budget        request_time total_clicks  avgspeed  \
# 28973          10          6874 2018-11-08 00:59:05          700      None
# 28974           5          2552 2018-11-08 00:59:07          700      None
# 29118          10          6874 2018-11-08 01:59:05          700      None
#
#       speed age_max  age_min  \
# 28973  None      44       25
# 28974  None      44       25
# 29118  None      44       25
#
#                                            flexible_spec  \
# 28973  [{'interests': [{'name': 'Online shopping', 'i...
# 28974  [{'interests': [{'name': '媽媽寶寶-懷孕、生產、育兒', 'id'...
# 29118  [{'interests': [{'id': '6003346592981', 'name'...
#
#                                            geo_locations
# 28973  <TargetingGeoLocation> {\n    "countries": [\n...
# 28974  <TargetingGeoLocation> {\n    "countries": [\n...
# 29118  <TargetingGeoLocation> {\n    "countries": [\n...
#
# [3 rows x 21 columns]

# %%
ad_list=df_camp1108['ad_id'].unique()
df_camp1108 = df_camp1108.sort_values(by=['ad_id','request_time']).reset_index(drop=True)
df_camp1108.head(3)
# Out:
#                ad_id  cpc  clicks  impressions  reach        campaign_id  \
# 0  23843180432910316  0.0       0            1      1  23843180432940316
# 1  23843180432910316  0.0       0            1      1  23843180432940316
# 2  23843180432910316  0.0       0            1      1  23843180432940316
#
#   spend_cap    objective          start_time           stop_time  \
# 0      None  LINK_CLICKS 2018-11-05 00:00:59 2018-11-12 23:59:00
# 1      None  LINK_CLICKS 2018-11-05 00:00:59 2018-11-12 23:59:00
# 2      None  LINK_CLICKS 2018-11-05 00:00:59 2018-11-12 23:59:00
#
#                          ...                          bid_amount  \
# 0                        ...                                   5
# 1                        ...                                   5
# 2                        ...                                   5
#
#    daily_budget        request_time total_clicks  avgspeed speed age_max  \
# 0           663 2018-11-08 02:59:10          700      None  None      44
# 1           663 2018-11-08 03:59:12          700      None  None      44
# 2           663 2018-11-08 04:59:12          700      None  None      44
#
#    age_min                                      flexible_spec  \
# 0       25  [{'interests': [{'name': 'Mammary gland', 'id'...
# 1       25  [{'interests': [{'id': '6002969062168', 'name'...
# 2       25  [{'interests': [{'id': '6002969062168', 'name'...
#
#                                        geo_locations
# 0  <TargetingGeoLocation> {\n    "countries": [\n...
# 1  <TargetingGeoLocation> {\n    "countries": [\n...
# 2  <TargetingGeoLocation> {\n    "countries": [\n...
#
# [3 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
date = datetime.date(2018,11,5)
minute = datetime.time(11,59,20).minute

# %%
df_camp1105 = df_camp[ (df_camp.request_time.dt.date == date) & (df_camp.request_time.dt.minute == minute) ]
ad_list=df_camp1105['ad_id'].unique()
df_camp1105 = df_camp1105.sort_values(by=['ad_id','request_time']).reset_index(drop=True)

# %%
fig=plt.figure(figsize=(15,10))

for ad in ad_list:
    # plot 1
    plt.subplot(3, 1, 1)
#     plt.xlabel('Time (hr)')
    plt.ylabel('CPC')
    plt.title('11/05 Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df_camp1105['request_time'][df_camp1105.ad_id==ad],df_camp1105['cpc'][df_camp1105.ad_id==ad],'o-', label=ad)
    plt.legend()
    # plot 2
    
    plt.subplot(3, 1, 2)
#     plt.xlabel('Time (hr)')
    plt.ylabel('Bid Amount')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df_camp1105['request_time'][df_camp1105.ad_id==ad],df_camp1105['bid_amount'][df_camp1105.ad_id==ad],'o-',label=ad)
    plt.legend()
    
    # plot 3
    plt.subplot(3, 1, 3)
    plt.xlabel('Time (hr)')
    plt.ylabel('Daily Budget')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df_camp1105['request_time'][df_camp1105.ad_id==ad],df_camp1105['daily_budget'][df_camp1105.ad_id==ad],'o-',label=ad)
    plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
date = datetime.date(2018,11,6)
minute = datetime.time(11,59,20).minute
df = df_camp[ (df_camp.request_time.dt.date == date) & (df_camp.request_time.dt.minute == minute) ]
ad_list=df['ad_id'].unique()
df = df.sort_values(by=['ad_id','request_time']).reset_index(drop=True)

# %%
fig=plt.figure(figsize=(15,10))

for ad in ad_list:
    # plot 1
    plt.subplot(3, 1, 1)
#     plt.xlabel('Time (hr)')
    plt.ylabel('CPC')
    plt.title('11/06 Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['cpc'][df.ad_id==ad],'o-', label=ad)
    plt.legend()
    # plot 2
    
    plt.subplot(3, 1, 2)
#     plt.xlabel('Time (hr)')
    plt.ylabel('Bid Amount')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['bid_amount'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
    
    # plot 3
    plt.subplot(3, 1, 3)
    plt.xlabel('Time (hr)')
    plt.ylabel('Daily Budget')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['daily_budget'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
date = datetime.date(2018,11,7)
minute = datetime.time(11,59,20).minute
df = df_camp[ (df_camp.request_time.dt.date == date) & (df_camp.request_time.dt.minute == minute) ]
ad_list=df['ad_id'].unique()
df = df.sort_values(by=['ad_id','request_time']).reset_index(drop=True)

# %%
fig=plt.figure(figsize=(15,10))

for ad in ad_list:
    # plot 1
    plt.subplot(3, 1, 1)
#     plt.xlabel('Time (hr)')
    plt.ylabel('CPC')
    plt.title('11/07 Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['cpc'][df.ad_id==ad],'o-', label=ad)
    plt.legend()
    # plot 2
    
    plt.subplot(3, 1, 2)
#     plt.xlabel('Time (hr)')
    plt.ylabel('Bid Amount')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['bid_amount'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
    
    # plot 3
    plt.subplot(3, 1, 3)
    plt.xlabel('Time (hr)')
    plt.ylabel('Daily Budget')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['daily_budget'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
date = datetime.date(2018,11,8)
minute = datetime.time(11,59,20).minute
df = df_camp[ (df_camp.request_time.dt.date == date) & (df_camp.request_time.dt.minute == minute) ]
ad_list=df['ad_id'].unique()
df = df.sort_values(by=['ad_id','request_time']).reset_index(drop=True)

# %%
fig=plt.figure(figsize=(15,10))

for ad in ad_list:
    # plot 1
    plt.subplot(3, 1, 1)
#     plt.xlabel('Time (hr)')
    plt.ylabel('CPC')
    plt.title('11/08 Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['cpc'][df.ad_id==ad],'o-', label=ad)
    plt.legend()
    # plot 2
    
    plt.subplot(3, 1, 2)
#     plt.xlabel('Time (hr)')
    plt.ylabel('Bid Amount')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['bid_amount'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
    
    # plot 3
    plt.subplot(3, 1, 3)
    plt.xlabel('Time (hr)')
    plt.ylabel('Daily Budget')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['daily_budget'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
date = datetime.date(2018,11,9)
minute = datetime.time(11,59,20).minute
df = df_camp[ (df_camp.request_time.dt.date == date) & (df_camp.request_time.dt.minute == minute) ]
ad_list=df['ad_id'].unique()
df = df.sort_values(by=['ad_id','request_time']).reset_index(drop=True)

# %%
fig=plt.figure(figsize=(15,10))

for ad in ad_list:
    # plot 1
    plt.subplot(3, 1, 1)
#     plt.xlabel('Time (hr)')
    plt.ylabel('CPC')
    plt.title('11/09 Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['cpc'][df.ad_id==ad],'o-', label=ad)
    plt.legend()
    # plot 2
    
    plt.subplot(3, 1, 2)
#     plt.xlabel('Time (hr)')
    plt.ylabel('Bid Amount')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['bid_amount'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
    
    # plot 3
    plt.subplot(3, 1, 3)
    plt.xlabel('Time (hr)')
    plt.ylabel('Daily Budget')
#     plt.title('Time Series Distibution')
    plt.grid(True)
    
    plt.plot(df['request_time'][df.ad_id==ad],df['daily_budget'][df.ad_id==ad],'o-',label=ad)
    plt.legend()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
